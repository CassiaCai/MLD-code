# %%
import re
w = open("bndgb2.txt", "r", encoding="utf-8")
w.read()
w = '  40.00   69.50\n  40.30   68.00\n  40.40   67.50\n  40.60   67.00\n  40.80   66.50\n  41.45   66.00\n  41.80   65.70\n  42.10   66.00\n  42.10   67.00\n  42.10   67.50\n  41.80   68.00\n  41.10   69.00\n  41.00   69.50\n  40.00   69.50\n'
output1w = w.split('\n')

neww = [] 
for string in output1w:
    output2w = string.split(' ')
    neww.append(output2w)

neww = [['', '', '40.00', '', '', '69.50'], ['', '', '40.30', '', '', '68.00'], ['', '', '40.40', '', '', '67.50'], ['', '', '40.60', '', '', '67.00'], ['', '', '40.80', '', '', '66.50'], ['', '', '41.45', '', '', '66.00'], ['', '', '41.80', '', '', '65.70'], ['', '', '42.10', '', '', '66.00'], ['', '', '42.10', '', '', '67.00'], ['', '', '42.10', '', '', '67.50'], ['', '', '41.80', '', '', '68.00'], ['', '', '41.10', '', '', '69.00'], ['', '', '41.00', '', '', '69.50'], ['', '', '40.00', '', '', '69.50']]
lon_w = []; lat_w = []

for i in range(14): 
    w1 = neww[i][2]
    lat_w.append(w1)
    w3 = neww[i][5]
    lon_w.append(w3)
lonlist_w = [float(i) for i in lon_w]; latlist_w = [float(i) for i in lat_w]
df_w = pd.DataFrame({'lon': lonlist_w, 'lat': latlist_w,})

lonlist_w_plot = [float(i)*-1 for i in lon_w]; latlist_w = [float(i) for i in lat_w]
df_w_plot = pd.DataFrame({'lon': lonlist_w_plot, 'lat': latlist_w,})
x_w = df_w_plot['lon']; y_w = df_w_plot['lat']

# %%
polygon_w = Polygon(df_w.values)
print(polygon_w)
# Out:
# POLYGON ((69.5 40, 68 40.3, 67.5 40.4, 67 40.6, 66.5 40.8, 66 41.45, 65.7 41.8, 66 42.1, 67 42.1, 67.5 42.1, 68 41.8, 69 41.1, 69.5 41, 69.5 40))

# %%
v = open("bndmbs.txt", "r", encoding="utf-8")
v.read()
v = '  37.00   76.00\n  36.00   75.50\n  35.50   75.00\n  36.00   74.75\n  37.40   74.50\n  39.50   72.00\n  40.50   74.00\n  39.40   74.25\n  37.00   76.00\n'
output1v = v.split('\n')

newv = [] 
for string in output1v:
    output2v = string.split(' ')
    newv.append(output2v)

newv = [['', '', '37.00', '', '', '76.00'], ['', '', '36.00', '', '', '75.50'], ['', '', '35.50', '', '', '75.00'], ['', '', '36.00', '', '', '74.75'], ['', '', '37.40', '', '', '74.50'], ['', '', '39.50', '', '', '72.00'], ['', '', '40.50', '', '', '74.00'], ['', '', '39.40', '', '', '74.25'], ['', '', '37.00', '', '', '76.00']]
lon_v = []; lat_v = []

for i in range(9): 
    v1 = newv[i][2]
    lat_v.append(v1)
    v3 = newv[i][5]
    lon_v.append(v3)
lonlist_v = [float(i) for i in lon_v]; latlist_v = [float(i) for i in lat_v]
df_v = pd.DataFrame({'lon': lonlist_v, 'lat': latlist_v,})


lonlist_v_plot = [float(i)*-1 for i in lon_v]; latlist_v = [float(i) for i in lat_v]
df_v_plot = pd.DataFrame({'lon': lonlist_v_plot, 'lat': latlist_v,})
x_v = df_v_plot['lon']; y_v = df_v_plot['lat']

# %%
polygon_v = Polygon(df_v.values.tolist())
print(polygon_v)
# Out:
# POLYGON ((76 37, 75.5 36, 75 35.5, 74.75 36, 74.5 37.4, 72 39.5, 74 40.5, 74.25 39.4, 76 37))

# %%
x = open("bndmbn.txt", "r", encoding="utf-8")
x.read()
x = '  40.50   74.00\n  39.50   72.00\n  40.00   71.40\n  40.00   69.50\n  41.00   69.50\n  41.10   70.00\n  41.00   72.00\n  40.50   74.00\n'
output1x = x.split('\n')

newx = [] 
for string in output1x:
    output2x = string.split(' ')
    newx.append(output2x)
newx = [['', '', '40.50', '', '', '74.00'], ['', '', '39.50', '', '', '72.00'], ['', '', '40.00', '', '', '71.40'], ['', '', '40.00', '', '', '69.50'], ['', '', '41.00', '', '', '69.50'], ['', '', '41.10', '', '', '70.00'], ['', '', '41.00', '', '', '72.00'], ['', '', '40.50', '', '', '74.00']]
lon_x = []; lat_x = []

for i in range(8): 
    x1 = newx[i][2]
    lat_x.append(x1)
    x3 = newx[i][5]
    lon_x.append(x3)
lonlist_x = [float(i) for i in lon_x]; latlist_x = [float(i) for i in lat_x]
df_x = pd.DataFrame({'lon': lonlist_x, 'lat': latlist_x,})

lonlist_x_plot = [float(i)*-1 for i in lon_x]; latlist_x = [float(i) for i in lat_x]
df_x_plot = pd.DataFrame({'lon': lonlist_x_plot, 'lat': latlist_x,})
x_x = df_x_plot['lon']; y_x = df_x_plot['lat']

# %%
polygon_x = Polygon(df_x.values.tolist())
print(polygon_x)
# Out:
# POLYGON ((74 40.5, 72 39.5, 71.40000000000001 40, 69.5 40, 69.5 41, 70 41.1, 72 41, 74 40.5))

# %%
y = open("bndgme.txt", "r", encoding="utf-8")
y.read()
y = '  41.80   68.00\n  42.10   67.50\n  42.10   67.00\n  42.10   66.00\n  43.00   66.00\n  44.20   66.50\n  44.20   67.00\n  44.20   68.00\n  41.80   68.00\n'
output1y = y.split('\n')

newy = [] 
for string in output1y:
    output2y = string.split(' ')
    newy.append(output2y)
newy = [['', '', '41.80', '', '', '68.00'], ['', '', '42.10', '', '', '67.50'], ['', '', '42.10', '', '', '67.00'], ['', '', '42.10', '', '', '66.00'], ['', '', '43.00', '', '', '66.00'], ['', '', '44.20', '', '', '66.50'], ['', '', '44.20', '', '', '67.00'], ['', '', '44.20', '', '', '68.00'], ['', '', '41.80', '', '', '68.00']]
lon_y = []; lat_y = []

for i in range(9): 
    y1 = newy[i][2]
    lat_y.append(y1)
    y3 = newy[i][5]
    lon_y.append(y3)
lonlist_y = [float(i) for i in lon_y]; latlist_y = [float(i) for i in lat_y]
df_y = pd.DataFrame({'lon': lonlist_y, 'lat': latlist_y,})

lonlist_y_plot = [float(i)*-1 for i in lon_y]; latlist_y = [float(i) for i in lat_y]
df_y_plot = pd.DataFrame({'lon': lonlist_y_plot, 'lat': latlist_y,})
x_y = df_y_plot['lon']; y_y = df_y_plot['lat']

# %%
polygon_y = Polygon(df_y.values)
print(polygon_y)
# Out:
# POLYGON ((68 41.8, 67.5 42.1, 67 42.1, 66 42.1, 66 43, 66.5 44.2, 67 44.2, 68 44.2, 68 41.8))

# %%
t = open("bndgmw.txt", "r", encoding="utf-8")
t.read()
t = '  42.20   70.50\n  42.00   70.00\n  41.10   69.00\n  41.80   68.00\n  44.20   68.00\n  43.90   69.00\n  43.70   70.00\n  43.00   70.50\n  42.20   70.50'
output1t = t.split('\n')
newt = [] 
for string in output1t:
    output2t = string.split(' ')
    newt.append(output2t)
lon_t = []; lat_t = []

for i in range(9): 
    t1 = newt[i][2]
    lat_t.append(t1)
    t3 = newt[i][5]
    lon_t.append(t3)
lonlist_t = [float(i) for i in lon_t]; latlist_t = [float(i) for i in lat_t]
df_t = pd.DataFrame({'lon': lonlist_t, 'lat': latlist_t,})

lonlist_t_plot = [float(i)*-1 for i in lon_t]; latlist_t = [float(i) for i in lat_t]
df_t_plot = pd.DataFrame({'lon': lonlist_t_plot, 'lat': latlist_t,})
x_t = df_t_plot['lon']; y_t = df_t_plot['lat']

# %%
polygon_t = Polygon(df_t.values)
print(polygon_t)
# Out:
# POLYGON ((70.5 42.2, 70 42, 69 41.1, 68 41.8, 68 44.2, 69 43.9, 70 43.7, 70.5 43, 70.5 42.2))

# %% [markdown]
# ### PLOTTING SET_UP

# %%
finaldepth = []; finallat = [];finallon = []
for year in range(1977,2020):
    filename = 'casts_{}.mat'.format(year)
    file = scipy.io.loadmat(filename,squeeze_me=True)
    npfile = file['casts_{}'.format(year)]
    
    lat_intermediate = []; lon_intermediate = []; p_intermediate = []; t_intermediate = []; yd_intermediate = []
    seasonyeardepth = []; seasonyeartemp = []; counterii = []
        
    for i in range(len(npfile)):
        yd = npfile[i]['yd']
        p = npfile[i]['p']
        s = npfile[i]['s']
        t = npfile[i]['t']
        lon = npfile[i]['lon']
        lat = npfile[i]['lat']
        floordepth = npfile[i]['depth']
        
        if yd > 334 and yd <= 365 or yd >= 0 and yd <= 59:
#         if yd > 243 and yd <= 334:
            lat_intermediate.append(npfile[i]['lat'])
            lon_intermediate.append(npfile[i]['lon'])
            p_intermediate.append(npfile[i]['p'])
            t_intermediate.append(npfile[i]['t'])
            yd_intermediate.append(npfile[i]['yd'])
            
    month_df = pd.DataFrame({'day': yd_intermediate,'lon': lon_intermediate,'lat': lat_intermediate, 'p': p_intermediate, 't': t_intermediate})
    newdf = pd.DataFrame({'lon': lon_intermediate,'lat': lat_intermediate})
    
#     print(newdf)
    
    for ii in range(len(month_df)):
        new = newdf.iloc[ii].values
        point = Point(new)
        if polygon_t.contains(point) == True:
#             print(ii)
            pt_df = pd.DataFrame({'p': month_df['p'].iloc[ii],'t': month_df['t'].iloc[ii]}) 
            df_ptsnew = pt_df.dropna()
            df_final = pd.DataFrame(df_ptsnew.values)
            l=[i for i in df_final[0] if i<=6]
            if len(l) > 0:
                surfaceval = []
                numrange = []
                for iii in range(len(l)):
                    val = df_final[1][iii]
                    numrange.append(iii)
                    surfaceval.append(val)
            surfacevalmean = statistics.mean(surfaceval)
#             print(surfacevalmean)
#             print(ii)
#             print(lat,lon)
            tempfin = []
            pressurefin = []
            for iii in range(numrange[-1],len(df_final)):
                tempfin.append(df_final[1][iii])
                pressurefin.append(df_final[0][iii])
            d = {'temp': list(reversed(tempfin)), 'pressure': list(reversed(pressurefin))}
            dffin = pd.DataFrame(d)
#             pnew = []; allmixedcount = []
#             inconclusivecount = []
            for ix in range(len(dffin)):
                b = dffin.at[ix,'temp']
                if b <= (surfacevalmean + 0.2) and b >= (surfacevalmean - 0.2):
                    if dffin.at[ix,'pressure'] >= floordepth - 6:
                        seasonyeartemp.append(dffin.at[ix,'temp'])
                        seasonyeardepth.append(dffin.at[ix,'pressure'])
#                         print(i,ii,iii,ix)
#                         print(newdf.iloc[ii])
                        counterii.append(ii)
                    elif dffin.at[ix,'pressure'] == df_final[0].iloc[-1]:
                        pass
                    else:
#                         pnew.append(dffin.at[ix,'pressure'])
                        seasonyeartemp.append(dffin.at[ix,'temp'])
                        seasonyeardepth.append(dffin.at[ix,'pressure'])
                        np.array(seasonyeartemp)
                        np.array(seasonyeardepth)
#                         print(i,ii,iii,ix)
#                         print(newdf.iloc[ii])
                        counterii.append(ii)
                    break  
#     if len(seasonyeartemp) > 0:
#         print(counterii)
    inlat = []; inlon = []
    for timer in counterii:
#         print(newdf['lat'][timer])
        inlat.append(newdf['lat'][timer])
        inlon.append(newdf['lon'][timer])
    dfplots = pd.DataFrame(list(zip(seasonyeardepth, inlat,inlon)),columns = ['depth','lat','lon'])
#     print('depth_',year,'=', seasonyeardepth)

    finaldepth.append(seasonyeardepth)
    finallat.append(inlat)
    finallon.append(inlon)
#     print('lat_',year,'=', inlat)
#     print('lon_',year,'=', inlon)
#     print(dfplots)
#         print('depth_',year,np.mean(seasonyeardepth))

# %%
# print(finaldepth)
flat_depth = [item for sublist in finaldepth for item in sublist]
flat_lat = [item for sublist in finallat for item in sublist]
flat_lon = [item for sublist in finallon for item in sublist]

# %%
print(len(flat_depth))
print(len(flat_lat))
print(len(flat_lon))
# Out:
# 943
# 943
# 943

# %%
flat_lon[:] = [x *-1 for x in flat_lon]

# %%
dfplottablet = pd.DataFrame(list(zip(flat_depth,flat_lon,flat_lat)),columns = ['depth','lon','lat'])

# %%
dfplottabley = pd.DataFrame(list(zip(flat_depth,flat_lon,flat_lat)),columns = ['depth','lon','lat'])

# %%
print(dfplottabley)
# Out:
#      depth        lon        lat
# 0     91.0 -67.716700  43.816700
# 1     46.0 -67.700000  43.400000
# 2     30.0 -67.700000  42.983300
# 3     34.0 -67.700000  42.600000
# 4     69.0 -67.466700  42.716700
# ..     ...        ...        ...
# 483   56.0 -66.750000  42.250000
# 484   36.0 -67.041667  42.368333
# 485   38.0 -67.041667  42.380000
# 486   60.0 -67.691667  42.006667
# 487   71.0 -67.755000  41.998333
#
# [488 rows x 3 columns]

# %%
dfplottablex = pd.DataFrame(list(zip(flat_depth,flat_lon,flat_lat)),columns = ['depth','lon','lat'])

# %%
print(dfplottablex)
# Out:
#      depth        lon        lat
# 0     20.0 -69.566700  40.133300
# 1     10.0 -69.700000  40.400000
# 2     30.0 -70.183300  40.683300
# 3     15.0 -70.583300  40.700000
# 4     20.0 -70.416700  40.216700
# ..     ...        ...        ...
# 992   55.0 -70.605000  40.661667
# 993   44.0 -70.606667  40.038333
# 994   73.0 -70.085000  40.081667
# 995   79.0 -69.670000  40.246667
# 996   92.0 -69.508333  40.078333
#
# [997 rows x 3 columns]

# %%
dfplottablew = pd.DataFrame(list(zip(flat_depth,flat_lon,flat_lat)),columns = ['depth','lon','lat'])

# %%
dfplottablev = pd.DataFrame(list(zip(flat_depth,flat_lon,flat_lat)),columns = ['depth','lon','lat'])

# %%
print(dfplottablev)
# Out:
#       depth        lon        lat
# 0      48.0 -74.966700  35.683300
# 1       1.0 -75.100000  36.150000
# 2      10.0 -74.766700  36.266700
# 3      35.0 -74.866700  36.650000
# 4      45.0 -74.833300  36.816700
# ...     ...        ...        ...
# 1225   38.0 -72.741667  39.058333
# 1226   84.0 -72.748333  39.331667
# 1227   32.0 -73.330000  39.493333
# 1228   33.0 -73.586667  39.831667
# 1229   67.0 -72.923333  39.828333
#
# [1230 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import griddata

# data coordinates and values
x_t = dfplottablet['lon']
y_t = dfplottablet['lat']
z_t = dfplottablet['depth']

# target grid to interpolate to
# xi = np.arange(-70.8,-67.8,0.05)
xi_t = np.arange(-71,-67,0.05)
yi_t = np.arange(40,44.5,0.05)
# xi = yi = np.arange(60,100,5)
xi_t,yi_t = np.meshgrid(xi_t,yi_t)

# set mask
# mask = polygon_v

# interpolate
zi_t = griddata((x_t,y_t),z_t,(xi_t,yi_t),method='linear')

# mask out the field
# zi[mask] = np.nan

# plot
fig = plt.figure()
ax = fig.add_subplot(111)
plt.contourf(xi_t,yi_t,zi_t,np.arange(0,180,1))
# plt.contourf(xi,yi,zi,np.arange(0,100,5))
# plt.plot(x,y,'k.')
plt.xlabel('xi',fontsize=16)
plt.ylabel('yi',fontsize=16)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import griddata

# data coordinates and values
x_v = dfplottablev['lon']
y_v = dfplottablev['lat']
z_v = dfplottablev['depth']

# target grid to interpolate to
# xi = np.arange(-70.8,-67.8,0.05)
xi_v = np.arange(-76,-72.5,0.05)
yi_v = np.arange(35,41.5,0.05)
# xi = yi = np.arange(60,100,5)
xi_v,yi_v = np.meshgrid(xi_v,yi_v)

# set mask
# mask = polygon_v

# interpolate
zi_v = griddata((x_v,y_v),z_v,(xi_v,yi_v),method='linear')

# mask out the field
# zi[mask] = np.nan

# plot
fig = plt.figure()
ax = fig.add_subplot(111)
plt.contourf(xi_v,yi_v,zi_v,np.arange(0,180,1))
# plt.contourf(xi,yi,zi,np.arange(0,100,5))
# plt.plot(x,y,'k.')
plt.xlabel('xi',fontsize=16)
plt.ylabel('yi',fontsize=16)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import griddata

# data coordinates and values
x_y = dfplottabley['lon']
y_y = dfplottabley['lat']
z_y = dfplottabley['depth']

# target grid to interpolate to
# xi = np.arange(-70.8,-67.8,0.05)
xi_y = np.arange(-69,-65,0.05)
yi_y = np.arange(41.5,44.5,0.05)
# xi = yi = np.arange(60,100,5)
xi_y,yi_y = np.meshgrid(xi_y,yi_y)

# set mask
# mask = polygon_v

# interpolate
zi_y = griddata((x_y,y_y),z_y,(xi_y,yi_y),method='linear')

# mask out the field
# zi[mask] = np.nan

# plot
fig = plt.figure()
ax = fig.add_subplot(111)
plt.contourf(xi_y,yi_y,zi_y,np.arange(0,180,1))
# plt.contourf(xi,yi,zi,np.arange(0,100,5))
# plt.plot(x,y,'k.')
plt.xlabel('xi',fontsize=16)
plt.ylabel('yi',fontsize=16)
plt.show()

# %%
print(xi_v,yi_v)
# Out:
# [[-76.   -75.95 -75.9  ... -72.65 -72.6  -72.55]
#  [-76.   -75.95 -75.9  ... -72.65 -72.6  -72.55]
#  [-76.   -75.95 -75.9  ... -72.65 -72.6  -72.55]
#  ...
#  [-76.   -75.95 -75.9  ... -72.65 -72.6  -72.55]
#  [-76.   -75.95 -75.9  ... -72.65 -72.6  -72.55]
#  [-76.   -75.95 -75.9  ... -72.65 -72.6  -72.55]] [[35.   35.   35.   ... 35.   35.   35.  ]
#  [35.05 35.05 35.05 ... 35.05 35.05 35.05]
#  [35.1  35.1  35.1  ... 35.1  35.1  35.1 ]
#  ...
#  [41.35 41.35 41.35 ... 41.35 41.35 41.35]
#  [41.4  41.4  41.4  ... 41.4  41.4  41.4 ]
#  [41.45 41.45 41.45 ... 41.45 41.45 41.45]]

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import griddata

# data coordinates and values
x_x = dfplottablex['lon']
y_x = dfplottablex['lat']
z_x = dfplottablex['depth']

# target grid to interpolate to
# xi = np.arange(-70.8,-67.8,0.05)
xi_x = np.arange(-76,-65,0.5)
yi_x = np.arange(35,41.5,0.5)
# xi = yi = np.arange(60,100,5)
xi_x,yi_x = np.meshgrid(xi_x,yi_x)

# set mask
# mask = polygon_v

# interpolate
zi_x = griddata((x_x,y_x),z_x,(xi_x,yi_x),method='linear')

# mask out the field
# zi[mask] = np.nan

# plot
fig = plt.figure()
ax = fig.add_subplot(111)
plt.contourf(xi_x,yi_x,zi_x,np.arange(0,180,1))
# plt.contourf(xi,yi,zi,np.arange(0,100,5))
# plt.plot(x,y,'k.')
plt.xlabel('xi',fontsize=16)
plt.ylabel('yi',fontsize=16)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import griddata

# data coordinates and values
x_w = dfplottablew['lon']
y_w = dfplottablew['lat']
z_w = dfplottablew['depth']

# target grid to interpolate to
xi_w = np.arange(-70.8,-65,0.5)
# xi_w = np.arange(-76,-72.5,0.05)
yi_w = np.arange(35,45,0.5)
# xi_ = yi = np.arange(60,100,5)
xi_w,yi_w = np.meshgrid(xi_w,yi_w)

# set mask
# mask = polygon_v

# interpolate
zi_w = griddata((x_w,y_w),z_w,(xi_w,yi_w),method='linear')

# mask out the field
# zi[mask] = np.nan

# # plot
fig = plt.figure()
ax = fig.add_subplot(111)
plt.contourf(xi_w,yi_w,zi_w,np.arange(0,180,1))
# plt.contourf(xi,yi,zi,np.arange(0,100,5))
# plt.plot(x,y,'k.')
plt.xlabel('xi',fontsize=16)
plt.ylabel('yi',fontsize=16)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.contourf(xi_w,yi_w,zi_w,np.arange(0,180,1))
# plt.contourf(xi,yi,zi,np.arange(0,100,5))
# plt.plot(x,y,'k.')
plt.xlabel('xi',fontsize=16)
plt.ylabel('yi',fontsize=16)
plt.show()

# %%
from matplotlib.pyplot import * ; import cartopy.feature as cfeature

plt.figure(figsize=(12, 8))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_extent([-78, -65, 35, 44.75], ccrs.PlateCarree())
# ax.set_extent([-76, -72, 35.5, 40.5], ccrs.PlateCarree())
feature = cfeature.NaturalEarthFeature(name='coastline', category='physical',scale='50m',edgecolor='black', facecolor='grey')

ax.add_feature(feature)
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,linewidth=1, color='black', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.ylabels_left = True
gl.ylabels_right = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
plt.contourf(xi_w,yi_w,zi_w,np.arange(0,180,1),vmin = 0,vmax = 150)
plt.contourf(xi_v,yi_v,zi_v,np.arange(0,180,1),vmin = 0, vmax = 150)
plt.contourf(xi_x,yi_x,zi_x,np.arange(0,180,1),vmin = 0, vmax = 150)
plt.contourf(xi_y,yi_y,zi_y,np.arange(0,180,1),vmin = 0, vmax = 150)
plt.contourf(xi_t,yi_t,zi_t,np.arange(0,180,1),vmin = 0, vmax = 150)

# cf = plt.contourf(xi_w,yi_w,zi_w,np.arange(0,180,1),cmap = 'ocean_r')

plt.contour(xi_w, yi_w, zi_w, levels=5, linewidths=1,colors='white')
plt.contour(xi_v, yi_v, zi_v, levels=5, linewidths=1,colors='white')
plt.contour(xi_x, yi_x, zi_x, levels=5, linewidths=1,colors='white')
plt.contour(xi_y, yi_y, zi_y, levels=5, linewidths=1,colors='white')
plt.contour(xi_t, yi_t, zi_t, levels=5, linewidths=1,colors='white')

# cbar = plt.colorbar(cf, ax=ax)

# plot(x_v,y_v,color='red', linewidth = 2, linestyle='-') #Western GoM
# plot(x_w,y_w,color='red', linewidth = 0.1, linestyle='-')
plot(x_x,y_x,color='red', linewidth = 0.1, linestyle='-') 


# plt.scatter(dfplottable['lon']*-1,dfplottable['lat'],c=dfplottable['depth'],cmap='RdBu')
# plt.savefig('SPRING_linearinterpol_sMAB_depth')
plt.show()

# %%
finaldepth = []; finallat = [];finallon = []
zi_listofarrays = []
for year in range(1977,2020):
    filename = 'casts_{}.mat'.format(year)
    file = scipy.io.loadmat(filename,squeeze_me=True)
    npfile = file['casts_{}'.format(year)] 
    lat_intermediate = []; lon_intermediate = []; p_intermediate = []; t_intermediate = []; yd_intermediate = []
    seasonyeardepth = []; seasonyeartemp = []; counterii = []   
    for i in range(len(npfile)):
        yd = npfile[i]['yd']
        p = npfile[i]['p']
        s = npfile[i]['s']
        t = npfile[i]['t']
        lon = npfile[i]['lon']
        lat = npfile[i]['lat']
        floordepth = npfile[i]['depth']
#         if yd > 334 and yd <= 365 or yd >= 0 and yd <= 59:
        if yd > 243 and yd <= 334:
            lat_intermediate.append(npfile[i]['lat'])
            lon_intermediate.append(npfile[i]['lon'])
            p_intermediate.append(npfile[i]['p'])
            t_intermediate.append(npfile[i]['t'])
            yd_intermediate.append(npfile[i]['yd'])   
    month_df = pd.DataFrame({'day': yd_intermediate,'lon': lon_intermediate,'lat': lat_intermediate, 'p': p_intermediate, 't': t_intermediate})
    newdf = pd.DataFrame({'lon': lon_intermediate,'lat': lat_intermediate})    
    for ii in range(len(month_df)):
        new = newdf.iloc[ii].values
        point = Point(new)
        if isinstance(month_df['p'].iloc[ii], int) or isinstance(month_df['p'].iloc[ii], float) or isinstance(month_df['t'].iloc[ii], int) or isinstance(month_df['t'].iloc[ii], float):
            pass
        elif polygon_x.contains(point) == True or polygon_y.contains(point) == True or polygon_t.contains(point) == True or polygon_w.contains(point) == True or polygon_v.contains(point) == True:
            pt_df = pd.DataFrame({'p': month_df['p'].iloc[ii],'t': month_df['t'].iloc[ii]}) 
            df_ptsnew = pt_df.dropna()
            df_final = pd.DataFrame(df_ptsnew.values)
            l=[i for i in df_final[0] if i<=6]
            if len(l) > 0:
                surfaceval = []
                numrange = []
                for iii in range(len(l)):
                    val = df_final[1][iii]
                    numrange.append(iii)
                    surfaceval.append(val)
            surfacevalmean = statistics.mean(surfaceval)
#             print(surfacevalmean)
#             print(ii)
#             print(lat,lon)
            tempfin = []
            pressurefin = []
            for iii in range(numrange[-1],len(df_final)):
                tempfin.append(df_final[1][iii])
                pressurefin.append(df_final[0][iii])
            d = {'temp': list(reversed(tempfin)), 'pressure': list(reversed(pressurefin))}
            dffin = pd.DataFrame(d)
#             pnew = []; allmixedcount = []
#             inconclusivecount = []
            for ix in range(len(dffin)):
                b = dffin.at[ix,'temp']
                if b <= (surfacevalmean + 0.2) and b >= (surfacevalmean - 0.2):
                    if dffin.at[ix,'pressure'] >= floordepth - 6:
                        seasonyeartemp.append(dffin.at[ix,'temp'])
                        seasonyeardepth.append(dffin.at[ix,'pressure'])
#                         print(i,ii,iii,ix)
#                         print(newdf.iloc[ii])
                        counterii.append(ii)
                    elif dffin.at[ix,'pressure'] == df_final[0].iloc[-1]:
                        pass
                    else:
#                         pnew.append(dffin.at[ix,'pressure'])
                        seasonyeartemp.append(dffin.at[ix,'temp'])
                        seasonyeardepth.append(dffin.at[ix,'pressure'])
                        np.array(seasonyeartemp)
                        np.array(seasonyeardepth)
#                         print(i,ii,iii,ix)
#                         print(newdf.iloc[ii])
                        counterii.append(ii)
                    break  
#     if len(seasonyeartemp) > 0:
#         print(counterii)
    inlat = []; inlon = []
    for timer in counterii:
#         print(newdf['lat'][timer])
        inlat.append(newdf['lat'][timer])
        inlon.append(newdf['lon'][timer])
#     dfplots = pd.DataFrame(list(zip(seasonyeardepth, inlat,inlon)),columns = ['depth','lat','lon'])
#     print('depth_',year,'=', seasonyeardepth)

    finaldepth.append(seasonyeardepth)
    finallat.append(inlat)
    finallon.append(inlon)
    
    flat_depth = [item for sublist in finaldepth for item in sublist]
    flat_lat = [item for sublist in finallat for item in sublist]
    flat_lon = [item for sublist in finallon for item in sublist]
    
#     print(len(flat_depth))
#     print(len(flat_lat))
#     print(len(flat_lon))
    
    flat_lon[:] = [x *-1 for x in flat_lon]
    
    name = 'dfplottablefull_{}'.format(year)
    
    name = pd.DataFrame(list(zip(flat_depth,flat_lon,flat_lat)),columns = ['depth','lon','lat'])
#     print('lat_',year,'=', inlat)
#     print('lon_',year,'=', inlon)
#     print(dfplots)
#         print('depth_',year,np.mean(seasonyeardepth))
    x = 'x_{}'.format(year)
    x = name['lon']
    y = 'y_{}'.format(year)
    y = name['lat']
    z = 'z_{}'.format(year)
    z = name['depth']
    
    xi = np.arange(-76,-65,0.25)
    yi = np.arange(35,46,0.25)
    xi,yi = np.meshgrid(xi,yi)
    
    
    zi = 'zi_{}'.format(year)
#     print(zi)
#     print(zi)
    zi = griddata((x,y),z,(xi,yi),method='linear')
    
    zi_listofarrays.append(zi)
#     zi += zi
#     print(zi)

# for i in range(1977, 2020):
    
#     ax = fig.add_subplot(111)
#     # plt.contourf(xi,yi,zi_1977to1982,np.arange(0,180,1))
#     plt.contourf(xi,yi,zi,np.arange(0,180,1))
#     # plt.contourf(xi,yi,zi,np.arange(0,100,5))
#     # plt.plot(x,y,'k.')
#     plt.xlabel('xi',fontsize=16)
#     plt.ylabel('yi',fontsize=16)
#     plt.show()

# %%
print(len(zi_listofarrays))
# Out:
# 43

# %%
print('yes')
# Out:
# yes

# %%
print(zi_listofarrays[0].shape)
# Out:
# (44, 44)

# %%
for i in range(len(zi_listofarrays)-1):
    b = zi_listofarrays[i] + zi_listofarrays[i+1]
    
print(len(zi_listofarrays))

meangrid = np.mean([zi_listofarrays[0]],axis=0)


# meangrid = np.mean([zi_listofarrays[1]+ zi_listofarrays[2]+ zi_listofarrays[3]+zi_listofarrays[4]+zi_listofarrays[5]+
#                   zi_listofarrays[6]+zi_listofarrays[7]+zi_listofarrays[8]+
#                   zi_listofarrays[9]+zi_listofarrays[10]+zi_listofarrays[11]+
#                   zi_listofarrays[12]+zi_listofarrays[13]+zi_listofarrays[14]+
#                   zi_listofarrays[15]+zi_listofarrays[16]+zi_listofarrays[17]+
#                   zi_listofarrays[18]+zi_listofarrays[19]+zi_listofarrays[20]+
#                   zi_listofarrays[21]+zi_listofarrays[22]+zi_listofarrays[23]+
#                   zi_listofarrays[24]+zi_listofarrays[25]+zi_listofarrays[26]+
#                   zi_listofarrays[27]+zi_listofarrays[28]+zi_listofarrays[29]+
#                   zi_listofarrays[30]+zi_listofarrays[31]+zi_listofarrays[32]+
#                   zi_listofarrays[33]+zi_listofarrays[34]+zi_listofarrays[35]+
#                   zi_listofarrays[36]+zi_listofarrays[37]+zi_listofarrays[38]+
#                   zi_listofarrays[39]+zi_listofarrays[40]+zi_listofarrays[41]+
#                   zi_listofarrays[42]],axis = 0)

# stdgrid = np.std([zi_listofarrays[12]+zi_listofarrays[13]+zi_listofarrays[14]+zi_listofarrays[40]+zi_listofarrays[41]+
#                   zi_listofarrays[42]],axis = 0)
# Out:
# 43

# %%
meangrid = np.mean([zi_listofarrays[22]],axis=0)

# %%
plt.figure(figsize=(12, 8))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_extent([-78, -65, 35.5, 44.5], ccrs.PlateCarree())

gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,linewidth=1, color='grey', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.ylabels_left = True
gl.ylabels_right = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER

# cf = plt.contourf(xi,yi,meangrid/40,cmap = 'ocean_r')
# cf = plt.contourf(xi,yi,meangrid,np.arange(0,340,20),cmap = 'ocean_r')
# cf = plt.contourf(xi,yi,meangrid,np.arange(0,300,20),cmap = 'ocean_r')
# cf = plt.contourf(xi,yi,meangrid,cmap = 'ocean_r')
cf = plt.contourf(xi,yi,meangrid,np.arange(0,190,10),cmap = 'ocean_r')



# plt.contour(xi, yi, meangridwinter, levels=5, linewidths=1,colors='white')

feature = cfeature.NaturalEarthFeature(name='coastline', category='physical',scale='50m',edgecolor='black', facecolor='dimgray')
ax.add_feature(feature,zorder=10)
cbar = plt.colorbar(cf, ax=ax)

plt.savefig('1999')
plt.show()

# %%
# newmeangridnew = np.nanmean([zi_listofarrays[0],zi_listofarrays[1],zi_listofarrays[2],zi_listofarrays[3],zi_listofarrays[4],
#                           zi_listofarrays[5],zi_listofarrays[6],zi_listofarrays[7],zi_listofarrays[8],
#                           zi_listofarrays[9],zi_listofarrays[10],zi_listofarrays[11],
#                           zi_listofarrays[12],zi_listofarrays[13],zi_listofarrays[14],
#                           zi_listofarrays[15],zi_listofarrays[16],zi_listofarrays[17],
#                           zi_listofarrays[18],zi_listofarrays[19],zi_listofarrays[20],
#                           zi_listofarrays[21],zi_listofarrays[22],zi_listofarrays[23],
#                           zi_listofarrays[24],zi_listofarrays[25],zi_listofarrays[26],
#                           zi_listofarrays[27],zi_listofarrays[28],zi_listofarrays[29],
#                           zi_listofarrays[30],zi_listofarrays[31],zi_listofarrays[32],
#                           zi_listofarrays[33],zi_listofarrays[34],zi_listofarrays[35],
#                           zi_listofarrays[36],zi_listofarrays[37],zi_listofarrays[38],
#                           zi_listofarrays[39],zi_listofarrays[40],zi_listofarrays[41],
#                           zi_listofarrays[42]],axis = 0)

newmeangridnew = np.nanmean([zi_listofarrays[0],zi_listofarrays[1],zi_listofarrays[2],zi_listofarrays[3],zi_listofarrays[4],
                          zi_listofarrays[5],zi_listofarrays[6],zi_listofarrays[7],zi_listofarrays[8],
                          zi_listofarrays[9],zi_listofarrays[10],zi_listofarrays[11],
                          zi_listofarrays[12],zi_listofarrays[13],zi_listofarrays[14],
                          zi_listofarrays[15],zi_listofarrays[16],zi_listofarrays[17],
                          zi_listofarrays[18],zi_listofarrays[19],zi_listofarrays[20],
                          zi_listofarrays[21],zi_listofarrays[22],zi_listofarrays[23],
                          zi_listofarrays[24],zi_listofarrays[25],zi_listofarrays[26],
                          zi_listofarrays[27],zi_listofarrays[28],zi_listofarrays[29],
                          zi_listofarrays[30],zi_listofarrays[31],zi_listofarrays[32],
                          zi_listofarrays[33],zi_listofarrays[34],zi_listofarrays[35],
                          zi_listofarrays[36],zi_listofarrays[37],zi_listofarrays[38],
                          zi_listofarrays[39],zi_listofarrays[40],zi_listofarrays[41]],axis = 0)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:28: RuntimeWarning: Mean of empty slice

# %%
newmeangridnew = np.nanmean([zi_listofarrays[0],zi_listofarrays[1],zi_listofarrays[2],zi_listofarrays[3],zi_listofarrays[4],
                          zi_listofarrays[5],zi_listofarrays[6],zi_listofarrays[7],zi_listofarrays[8],
                          zi_listofarrays[9],zi_listofarrays[10],zi_listofarrays[11],
                          zi_listofarrays[12],zi_listofarrays[13],zi_listofarrays[14],
                          zi_listofarrays[15],zi_listofarrays[16],zi_listofarrays[17],
                          zi_listofarrays[18],zi_listofarrays[19],zi_listofarrays[20],
                          zi_listofarrays[21],zi_listofarrays[22],zi_listofarrays[23],
                          zi_listofarrays[24],zi_listofarrays[25],zi_listofarrays[26],
                          zi_listofarrays[27],zi_listofarrays[28],zi_listofarrays[29],
                          zi_listofarrays[30],zi_listofarrays[31],zi_listofarrays[32],
                          zi_listofarrays[33],zi_listofarrays[34],zi_listofarrays[35],
                          zi_listofarrays[36],zi_listofarrays[37],zi_listofarrays[38],
                          zi_listofarrays[39],zi_listofarrays[40],zi_listofarrays[41],zi_listofarrays[42]],axis = 0)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: Mean of empty slice
#   del sys.path[0]

# %%
newmeangridnew = np.nanmean([zi_listofarrays[0],zi_listofarrays[1]],axis = 0)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: Mean of empty slice
#   """Entry point for launching an IPython kernel.

# %%
newstdgridnew = np.nanstd([zi_listofarrays[0],zi_listofarrays[1],zi_listofarrays[2],zi_listofarrays[3],zi_listofarrays[4],
                          zi_listofarrays[5],zi_listofarrays[6],zi_listofarrays[7],zi_listofarrays[8],
                          zi_listofarrays[9],zi_listofarrays[10],zi_listofarrays[11],
                          zi_listofarrays[12],zi_listofarrays[13],zi_listofarrays[14],
                          zi_listofarrays[15],zi_listofarrays[16],zi_listofarrays[17],
                          zi_listofarrays[18],zi_listofarrays[19],zi_listofarrays[20],
                          zi_listofarrays[21],zi_listofarrays[22],zi_listofarrays[23],
                          zi_listofarrays[24],zi_listofarrays[25],zi_listofarrays[26],
                          zi_listofarrays[27],zi_listofarrays[28],zi_listofarrays[29],
                          zi_listofarrays[30],zi_listofarrays[31],zi_listofarrays[32],
                          zi_listofarrays[33],zi_listofarrays[34],zi_listofarrays[35],
                          zi_listofarrays[36],zi_listofarrays[37],zi_listofarrays[38],
                          zi_listofarrays[39],zi_listofarrays[40],zi_listofarrays[41],
                          zi_listofarrays[42]],axis = 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-3659028ea156> in <module>
# ----> 1 newstdgridnew = np.nanstd([zi_listofarrays[0],zi_listofarrays[1],zi_listofarrays[2],zi_listofarrays[3],zi_listofarrays[4],
#       2                           zi_listofarrays[5],zi_listofarrays[6],zi_listofarrays[7],zi_listofarrays[8],
#       3                           zi_listofarrays[9],zi_listofarrays[10],zi_listofarrays[11],
#       4                           zi_listofarrays[12],zi_listofarrays[13],zi_listofarrays[14],
#       5                           zi_listofarrays[15],zi_listofarrays[16],zi_listofarrays[17],
#
# NameError: name 'zi_listofarrays' is not defined

# %%
newstdgridnew = np.nanstd([zi_listofarrays[0],zi_listofarrays[1],zi_listofarrays[2],zi_listofarrays[3],zi_listofarrays[4],
                          zi_listofarrays[5],zi_listofarrays[6],zi_listofarrays[7],zi_listofarrays[8],
                          zi_listofarrays[9],zi_listofarrays[10],zi_listofarrays[11],
                          zi_listofarrays[12],zi_listofarrays[13],zi_listofarrays[14],
                          zi_listofarrays[15],zi_listofarrays[16],zi_listofarrays[17],
                          zi_listofarrays[18],zi_listofarrays[19],zi_listofarrays[20],
                          zi_listofarrays[21],zi_listofarrays[22],zi_listofarrays[23],
                          zi_listofarrays[24],zi_listofarrays[25],zi_listofarrays[26],
                          zi_listofarrays[27],zi_listofarrays[28],zi_listofarrays[29],
                          zi_listofarrays[30],zi_listofarrays[31],zi_listofarrays[32],
                          zi_listofarrays[33],zi_listofarrays[34],zi_listofarrays[35],
                          zi_listofarrays[36],zi_listofarrays[37],zi_listofarrays[38],
                          zi_listofarrays[39],zi_listofarrays[40],zi_listofarrays[41]],axis = 0)

# %%
newmeangrid = np.mean([np.mean([zi_listofarrays[1]],axis=0),np.mean([zi_listofarrays[16]],axis=0),np.mean([zi_listofarrays[35]],axis=0)],axis=0)

# %%
print(newmeangrid.shape)
# Out:
# (22, 22)

# %%
from matplotlib.pyplot import * ; import cartopy.feature as cfeature

plt.figure(figsize=(12, 8))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_extent([-78, -65, 35.5, 44.5], ccrs.PlateCarree())

gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,linewidth=1, color='grey', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.ylabels_left = True
gl.ylabels_right = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER

# cf = plt.contourf(xi,yi,meangrid/40,cmap = 'ocean_r')
# cf = plt.contourf(xi,yi,meangrid,np.arange(0,340,20),cmap = 'ocean_r')
# cf = plt.contourf(xi,yi,newmeangridnew,np.arange(0,300,20),cmap = 'ocean_r')
# cf = plt.contourf(xi,yi,newmeangridnew,cmap = 'ocean_r')

# cf = plt.contourf(xi,yi,newmeangridnew,cmap = 'ocean_r')
# cf = plt.contourf(xi,yi,newmeangridnew,np.arange(0,150,10),cmap = 'ocean_r')
# cf = plt.contourf(xi,yi,newstdgridnew,np.arange(0,150,10),cmap = 'ocean_r')
cf = plt.contourf(xi,yi,newstdgridnew,np.arange(0,65,5),cmap = 'ocean_r')
# cf = plt.contourf(xi,yi,newstdgridnew,np.arange(0,370,10),cmap = 'ocean_r')
# cf = plt.contourf(xi,yi,newstdgridnew,np.arange(0,170,10),cmap = 'ocean_r')

# plt.contour(xi, yi, newmeangridnew, levels=5, linewidths=1,colors='white')

feature = cfeature.NaturalEarthFeature(name='coastline', category='physical',scale='50m',edgecolor='black', facecolor='dimgray')
ax.add_feature(feature,zorder=10)
cbar = plt.colorbar(cf, ax=ax)

plt.savefig('SUMMER_std_depth')

plt.show()

# %%
newmeangridnewearly = np.nanmean([zi_listofarrays[0],zi_listofarrays[1],zi_listofarrays[2],zi_listofarrays[3],zi_listofarrays[4],
                          zi_listofarrays[5],zi_listofarrays[6],zi_listofarrays[7],zi_listofarrays[8],
                          zi_listofarrays[9]],axis = 0)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: Mean of empty slice
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
newmeangridnewlate = np.nanmean([zi_listofarrays[33],zi_listofarrays[34],zi_listofarrays[35],
                          zi_listofarrays[36],zi_listofarrays[37],zi_listofarrays[38],
                          zi_listofarrays[39],zi_listofarrays[40],zi_listofarrays[41],
                          zi_listofarrays[42]],axis = 0)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: Mean of empty slice
#   after removing the cwd from sys.path.

# %%
newmeangridnewlate = np.nanmean([zi_listofarrays[32],zi_listofarrays[33],zi_listofarrays[34],zi_listofarrays[35],
                          zi_listofarrays[36],zi_listofarrays[37],zi_listofarrays[38],
                          zi_listofarrays[39],zi_listofarrays[40],zi_listofarrays[41]],axis = 0)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: Mean of empty slice
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
newmeangridnewdiff = newmeangridnewlate - newmeangridnewearly

# %%
print(newmeangridnewdiff.shape)
# Out:
# (44, 44)

# %%
from matplotlib.pyplot import * ; import cartopy.feature as cfeature

plt.figure(figsize=(12, 8))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_extent([-78, -65, 35.5, 44.5], ccrs.PlateCarree())

gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,linewidth=1, color='grey', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.ylabels_left = True
gl.ylabels_right = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER

# cf = plt.contourf(xi,yi,meangrid/40,cmap = 'ocean_r')
# cf = plt.contourf(xi,yi,meangrid,np.arange(0,340,20),cmap = 'ocean_r')
# cf = plt.contourf(xi,yi,newmeangridnew,np.arange(0,300,20),cmap = 'ocean_r')
# cf = plt.contourf(xi,yi,newmeangridnew,cmap = 'ocean_r')

# cf = plt.contourf(xi,yi,newmeangridnew,cmap = 'ocean_r')
# cf = plt.contourf(xi,yi,newmeangridnew,np.arange(0,150,10),cmap = 'ocean_r')
# cf = plt.contourf(xi,yi,newstdgridnew,np.arange(0,150,10),cmap = 'ocean_r')
# cf = plt.contourf(xi,yi,newmeangridnewdiff,np.arange(-120,130,10), cmap = 'seismic')
# cf = plt.contourf(xi,yi,newmeangridnewdiff,cmap = 'seismic')
cf = plt.contourf(xi,yi,newmeangridnewdiff,np.arange(-100,105,5), cmap = 'seismic')



# cf = plt.contourf(newmeangridnewdiff,vmin = -140, vmax = 140, cmap = 'seismic')


# cf = plt.contourf(xi,yi,newmeangridnewdiff, np.arange(-140,140,10),vmin = -140, vmax = 140, cmap = 'seismic')


# plt.contour(xi, yi, newmeangridnew, levels=5, linewidths=1,colors='white')

feature = cfeature.NaturalEarthFeature(name='coastline', category='physical',scale='50m',edgecolor='black', facecolor='dimgray')
ax.add_feature(feature,zorder=10)
cbar = plt.colorbar(cf,ax=ax)
plt.savefig('SUMMER_lastdecademean_minus_firstdecademean')

plt.show()

# %%
print(meangrid.shape)
# Out:
# (22, 22)

# %%
meangrid = np.mean()

# %%
meangridsummer = np.mean([zi_1977 + zi_1978], axis=0)

# stdgridsummer = np.std([zi_1977to1982, zi_1983to1988 + zi_1989to1994 + zi_1995to2000 + zi_2001to2006 + zi_2007to2012 + zi_2013to2019], axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-591-3d22218f5945> in <module>
# ----> 1 meangridsummer = np.mean([zi_1977 + zi_1978], axis=0)
#       2
#       3 # stdgridsummer = np.std([zi_1977to1982, zi_1983to1988 + zi_1989to1994 + zi_1995to2000 + zi_2001to2006 + zi_2007to2012 + zi_2013to2019], axis=0)
#
# NameError: name 'zi_1977' is not defined

# %%
# print(finaldepth)
flat_depth = [item for sublist in finaldepth for item in sublist]
flat_lat = [item for sublist in finallat for item in sublist]
flat_lon = [item for sublist in finallon for item in sublist]

# %%
print(len(flat_depth))
print(len(flat_lat))
print(len(flat_lon))
# Out:
# 24
# 24
# 24

# %%
flat_lon[:] = [x *-1 for x in flat_lon]

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import griddata

# data coordinates and values
x_1977to1982 = dfplottablefull_1977to1982['lon']
y_1977to1982 = dfplottablefull_1977to1982['lat']
z_1977to1982 = dfplottablefull_1977to1982['depth']

x_1983to1988 = dfplottablefull_1983to1988['lon']
y_1983to1988 = dfplottablefull_1983to1988['lat']
z_1983to1988 = dfplottablefull_1983to1988['depth']

x_1989to1994 = dfplottablefull_1989to1994['lon']
y_1989to1994 = dfplottablefull_1989to1994['lat']
z_1989to1994 = dfplottablefull_1989to1994['depth']

x_1995to2000 = dfplottablefull_1995to2000['lon']
y_1995to2000 = dfplottablefull_1995to2000['lat']
z_1995to2000 = dfplottablefull_1995to2000['depth']

x_2001to2006 = dfplottablefull_2001to2006['lon']
y_2001to2006 = dfplottablefull_2001to2006['lat']
z_2001to2006 = dfplottablefull_2001to2006['depth']

x_2007to2012 = dfplottablefull_2007to2012['lon']
y_2007to2012 = dfplottablefull_2007to2012['lat']
z_2007to2012 = dfplottablefull_2007to2012['depth']

x_2013to2019 = dfplottablefull_2013to2019['lon']
y_2013to2019 = dfplottablefull_2013to2019['lat']
z_2013to2019 = dfplottablefull_2013to2019['depth']

# target grid to interpolate to
# xi = np.arange(-70.8,-67.8,0.05)
xi = np.arange(-76,-65,0.25)
yi = np.arange(35,46,0.25)
# xi = yi = np.arange(60,100,5)
xi,yi = np.meshgrid(xi,yi)

# interpolate
zi_1977to1982 = griddata((x_1977to1982,y_1977to1982),z_1977to1982,(xi,yi),method='linear')
zi_1983to1988 = griddata((x_1983to1988,y_1983to1988),z_1983to1988,(xi,yi),method='linear')
zi_1989to1994 = griddata((x_1989to1994,y_1989to1994),z_1989to1994,(xi,yi),method='linear')
zi_1995to2000 = griddata((x_1995to2000,y_1995to2000),z_1995to2000,(xi,yi),method='linear')
zi_2001to2006 = griddata((x_2001to2006,y_2001to2006),z_2001to2006,(xi,yi),method='linear')
zi_2007to2012 = griddata((x_2007to2012,y_2007to2012),z_2007to2012,(xi,yi),method='linear')
zi_2013to2019 = griddata((x_2013to2019,y_2013to2019),z_2013to2019,(xi,yi),method='linear')

zi_1977to1982f = np.mean(zi_1977to1982)

# mask out the field
# zi[mask] = np.nan

# fig = plt.figure()
ax = fig.add_subplot(111)
# plt.contourf(xi,yi,zi_1977to1982,np.arange(0,180,1))
plt.contourf(xi,yi,zi_1995to2000,np.arange(0,180,1))
# plt.contourf(xi,yi,zi,np.arange(0,100,5))
# plt.plot(x,y,'k.')
plt.xlabel('xi',fontsize=16)
plt.ylabel('yi',fontsize=16)
plt.show()

# %%
dfplottablefull_1977 = pd.DataFrame(list(zip(flat_depth,flat_lon,flat_lat)),columns = ['depth','lon','lat'])

# %%
dfplottablefull_1978 = pd.DataFrame(list(zip(flat_depth,flat_lon,flat_lat)),columns = ['depth','lon','lat'])

# %%
dfplottablefull_1979 = pd.DataFrame(list(zip(flat_depth,flat_lon,flat_lat)),columns = ['depth','lon','lat'])

# %%
dfplottablefull_1980 = pd.DataFrame(list(zip(flat_depth,flat_lon,flat_lat)),columns = ['depth','lon','lat'])

# %%
dfplottablefull_1981 = pd.DataFrame(list(zip(flat_depth,flat_lon,flat_lat)),columns = ['depth','lon','lat'])

# %%
print(dfplottablefull_1977)
# Out:
#     depth      lon      lat
# 0    30.0 -68.6167  40.4667
# 1    30.0 -68.7333  40.8500
# 2    30.0 -68.7000  41.3333
# 3    75.0 -68.8833  41.6167
# 4    72.0 -69.1500  41.6500
# 5    73.0 -69.1167  41.3667
# 6    50.0 -69.1000  41.0667
# 7    10.0 -69.1167  40.9167
# 8    70.0 -69.0833  40.6500
# 9    30.0 -69.0500  40.4167
# 10   20.0 -69.5667  40.1333
# 11   10.0 -69.7000  40.4000
# 12   30.0 -70.1833  40.6833
# 13   15.0 -70.5833  40.7000
# 14   20.0 -70.4167  40.2167
# 15   20.0 -72.4667  40.5667
# 16   20.0 -72.1333  40.8167
# 17   50.0 -71.1667  40.9667
# 18    5.0 -71.0333  40.6833
# 19   30.0 -70.8500  40.3500
# 20   15.0 -70.7667  40.1667
# 21   50.0 -71.6000  40.5167
# 22   50.0 -71.9500  40.2167
# 23   40.0 -72.4667  40.5667

# %%
print(dfplottablefull_1977to1982)
# Out:
#      depth      lon      lat
# 0     30.0 -68.6167  40.4667
# 1     30.0 -68.7333  40.8500
# 2     30.0 -68.7000  41.3333
# 3     75.0 -68.8833  41.6167
# 4     72.0 -69.1500  41.6500
# ..     ...      ...      ...
# 402   70.0 -74.2333  37.9167
# 403   31.0 -74.5167  38.2333
# 404   10.0 -74.8000  38.5833
# 405   10.0 -75.2833  37.8000
# 406   44.0 -74.3667  37.6333
#
# [407 rows x 3 columns]

# %%
dfplottablefull_1977to1982 = pd.DataFrame(list(zip(flat_depth,flat_lon,flat_lat)),columns = ['depth','lon','lat'])

# %%
dfplottablefull_1983to1988 = pd.DataFrame(list(zip(flat_depth,flat_lon,flat_lat)),columns = ['depth','lon','lat'])

# %%
dfplottablefull_1989to1994 = pd.DataFrame(list(zip(flat_depth,flat_lon,flat_lat)),columns = ['depth','lon','lat'])

# %%
dfplottablefull_1995to2000 = pd.DataFrame(list(zip(flat_depth,flat_lon,flat_lat)),columns = ['depth','lon','lat'])

# %%
dfplottablefull_2001to2006 = pd.DataFrame(list(zip(flat_depth,flat_lon,flat_lat)),columns = ['depth','lon','lat'])

# %%
dfplottablefull_2007to2012 = pd.DataFrame(list(zip(flat_depth,flat_lon,flat_lat)),columns = ['depth','lon','lat'])

# %%
dfplottablefull_2013to2019 = pd.DataFrame(list(zip(flat_depth,flat_lon,flat_lat)),columns = ['depth','lon','lat'])

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import griddata

# data coordinates and values
x_1977to1982 = dfplottablefull_1977to1982['lon']
y_1977to1982 = dfplottablefull_1977to1982['lat']
z_1977to1982 = dfplottablefull_1977to1982['depth']

x_1983to1988 = dfplottablefull_1983to1988['lon']
y_1983to1988 = dfplottablefull_1983to1988['lat']
z_1983to1988 = dfplottablefull_1983to1988['depth']

x_1989to1994 = dfplottablefull_1989to1994['lon']
y_1989to1994 = dfplottablefull_1989to1994['lat']
z_1989to1994 = dfplottablefull_1989to1994['depth']

x_1995to2000 = dfplottablefull_1995to2000['lon']
y_1995to2000 = dfplottablefull_1995to2000['lat']
z_1995to2000 = dfplottablefull_1995to2000['depth']

x_2001to2006 = dfplottablefull_2001to2006['lon']
y_2001to2006 = dfplottablefull_2001to2006['lat']
z_2001to2006 = dfplottablefull_2001to2006['depth']

x_2007to2012 = dfplottablefull_2007to2012['lon']
y_2007to2012 = dfplottablefull_2007to2012['lat']
z_2007to2012 = dfplottablefull_2007to2012['depth']

x_2013to2019 = dfplottablefull_2013to2019['lon']
y_2013to2019 = dfplottablefull_2013to2019['lat']
z_2013to2019 = dfplottablefull_2013to2019['depth']

# target grid to interpolate to
# xi = np.arange(-70.8,-67.8,0.05)
xi = np.arange(-76,-65,0.25)
yi = np.arange(35,46,0.25)
# xi = yi = np.arange(60,100,5)
xi,yi = np.meshgrid(xi,yi)

# interpolate
zi_1977to1982 = griddata((x_1977to1982,y_1977to1982),z_1977to1982,(xi,yi),method='linear')
zi_1983to1988 = griddata((x_1983to1988,y_1983to1988),z_1983to1988,(xi,yi),method='linear')
zi_1989to1994 = griddata((x_1989to1994,y_1989to1994),z_1989to1994,(xi,yi),method='linear')
zi_1995to2000 = griddata((x_1995to2000,y_1995to2000),z_1995to2000,(xi,yi),method='linear')
zi_2001to2006 = griddata((x_2001to2006,y_2001to2006),z_2001to2006,(xi,yi),method='linear')
zi_2007to2012 = griddata((x_2007to2012,y_2007to2012),z_2007to2012,(xi,yi),method='linear')
zi_2013to2019 = griddata((x_2013to2019,y_2013to2019),z_2013to2019,(xi,yi),method='linear')

zi_1977to1982f = np.mean(zi_1977to1982)

# mask out the field
# zi[mask] = np.nan

# fig = plt.figure()
ax = fig.add_subplot(111)
# plt.contourf(xi,yi,zi_1977to1982,np.arange(0,180,1))
plt.contourf(xi,yi,zi_1995to2000,np.arange(0,180,1))
# plt.contourf(xi,yi,zi,np.arange(0,100,5))
# plt.plot(x,y,'k.')
plt.xlabel('xi',fontsize=16)
plt.ylabel('yi',fontsize=16)
plt.show()
# Out:
# ()

# %% [markdown]
# ### SUMMER

# %%
meangridsummer = np.mean([zi_1977to1982, zi_1983to1988 + zi_1989to1994 + zi_1995to2000 + zi_2001to2006 + zi_2007to2012 + zi_2013to2019], axis=0)

stdgridsummer = np.std([zi_1977to1982, zi_1983to1988 + zi_1989to1994 + zi_1995to2000 + zi_2001to2006 + zi_2007to2012 + zi_2013to2019], axis=0)

# %%
# newmeangridsummer = meangridsummer /5
# meangridsummer.shape
print(newmeangridsummer.shape)
# Out:
# (44, 44)

# %% [markdown]
# ### FALL

# %%
meangridfall = np.mean([zi_1977to1982, zi_1983to1988 + zi_1989to1994 + zi_1995to2000 + zi_2001to2006 + zi_2007to2012 + zi_2013to2019], axis=0)

stdgridfall = np.std([zi_1977to1982, zi_1983to1988 + zi_1989to1994 + zi_1995to2000 + zi_2001to2006 + zi_2007to2012 + zi_2013to2019], axis=0)

# %% [markdown]
# ### WINTER

# %%
meangridwinter = np.mean([zi_1977to1982, zi_1983to1988 + zi_1989to1994 + zi_1995to2000 + zi_2001to2006 + zi_2007to2012 + zi_2013to2019], axis=0)

stdgridwinter = np.std([zi_1977to1982, zi_1983to1988 + zi_1989to1994 + zi_1995to2000 + zi_2001to2006 + zi_2007to2012 + zi_2013to2019], axis=0)

# %% [markdown]
# ### SPRING

# %%
meangridspring = np.mean([zi_1977to1982, zi_1983to1988 + zi_1989to1994 + zi_1995to2000 + zi_2001to2006 + zi_2007to2012 + zi_2013to2019], axis=0)

stdgridspring = np.std([zi_1977to1982, zi_1983to1988 + zi_1989to1994 + zi_1995to2000 + zi_2001to2006 + zi_2007to2012 + zi_2013to2019], axis=0)

# %%
from matplotlib.pyplot import * ; import cartopy.feature as cfeature

plt.figure(figsize=(12, 8))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_extent([-78, -65, 35.5, 44.5], ccrs.PlateCarree())
# ax.set_extent([-76, -72, 35.5, 40.5], ccrs.PlateCarree())
# feature = cfeature.NaturalEarthFeature(name='coastline', category='physical',scale='50m',edgecolor='black', facecolor='grey')

# ax.add_feature(feature)
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,linewidth=1, color='grey', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.ylabels_left = True
gl.ylabels_right = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
# plt.contourf(xi,yi,meangrid,np.arange(0,200,20))


# cf = plt.contourf(xi,yi,meangrid,np.arange(0,750,50),cmap = 'ocean_r')
cf = plt.contourf(xi,yi,meangrid,cmap = 'ocean_r')


# cf = plt.contourf(xi,yi,zi,np.arange(0,200,10),cmap = 'YlGnBu')
# plt.contour(xi, yi, meangridwinter, levels=5, linewidths=1,colors='white')


feature = cfeature.NaturalEarthFeature(name='coastline', category='physical',scale='50m',edgecolor='black', facecolor='dimgray')
ax.add_feature(feature,zorder=10)

cbar = plt.colorbar(cf, ax=ax)

# plt.scatter(dfplottable['lon']*-1,dfplottable['lat'],c=dfplottable['depth'],cmap='RdBu')
plt.savefig('SPRINGmeanval_MLD_fullregion_unmasked')
plt.show()

# %%
from matplotlib.pyplot import * ; import cartopy.feature as cfeature

plt.figure(figsize=(12, 8))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_extent([-78, -65, 35.5, 44.5], ccrs.PlateCarree())
# ax.set_extent([-76, -72, 35.5, 40.5], ccrs.PlateCarree())
# feature = cfeature.NaturalEarthFeature(name='coastline', category='physical',scale='50m',edgecolor='black', facecolor='grey')

# ax.add_feature(feature)
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,linewidth=1, color='grey', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.ylabels_left = True
gl.ylabels_right = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
# plt.contourf(xi,yi,stdgrid,np.arange(0,200,20))


# cf = plt.contourf(xi,yi,stdgrid,np.arange(0,800,50),cmap = 'ocean_r')
cf = plt.contourf(xi,yi,stdgridwinter,cmap = 'ocean_r')
plt.contour(xi, yi, stdgridwinter, levels=5, linewidths=1,colors='white')



# cf = plt.contourf(xi,yi,zi,np.arange(0,200,10),cmap = 'YlGnBu')
# plt.contour(xi, yi, stdgrid, levels=8, linewidths=1,colors='white')


feature = cfeature.NaturalEarthFeature(name='coastline', category='physical',scale='50m',edgecolor='black', facecolor='dimgray')
ax.add_feature(feature,zorder = 10)


cbar = plt.colorbar(cf, ax=ax)

# plt.scatter(dfplottable['lon']*-1,dfplottable['lat'],c=dfplottable['depth'],cmap='RdBu')
plt.savefig('SPRINGstandarddev_MLD_fullregion_unmasked')
plt.show()
