# %%
import matplotlib.pyplot as plt; import numpy as np; import netCDF4; from netCDF4 import Dataset
import pandas as pd; import numpy.ma as ma; import time as timeit; import os; import math; import re
import itertools; import scipy.io; import mat73; import collections
import cartopy; import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from matplotlib.ticker import FuncFormatter
from matplotlib.ticker import AutoMinorLocator; from matplotlib.ticker import FixedLocator
from shapely.geometry import Point; from shapely.geometry.polygon import Polygon
# %matplotlib inline
import statistics; import xarray as xr; from scipy.interpolate import griddata
from matplotlib.path import Path; from numpy import nan; import re; import gsw

# %%
w = '  40.00   69.50\n  40.30   68.00\n  40.40   67.50\n  40.60   67.00\n  40.80   66.50\n  41.45   66.00\n  41.80   65.70\n  42.10   66.00\n  42.10   67.00\n  42.10   67.50\n  41.80   68.00\n  41.10   69.00\n  41.00   69.50\n  40.00   69.50\n'
output1w = w.split('\n')
neww = [] 
for string in output1w:
    output2w = string.split(' ')
    neww.append(output2w)
neww = [['', '', '40.00', '', '', '69.50'], ['', '', '40.30', '', '', '68.00'], ['', '', '40.40', '', '', '67.50'], ['', '', '40.60', '', '', '67.00'], ['', '', '40.80', '', '', '66.50'], ['', '', '41.45', '', '', '66.00'], ['', '', '41.80', '', '', '65.70'], ['', '', '42.10', '', '', '66.00'], ['', '', '42.10', '', '', '67.00'], ['', '', '42.10', '', '', '67.50'], ['', '', '41.80', '', '', '68.00'], ['', '', '41.10', '', '', '69.00'], ['', '', '41.00', '', '', '69.50'], ['', '', '40.00', '', '', '69.50']]
lon_w = []; lat_w = []
for i in range(14): 
    w1 = neww[i][2]
    lat_w.append(w1)
    w3 = neww[i][5]
    lon_w.append(w3)
lonlist_w = [float(i) for i in lon_w]; latlist_w = [float(i) for i in lat_w]
lonlist_wneg = [float(i)*-1 for i in lon_w]
df_w = pd.DataFrame({'lon': lonlist_w, 'lat': latlist_w,})
df_w_plottable = pd.DataFrame({'lon': lonlist_wneg, 'lat': latlist_w,})

lonlist_w_plot = [float(i)*-1 for i in lon_w]; latlist_w = [float(i) for i in lat_w]
df_w_plot = pd.DataFrame({'lon': lonlist_w_plot, 'lat': latlist_w,})
x_w = df_w_plot['lon']; y_w = df_w_plot['lat']

# %%
polygon_w = Polygon(df_w.values)
print(polygon_w)
# Out:
# POLYGON ((69.5 40, 68 40.3, 67.5 40.4, 67 40.6, 66.5 40.8, 66 41.45, 65.7 41.8, 66 42.1, 67 42.1, 67.5 42.1, 68 41.8, 69 41.1, 69.5 41, 69.5 40))

# %%
v = '  37.00   76.00\n  36.00   75.50\n  35.50   75.00\n  36.00   74.75\n  37.40   74.50\n  39.50   72.00\n  40.50   74.00\n  39.40   74.25\n  37.00   76.00\n'
output1v = v.split('\n')
newv = [] 
for string in output1v:
    output2v = string.split(' ')
    newv.append(output2v)
newv = [['', '', '37.00', '', '', '76.00'], ['', '', '36.00', '', '', '75.50'], ['', '', '35.50', '', '', '75.00'], ['', '', '36.00', '', '', '74.75'], ['', '', '37.40', '', '', '74.50'], ['', '', '39.50', '', '', '72.00'], ['', '', '40.50', '', '', '74.00'], ['', '', '39.40', '', '', '74.25'], ['', '', '37.00', '', '', '76.00']]
lon_v = []; lat_v = []
for i in range(9): 
    v1 = newv[i][2]
    lat_v.append(v1)
    v3 = newv[i][5]
    lon_v.append(v3)
lonlist_v = [float(i) for i in lon_v]; latlist_v = [float(i) for i in lat_v]
df_v = pd.DataFrame({'lon': lonlist_v, 'lat': latlist_v,})
lonlist_v_plot = [float(i)*-1 for i in lon_v]; latlist_v = [float(i) for i in lat_v]
df_v_plot = pd.DataFrame({'lon': lonlist_v_plot, 'lat': latlist_v,})
x_v = df_v_plot['lon']; y_v = df_v_plot['lat']

lonlist_vneg = [float(i)*-1 for i in lon_v]
df_v_plottable = pd.DataFrame({'lon': lonlist_vneg, 'lat': latlist_v,})

# %%
polygon_v = Polygon(df_v.values.tolist())
print(polygon_v)
# Out:
# POLYGON ((76 37, 75.5 36, 75 35.5, 74.75 36, 74.5 37.4, 72 39.5, 74 40.5, 74.25 39.4, 76 37))

# %%
x = '  40.50   74.00\n  39.50   72.00\n  40.00   71.40\n  40.00   69.50\n  41.00   69.50\n  41.10   70.00\n  41.00   72.00\n  40.50   74.00\n'
output1x = x.split('\n')
newx = [] 
for string in output1x:
    output2x = string.split(' ')
    newx.append(output2x)
newx = [['', '', '40.50', '', '', '74.00'], ['', '', '39.50', '', '', '72.00'], ['', '', '40.00', '', '', '71.40'], ['', '', '40.00', '', '', '69.50'], ['', '', '41.00', '', '', '69.50'], ['', '', '41.10', '', '', '70.00'], ['', '', '41.00', '', '', '72.00'], ['', '', '40.50', '', '', '74.00']]
lon_x = []; lat_x = []
for i in range(8): 
    x1 = newx[i][2]
    lat_x.append(x1)
    x3 = newx[i][5]
    lon_x.append(x3)
lonlist_x = [float(i) for i in lon_x]; latlist_x = [float(i) for i in lat_x]
df_x = pd.DataFrame({'lon': lonlist_x, 'lat': latlist_x,})
lonlist_x_plot = [float(i)*-1 for i in lon_x]; latlist_x = [float(i) for i in lat_x]
df_x_plot = pd.DataFrame({'lon': lonlist_x_plot, 'lat': latlist_x,})
x_x = df_x_plot['lon']; y_x = df_x_plot['lat']

lonlist_xneg = [float(i)*-1 for i in lon_x]
df_x_plottable = pd.DataFrame({'lon': lonlist_xneg, 'lat': latlist_x,})

# %%
polygon_x = Polygon(df_x.values.tolist())
print(polygon_x)
# Out:
# POLYGON ((74 40.5, 72 39.5, 71.40000000000001 40, 69.5 40, 69.5 41, 70 41.1, 72 41, 74 40.5))

# %%
y = '  41.80   68.00\n  42.10   67.50\n  42.10   67.00\n  42.10   66.00\n  43.00   66.00\n  44.20   66.50\n  44.20   67.00\n  44.20   68.00\n  41.80   68.00\n'
output1y = y.split('\n')
newy = [] 
for string in output1y:
    output2y = string.split(' ')
    newy.append(output2y)
newy = [['', '', '41.80', '', '', '68.00'], ['', '', '42.10', '', '', '67.50'], ['', '', '42.10', '', '', '67.00'], ['', '', '42.10', '', '', '66.00'], ['', '', '43.00', '', '', '66.00'], ['', '', '44.20', '', '', '66.50'], ['', '', '44.20', '', '', '67.00'], ['', '', '44.20', '', '', '68.00'], ['', '', '41.80', '', '', '68.00']]
lon_y = []; lat_y = []
for i in range(9): 
    y1 = newy[i][2]
    lat_y.append(y1)
    y3 = newy[i][5]
    lon_y.append(y3)
lonlist_y = [float(i) for i in lon_y]; latlist_y = [float(i) for i in lat_y]
df_y = pd.DataFrame({'lon': lonlist_y, 'lat': latlist_y,})
lonlist_y_plot = [float(i)*-1 for i in lon_y]; latlist_y = [float(i) for i in lat_y]
df_y_plot = pd.DataFrame({'lon': lonlist_y_plot, 'lat': latlist_y,})
x_y = df_y_plot['lon']; y_y = df_y_plot['lat']

lonlist_yneg = [float(i)*-1 for i in lon_y]
df_y_plottable = pd.DataFrame({'lon': lonlist_yneg, 'lat': latlist_y,})

# %%
polygon_y = Polygon(df_y.values)
print(polygon_y)
# Out:
# POLYGON ((68 41.8, 67.5 42.1, 67 42.1, 66 42.1, 66 43, 66.5 44.2, 67 44.2, 68 44.2, 68 41.8))

# %%
t = '  42.20   70.50\n  42.00   70.00\n  41.10   69.00\n  41.80   68.00\n  44.20   68.00\n  43.90   69.00\n  43.70   70.00\n  43.00   70.50\n  42.20   70.50'
output1t = t.split('\n')
newt = [] 
for string in output1t:
    output2t = string.split(' ')
    newt.append(output2t)
lon_t = []; lat_t = []
for i in range(9): 
    t1 = newt[i][2]
    lat_t.append(t1)
    t3 = newt[i][5]
    lon_t.append(t3)
lonlist_t = [float(i) for i in lon_t]; latlist_t = [float(i) for i in lat_t]
df_t = pd.DataFrame({'lon': lonlist_t, 'lat': latlist_t,})
lonlist_t_plot = [float(i)*-1 for i in lon_t]; latlist_t = [float(i) for i in lat_t]
df_t_plot = pd.DataFrame({'lon': lonlist_t_plot, 'lat': latlist_t,})
x_t = df_t_plot['lon']; y_t = df_t_plot['lat']

lonlist_tneg = [float(i)*-1 for i in lon_t]
df_t_plottable = pd.DataFrame({'lon': lonlist_tneg, 'lat': latlist_t,})

# %%
polygon_t = Polygon(df_t.values)
print(polygon_t)
# Out:
# POLYGON ((70.5 42.2, 70 42, 69 41.1, 68 41.8, 68 44.2, 69 43.9, 70 43.7, 70.5 43, 70.5 42.2))

# %%
fname ='surf-temp-global-reanalysis-phy-001-030-daily_1598019941052.nc'

# %%
DS=xr.open_dataset(fname)

# %%
print(DS)
# Out:
# <xarray.Dataset>
# Dimensions:    (depth: 1, latitude: 133, longitude: 181, time: 9490)
# Coordinates:
#   * depth      (depth) float32 0.494025
#   * latitude   (latitude) float32 35.0 35.083332 35.166668 ... 45.916668 46.0
#   * time       (time) datetime64[ns] 1993-01-01T12:00:00 ... 2018-12-25T12:00:00
#   * longitude  (longitude) float32 -78.0 -77.916664 ... -63.083332 -63.0
# Data variables:
#     thetao     (time, depth, latitude, longitude) float32 ...
# Attributes:
#     title:                              daily mean fields from Global Ocean P...
#     easting:                            longitude
#     northing:                           latitude
#     history:                            2019/04/04 11:59:50 MERCATOR OCEAN Ne...
#     source:                             MERCATOR GLORYS12V1
#     institution:                        MERCATOR OCEAN
#     references:                         http://www.mercator-ocean.fr
#     comment:                            CMEMS product
#     Conventions:                        CF-1.4
#     domain_name:                        GL12
#     FROM_ORIGINAL_FILE__field_type:     mean
#     field_date:                         2018-12-25 00:00:00
#     field_julian_date:                  25195.0
#     julian_day_unit:                    days since 1950-01-01 00:00:00
#     bulletin_date:                      2018-12-26 00:00:00
#     bulletin_type:                      operational
#     FROM_ORIGINAL_FILE__longitude_min:  -180.0
#     FROM_ORIGINAL_FILE__longitude_max:  179.91667
#     FROM_ORIGINAL_FILE__latitude_min:   -80.0
#     FROM_ORIGINAL_FILE__latitude_max:   90.0
#     z_min:                              0.494025
#     z_max:                              5727.917
#     forecast_range:                     6-day_forecast
#     forecast_type:                      hindcast
#     _CoordSysBuilder:                   ucar.nc2.dataset.conv.CF1Convention

# %%
print(DS['latitude'])
# Out:
# <xarray.DataArray 'latitude' (latitude: 133)>
# array([35.      , 35.083332, 35.166668, 35.25    , 35.333332, 35.416668,
#        35.5     , 35.583332, 35.666668, 35.75    , 35.833332, 35.916668,
#        36.      , 36.083332, 36.166668, 36.25    , 36.333332, 36.416668,
#        36.5     , 36.583332, 36.666668, 36.75    , 36.833332, 36.916668,
#        37.      , 37.083332, 37.166668, 37.25    , 37.333332, 37.416668,
#        37.5     , 37.583332, 37.666668, 37.75    , 37.833332, 37.916668,
#        38.      , 38.083332, 38.166668, 38.25    , 38.333332, 38.416668,
#        38.5     , 38.583332, 38.666668, 38.75    , 38.833332, 38.916668,
#        39.      , 39.083332, 39.166668, 39.25    , 39.333332, 39.416668,
#        39.5     , 39.583332, 39.666668, 39.75    , 39.833332, 39.916668,
#        40.      , 40.083332, 40.166668, 40.25    , 40.333332, 40.416668,
#        40.5     , 40.583332, 40.666668, 40.75    , 40.833332, 40.916668,
#        41.      , 41.083332, 41.166668, 41.25    , 41.333332, 41.416668,
#        41.5     , 41.583332, 41.666668, 41.75    , 41.833332, 41.916668,
#        42.      , 42.083332, 42.166668, 42.25    , 42.333332, 42.416668,
#        42.5     , 42.583332, 42.666668, 42.75    , 42.833332, 42.916668,
#        43.      , 43.083332, 43.166668, 43.25    , 43.333332, 43.416668,
#        43.5     , 43.583332, 43.666668, 43.75    , 43.833332, 43.916668,
#        44.      , 44.083332, 44.166668, 44.25    , 44.333332, 44.416668,
#        44.5     , 44.583332, 44.666668, 44.75    , 44.833332, 44.916668,
#        45.      , 45.083332, 45.166668, 45.25    , 45.333332, 45.416668,
#        45.5     , 45.583332, 45.666668, 45.75    , 45.833332, 45.916668,
#        46.      ], dtype=float32)
# Coordinates:
#   * latitude  (latitude) float32 35.0 35.083332 35.166668 ... 45.916668 46.0
# Attributes:
#     valid_min:            35.0
#     valid_max:            46.0
#     step:                 0.08333588
#     units:                degrees_north
#     unit_long:            Degrees North
#     long_name:            Latitude
#     standard_name:        latitude
#     axis:                 Y
#     _ChunkSizes:          2041
#     _CoordinateAxisType:  Lat

# %%
print(DS['longitude'])
# Out:
# <xarray.DataArray 'longitude' (longitude: 181)>
# array([-78.      , -77.916664, -77.833336, -77.75    , -77.666664, -77.583336,
#        -77.5     , -77.416664, -77.333336, -77.25    , -77.166664, -77.083336,
#        -77.      , -76.916664, -76.833336, -76.75    , -76.666664, -76.583336,
#        -76.5     , -76.416664, -76.333336, -76.25    , -76.166664, -76.083336,
#        -76.      , -75.916664, -75.833336, -75.75    , -75.666664, -75.583336,
#        -75.5     , -75.416664, -75.333336, -75.25    , -75.166664, -75.083336,
#        -75.      , -74.916664, -74.833336, -74.75    , -74.666664, -74.583336,
#        -74.5     , -74.416664, -74.333336, -74.25    , -74.166664, -74.083336,
#        -74.      , -73.916664, -73.833336, -73.75    , -73.666664, -73.583336,
#        -73.5     , -73.416664, -73.333336, -73.25    , -73.166664, -73.083336,
#        -73.      , -72.916664, -72.833336, -72.75    , -72.666664, -72.583336,
#        -72.5     , -72.416664, -72.333336, -72.25    , -72.166664, -72.083336,
#        -72.      , -71.916664, -71.833336, -71.75    , -71.666664, -71.583336,
#        -71.5     , -71.416664, -71.333336, -71.25    , -71.166664, -71.083336,
#        -71.      , -70.916664, -70.833336, -70.75    , -70.666664, -70.583336,
#        -70.5     , -70.416664, -70.333336, -70.25    , -70.166664, -70.083336,
#        -70.      , -69.916664, -69.833336, -69.75    , -69.666664, -69.583336,
#        -69.5     , -69.416664, -69.333336, -69.25    , -69.166664, -69.083336,
#        -69.      , -68.916664, -68.833336, -68.75    , -68.666664, -68.583336,
#        -68.5     , -68.416664, -68.333336, -68.25    , -68.166664, -68.083336,
#        -68.      , -67.916664, -67.833336, -67.75    , -67.666664, -67.583336,
#        -67.5     , -67.416664, -67.333336, -67.25    , -67.166664, -67.083336,
#        -67.      , -66.916664, -66.833336, -66.75    , -66.666664, -66.583336,
#        -66.5     , -66.416664, -66.333336, -66.25    , -66.166664, -66.083336,
#        -66.      , -65.916664, -65.833336, -65.75    , -65.666664, -65.583336,
#        -65.5     , -65.416664, -65.333336, -65.25    , -65.166664, -65.083336,
#        -65.      , -64.916664, -64.833336, -64.75    , -64.666664, -64.583336,
#        -64.5     , -64.416664, -64.333336, -64.25    , -64.166664, -64.083336,
#        -64.      , -63.916668, -63.833332, -63.75    , -63.666668, -63.583332,
#        -63.5     , -63.416668, -63.333332, -63.25    , -63.166668, -63.083332,
#        -63.      ], dtype=float32)
# Coordinates:
#   * longitude  (longitude) float32 -78.0 -77.916664 ... -63.083332 -63.0
# Attributes:
#     valid_min:            -78.0
#     valid_max:            -63.0
#     step:                 0.08332825
#     units:                degrees_east
#     unit_long:            Degrees East
#     long_name:            Longitude
#     standard_name:        longitude
#     axis:                 X
#     _ChunkSizes:          4320
#     _CoordinateAxisType:  Lon

# %%
pointstouse = []; finallatestdepth = []; finallatestsurfval = []
finalfinaldepth = []; finalfinalratio = []; filteredMLDlist = []; meanfilteredMLDlist = []; stdfilteredMLDlist = []; years = []; bananasplitmean = []; bananasplitstd = [];floormean = [];floorstd = []; latfinal = []; lonfinal = []; ratiofinal = [];bottomdfinal = []; filteredfloorslist = [];zi_listofarrays = []
for year in range(1993,2019):
    filename = 'casts_{}.mat'.format(year)
    file = scipy.io.loadmat(filename,squeeze_me=True)
    npfile = file['casts_{}'.format(year)]
    finaldepth = []; finallat = [];finallon = []
    lat_intermediate = []; lon_intermediate = []; p_intermediate = []; t_intermediate = []; yd_intermediate = []
    seasonyeardepth = []; seasonyeartemp = [];seasonyearsal = []; counterii = []; floors = []; floor_intermediate = []; s_intermediate = [];seasonyearsal = []; lat = []; lon = []; lonneg = []
    surfacevalnew = []
    for i in range(len(npfile)):
        yd = npfile[i]['yd']
        p = npfile[i]['p']
        s = npfile[i]['s']
        t = npfile[i]['t']
        gear = npfile[i]['gear']
        floordepth = npfile[i]['depth']
        if gear == 'Bottle':
            pass
        elif yd > 151 and yd <= 181:
#         elif yd > 334 and yd <= 365 or yd >= 0 and yd <= 59:
            lat_intermediate.append(npfile[i]['lat'])
            lon_intermediate.append(npfile[i]['lon'])
            p_intermediate.append(npfile[i]['p'])
            t_intermediate.append(npfile[i]['t'])
            yd_intermediate.append(npfile[i]['yd'])
            floor_intermediate.append(npfile[i]['depth'])
            s_intermediate.append(npfile[i]['s'])
    month_df = pd.DataFrame({'day': yd_intermediate,'lon': lon_intermediate,'lat': lat_intermediate, 'p': p_intermediate, 't': t_intermediate, 
                            'depth': floor_intermediate, 's': s_intermediate})
    newdf = pd.DataFrame({'lon': lon_intermediate,'lat': lat_intermediate,'date': yd_intermediate})
    for ii in range(len(month_df)):
        new = newdf.iloc[ii].values
        point = Point(new)
        if isinstance(month_df['p'].iloc[ii], int) or isinstance(month_df['p'].iloc[ii], float) or isinstance(month_df['t'].iloc[ii], int) or isinstance(month_df['t'].iloc[ii], float):
            pass
#         elif polygon_v.contains(point) == True:
        elif polygon_x.contains(point) == True or polygon_y.contains(point) == True or polygon_t.contains(point) == True or polygon_w.contains(point) == True or polygon_v.contains(point) == True:
            pt_df = pd.DataFrame({'p': month_df['p'].iloc[ii],'temp': month_df['t'].iloc[ii],'sal': month_df['s'].iloc[ii]}) 
            df_ptsnew = pt_df.dropna()
            df_final = pd.DataFrame(df_ptsnew.values)
            l=[i for i in df_final[0] if i<=6]
            if len(l) > 0:
                surfaceval = []
                numrange = []
                for x in range(len(l)):
                    val = df_final[1][x]
                    numrange.append(x)
                    surfaceval.append(val)      
            surfacevalmean = statistics.mean(surfaceval)
            tempfin = []
            pressurefin = []
            salfin = []
            for iii in range(numrange[-1],len(df_final)):
                tempfin.append(df_final[1][iii])
                pressurefin.append(df_final[0][iii])
                salfin.append(df_final[2][iii])
            d = {'temp': list(reversed(tempfin)), 'sal': list(reversed(salfin)), 'pressure': list(reversed(pressurefin))}
            dunreversed = {'temp': list(tempfin), 'sal': list(salfin), 'pressure': list(pressurefin)}
            dffinunreversed = pd.DataFrame(dunreversed)
            dffin = pd.DataFrame(d)
            
            for ix in range(len(dffinunreversed)):
                if dffinunreversed.at[len(dffinunreversed)-1,'temp'] <= (surfacevalmean + 0.2) and dffinunreversed.at[len(dffinunreversed)-1,'temp'] >= (surfacevalmean - 0.2):
                    if month_df['depth'].iloc[ii] <= 300:
                        seasonyeardepth.append(dffinunreversed.at[len(dffinunreversed)-1,'pressure'])
                        seasonyeartemp.append(dffinunreversed.at[len(dffinunreversed)-1,'temp'])
                        seasonyearsal.append(dffinunreversed.at[len(dffinunreversed)-1,'sal'])
                        floors.append(month_df['depth'].iloc[ii])
                        lat.append(month_df['lat'].iloc[ii])
                        lon.append(month_df['lon'].iloc[ii])
                        lonneg.append(month_df['lon'].iloc[ii]*-1)
                        counterii.append(ii)
                        surfacevalnew.append(surfacevalmean)
#                         fig, (ax1) = plt.subplots(1,1)
#                         ax1.plot(df_final[1],df_final[0]*-1,color='blue')
#         #               print(dffinunreversed.at[ix,'pressure'])
#                         ax1.axhline(y=dffinunreversed.at[len(dffinunreversed)-1,'pressure']*-1, color='red', linestyle='--')
#                         ax1.axhline(y=dffinunreversed.at[ix,'pressure']*-1, color='brown', linestyle='--')
#                         seasonyeardepth.append(dffinunreversed.at[ix,'pressure'])
                    break
                elif dffinunreversed.at[ix,'temp'] >= (surfacevalmean - 0.2) and dffinunreversed.at[ix,'temp'] <= (surfacevalmean + 0.2):
                    pass
                else:
                    if dffinunreversed.at[ix,'pressure'] >= (month_df['depth'].iloc[ii] - 6): # ALL MIXED
                        if dffinunreversed.at[ix,'pressure'] == dffinunreversed.at[len(dffinunreversed)-1,'pressure']:
                            if dffinunreversed.at[ix,'pressure'] <= (month_df['depth'].iloc[ii] - 15):
                                pass
                            else:
                                if month_df['depth'].iloc[ii] <= 300:
                                    seasonyeardepth.append(dffinunreversed.at[ix,'pressure'])
                                    seasonyeartemp.append(dffinunreversed.at[ix,'temp'])
                                    seasonyearsal.append(dffinunreversed.at[ix,'sal'])
                                    floors.append(month_df['depth'].iloc[ii])
                                    lat.append(month_df['lat'].iloc[ii])
                                    lon.append(month_df['lon'].iloc[ii])
                                    lonneg.append(month_df['lon'].iloc[ii]*-1)
                                    counterii.append(ii)
                                    surfacevalnew.append(surfacevalmean)
                                    
                                    
#                                     fig, (ax1) = plt.subplots(1,1)
#                                     ax1.plot(df_final[1],df_final[0]*-1,color='blue')
#         #                             print(dffinunreversed.at[ix,'pressure'])
#                                     ax1.axhline(y=dffinunreversed.at[ix,'pressure']*-1, color='brown', linestyle='--')
                                    break
                        else:
                            if month_df['depth'].iloc[ii] <= 300:
                                seasonyeardepth.append(dffinunreversed.at[ix,'pressure'])
                                seasonyeartemp.append(dffinunreversed.at[ix,'temp'])
                                seasonyearsal.append(dffinunreversed.at[ix,'sal'])
                                floors.append(month_df['depth'].iloc[ii])
                                lat.append(month_df['lat'].iloc[ii])
                                lon.append(month_df['lon'].iloc[ii])
                                lonneg.append(month_df['lon'].iloc[ii]*-1)
                                counterii.append(ii)
                                surfacevalnew.append(surfacevalmean)
#                                 fig, (ax1) = plt.subplots(1,1)
#                                 ax1.plot(df_final[1],df_final[0]*-1,color='blue')
#         #                             print(dffinunreversed.at[ix,'pressure'])
#                                 ax1.axhline(y=dffinunreversed.at[ix,'pressure']*-1, color='brown', linestyle='--')
                    elif dffinunreversed.at[ix,'pressure'] == 0:
                        pass
                    elif ix == 0: 
                        if month_df['depth'].iloc[ii] <= 300:
                            seasonyeardepth.append(dffinunreversed.at[ix,'pressure'])
                            seasonyeartemp.append(dffinunreversed.at[ix,'temp'])
                            seasonyearsal.append(dffinunreversed.at[ix,'sal'])
                            floors.append(month_df['depth'].iloc[ii])
                            lat.append(month_df['lat'].iloc[ii])
                            lon.append(month_df['lon'].iloc[ii])
                            lonneg.append(month_df['lon'].iloc[ii]*-1)
                            counterii.append(ii)
                            surfacevalnew.append(surfacevalmean)
#                             fig, (ax1) = plt.subplots(1,1)
#                             ax1.plot(df_final[1],df_final[0]*-1,color='blue')
#         #                   print(dffinunreversed.at[ix,'pressure'])
#                             ax1.axhline(y=dffinunreversed.at[ix,'pressure']*-1, color='brown', linestyle='--')
                    else: # Well-defined mixed layer detected
                        if month_df['depth'].iloc[ii] <= 300:
                            seasonyeardepth.append(dffinunreversed.at[ix,'pressure'])
                            seasonyeartemp.append(dffinunreversed.at[ix,'temp'])
                            seasonyearsal.append(dffinunreversed.at[ix,'sal'])
                            floors.append(month_df['depth'].iloc[ii])
                            lat.append(month_df['lat'].iloc[ii])
                            lon.append(month_df['lon'].iloc[ii])
                            lonneg.append(month_df['lon'].iloc[ii]*-1)
                            counterii.append(ii)
                            surfacevalnew.append(surfacevalmean)
#                             fig, (ax1) = plt.subplots(1,1)
#                             ax1.plot(df_final[1],df_final[0]*-1,color='blue')
#         #                             print(dffinunreversed.at[ix,'pressure'])
#                             ax1.axhline(y=dffinunreversed.at[ix,'pressure']*-1, color='brown', linestyle='--')
                    break

    inlat = []; inlon = []; date = []
    for timer in counterii:
        inlat.append(newdf['lat'][timer])
        inlon.append(newdf['lon'][timer])
        date.append(newdf['date'][timer])                 
    if len(seasonyeardepth) > 0:    
        print(year)
#         print(seasonyeardepth)
#         print(inlat)
#         print(inlon)
#         print(date)
        full = pd.DataFrame({'mld': seasonyeardepth,'lat': lat, 'lon': lon, 'date': date, 'surfacetemp': surfacevalnew}) 
        print(full)
        print(len(full))
        finallatestdepth.append(seasonyeardepth)
        finallatestsurfval.append(surfacevalnew)
    
    for x in range(len(date)):
        use=DS.sel(time=slice('{}-06-01'.format(year),'{}-06-30'.format(year))) 
        locate_date = use.sel(time=use.time.dt.day==(date[x])-151)
        mld_locate_date = locate_date.thetao.values[0][0]
#         mld_locate_date = locate_date.mlotst.values
    
        lat = np.array(locate_date.thetao['latitude'][:])
        long = np.array(locate_date.thetao['longitude'][:])
    
        lonneg = [float(i)*-1 for i in inlon]
        distanceslat = []; distanceslon = []
        for i in range(133):
            distanceslat.append((inlat[x] - lat[i])**2)
            index_min_lat = min(range(len(distanceslat)), key=distanceslat.__getitem__)
        for ii in range(181):
            distanceslon.append((lonneg[x] - long[ii])**2)
            index_min_lon = min(range(len(distanceslon)), key=distanceslon.__getitem__)
        lat_index_use, lon_index_use = index_min_lat, index_min_lon
#         print(lat_index_use, lon_index_use)
        pointstouse.append(mld_locate_date[lat_index_use, lon_index_use])
# Out:
# 1993
#       mld      lat      lon  date  surfacetemp
# 0    42.0  41.8250  67.3700   153     8.438333
# 1    11.0  41.9417  65.8900   155     7.295000
# 2     8.0  41.7683  66.0550   156     6.024000
# 3    14.0  41.6683  66.1500   156     6.954000
# 4    12.0  41.5450  66.0167   157     7.326000
# 5     9.0  41.4650  66.2300   159     7.046000
# 6    17.0  41.4650  66.2233   159     7.232000
# 7    14.0  41.3833  66.2533   160     7.030000
# 8    10.0  41.3150  66.3167   160     7.362000
# 9     8.0  41.2933  66.2000   161     7.222000
# 10    7.0  41.2917  66.1967   161     7.392000
# 11    7.0  41.2517  66.2417   161     7.464000
# 12   11.0  41.2450  66.2400   161     7.464000
# 13   98.0  41.2033  66.2817   161     7.582000
# 14    8.0  41.2050  66.2833   161     7.650000
# 15   89.0  41.2567  66.3400   161     7.300000
# 16    6.0  40.9567  66.6733   163     8.274000
# 17    6.0  40.7783  66.7750   164    16.978000
# 18    6.0  40.6417  66.9767   165    14.816000
# 19    6.0  40.6617  67.1117   165     9.816000
# 20  101.0  40.4983  67.5433   174    11.950000
# 21  116.0  40.4967  67.5417   174    12.020000
# 22   23.0  40.3500  67.7933   175    17.420000
# 23   15.0  40.4967  68.0100   175    12.402500
# 24   15.0  40.3150  68.0667   175    16.132500
# 25   16.0  40.5217  68.2717   176    12.720000
# 26   13.0  40.2567  68.3283   176    16.415000
# 27   12.0  40.3600  68.5033   176    13.607500
# 28   10.0  40.2917  68.7217   178    14.647500
# 29    8.0  40.1500  68.8633   178    16.398000
# 30    8.0  40.2283  69.0250   179    15.912500
# 31    6.0  40.1867  69.2033   179    15.377500
# 32    6.0  40.5450  68.1533   181    15.454000
# 33    6.0  40.4317  67.9617   181    16.432000
# 34
# 1994
#       mld      lat      lon  date  surfacetemp
# 0    16.0  41.2800  69.0700   152     7.730000
# 1    45.0  40.8883  68.3500   152     9.297500
# 2     7.0  40.7150  67.9650   152    11.656667
# 3    68.0  40.7683  67.6167   152    11.390000
# 4    36.0  41.0117  68.3250   153     9.207500
# ..    ...      ...      ...   ...          ...
# 211   6.0  40.9217  68.8233   180    13.446667
# 212  62.0  40.9950  68.8317   180    11.523333
# 213  65.0  41.0850  68.8300   181    12.176667
# 214  21.0  41.1600  68.8400   181    12.306667
# 215  15.0  41.2333  68.8400   181    10.798333
#
# [216 rows x 5 columns]
# 216
# 1995
#       mld      lat      lon  date  surfacetemp
# 0    13.0  41.4233  68.7517   171    12.218333
# 1     8.0  41.2000  68.7417   171    11.673333
# 2    58.0  40.8333  68.7467   171     9.221667
# 3    33.0  40.7467  68.5017   171     9.928333
# 4    48.0  41.0033  68.5017   171    10.534000
# ..    ...      ...      ...   ...          ...
# 179  17.0  40.2283  72.2867   180    15.340000
# 180  21.0  40.3133  72.0217   180    15.160000
# 181  13.0  40.3833  71.8833   180    15.138000
# 182  10.0  40.8083  72.2817   180    16.526000
# 183   7.0  40.8550  72.1983   181    16.226667
#
# [184 rows x 5 columns]
# 184
# 1996
#       mld      lat      lon  date  surfacetemp
# 0     7.0  40.5100  67.2317   180    14.126667
# 1     6.0  42.1183  70.2750   152    10.320000
# 2     6.0  42.4167  70.2667   153    12.456667
# 3     6.0  42.7317  70.2633   153    12.058333
# 4     7.0  42.7300  70.2600   153    11.966667
# ..    ...      ...      ...   ...          ...
# 233   7.0  41.6000  66.2767   177    11.416667
# 234  12.0  41.8450  66.2500   177    11.406667
# 235  18.0  42.1283  66.2550   177    12.001667
# 236   9.0  41.9967  66.0133   177    10.144000
# 237   6.0  41.7567  65.9983   177     9.870000
#
# [238 rows x 5 columns]
# 238
# 1997
#      mld      lat      lon  date  surfacetemp
# 0    8.0  39.2850  73.8567   156    12.085000
# 1   20.0  39.2833  73.8517   157    12.025000
# 2   13.0  39.2833  73.8533   157    12.215000
# 3   10.0  39.2817  73.8533   157    11.952500
# 4   21.0  39.3867  73.9117   159    12.450000
# ..   ...      ...      ...   ...          ...
# 94  36.1  41.2780  68.2780   178    11.750000
# 95  66.0  41.3017  68.6033   178    10.562000
# 96  34.5  41.2750  68.3080   178    11.822000
# 97   6.0  41.4883  68.9483   178    16.253333
# 98   6.0  41.4850  68.9350   178    15.323333
#
# [99 rows x 5 columns]
# 99
# 1998
#       mld      lat      lon  date  surfacetemp
# 0    14.0  40.2067  71.1083   152    13.276000
# 1    15.0  40.4417  71.1133   152    13.372000
# 2     9.0  40.4417  71.1150   152    13.461667
# 3    17.0  40.0500  70.2867   152    14.860000
# 4     7.0  40.1467  69.1300   152    11.604000
# ..    ...      ...      ...   ...          ...
# 144   7.0  41.6083  68.4467   176    10.908000
# 145  11.5  41.5080  68.9720   177    15.010000
# 146  46.0  41.4017  68.2900   176    12.665000
# 147  51.0  41.3033  68.5900   176    11.011667
# 148   6.0  41.4883  68.9450   176    14.652000
#
# [149 rows x 5 columns]
# 149
# 1999
#       mld      lat      lon  date  surfacetemp
# 0    13.0  41.1400  68.7000   154     9.686667
# 1    38.0  41.1383  68.6917   154     9.590000
# 2     8.0  41.3833  68.6950   154    14.084000
# 3    11.0  41.7700  68.5533   154    13.275000
# 4    37.0  41.3300  67.8700   154    11.170000
# ..    ...      ...      ...   ...          ...
# 201  12.0  42.6983  69.8050   181    18.350000
# 202   7.0  40.5983  71.9883   166    18.400000
# 203  11.0  42.5833  69.8483   181    18.138000
# 204  12.0  42.4983  69.9750   181    18.048000
# 205  10.0  42.3617  69.8417   181    18.908000
#
# [206 rows x 5 columns]
# 206
# 2000
#      mld      lat      lon  date  surfacetemp
# 0    9.0  41.2783  66.5433   172    12.886000
# 1    6.0  41.3000  66.7017   173    11.016000
# 2    6.0  41.2733  66.5517   173    12.176000
# 3    7.0  41.2267  66.7650   173    11.997500
# 4    6.0  41.2317  66.6833   173    11.224000
# ..   ...      ...      ...   ...          ...
# 87  12.0  43.6733  69.7083   158    10.383333
# 88  13.0  43.4133  70.1483   158    10.518333
# 89  34.0  43.0583  70.0550   159     8.828333
# 90   6.0  42.6050  69.7450   159    10.848000
# 91   6.0  42.3800  70.3633   160    10.486667
#
# [92 rows x 5 columns]
# 92
# 2001
#      mld      lat      lon  date  surfacetemp
# 0   23.0  41.7017  65.8283   152     8.328000
# 1    7.0  41.9317  66.3100   152     7.651667
# 2   11.0  42.0733  66.8250   152     8.266667
# 3   20.0  42.2767  66.6967   152     8.346000
# 4   18.0  42.2833  66.7200   152     8.350000
# ..   ...      ...      ...   ...          ...
# 77   7.0  39.3200  73.2667   181    23.711667
# 78   7.0  39.0300  73.4367   181    24.301667
# 79   6.0  38.7400  73.8100   181    23.190000
# 80   8.0  38.7600  73.6483   181    24.401667
# 81   6.0  38.9033  73.4967   181    24.728333
#
# [82 rows x 5 columns]
# 82
# 2002
#      mld      lat      lon  date  surfacetemp
# 0    6.0  41.7450  65.9517   152     7.886000
# 1   12.0  41.7917  66.3867   152     8.393333
# 2   58.0  41.7850  66.7617   152     8.885000
# 3   72.0  42.0350  66.5850   152     8.375000
# 4    7.0  42.0000  66.4050   152     8.816667
# ..   ...      ...      ...   ...          ...
# 57  11.0  43.4900  69.9200   156    10.436000
# 58  12.0  43.4933  69.9200   156    10.413333
# 59   9.0  43.2983  70.2200   156    11.290000
# 60   8.0  42.9950  70.1600   156    11.980000
# 61   8.0  42.2150  70.0917   157    12.134000
#
# [62 rows x 5 columns]
# 62
# 2004
#      mld      lat      lon  date  surfacetemp
# 0   24.0  40.9833  69.3100   152     7.000000
# 1   43.0  40.9800  69.3100   152     6.900000
# 2   37.0  40.6883  69.3483   152     6.761667
# 3    6.0  40.7717  69.9400   152     9.043333
# 4   13.0  40.9383  70.7783   152    12.280000
# ..   ...      ...      ...   ...          ...
# 66  17.0  42.1417  69.0817   160    10.110000
# 67  24.0  41.9383  69.3433   160    10.770000
# 68   6.0  40.0983  69.5500   176    12.090000
# 69   7.0  40.0900  69.5483   177    12.760000
# 70   6.0  41.0050  66.4767   181    14.292500
#
# [71 rows x 5 columns]
# 71
# 2005
#      mld      lat      lon  date  surfacetemp
# 0    6.0  41.8967  69.6467   153     7.545000
# 1    7.0  41.2717  68.6817   153     7.258000
# 2    6.0  41.2717  68.6850   153     7.055000
# 3   35.0  40.9800  68.1100   153     8.371667
# 4    8.0  40.9000  67.6467   153     9.195000
# ..   ...      ...      ...   ...          ...
# 64  10.0  42.1883  69.4083   158     9.516667
# 65   6.0  42.3983  69.6117   158    10.326000
# 66   6.0  42.4033  69.6167   158    10.310000
# 67  15.0  42.5033  69.6667   158     9.988333
# 68   6.0  42.3950  70.1817   159     9.571667
#
# [69 rows x 5 columns]
# 69
# 2006
#       mld      lat      lon  date  surfacetemp
# 0     6.0  40.9450  71.1517   152    14.176667
# 1     6.0  40.7333  71.2733   152    13.391667
# 2     6.0  40.6050  71.5017   152    14.388333
# 3     6.0  40.1867  72.4283   152    12.403333
# 4     6.0  40.1883  72.4300   152    14.993333
# ..    ...      ...      ...   ...          ...
# 129   6.0  42.8517  70.0000   165    11.555000
# 130   6.0  42.8600  70.0083   165    10.844000
# 131  10.0  42.2483  69.9733   165    11.916667
# 132   6.0  42.3300  69.5900   165    13.285000
# 133   6.0  42.3233  69.5900   165    12.323333
#
# [134 rows x 5 columns]
# 134
# 2007
#      mld      lat      lon  date  surfacetemp
# 0   18.0  42.5183  66.7083   152     9.135000
# 1    6.0  42.5183  66.7067   152     8.811667
# 2    7.0  42.4167  67.0050   152    11.103333
# 3    6.0  42.3600  66.5100   152     9.765000
# 4   11.0  42.3600  66.5067   152    10.030000
# 5    6.0  42.0650  66.5167   152     9.516667
# 6   53.0  42.0217  66.9733   152     8.268333
# 7   50.0  42.0650  67.0800   152     8.461667
# 8   39.0  42.0617  67.0750   152     8.475000
# 9    7.0  42.1883  67.3200   152    11.238333
# 10   6.0  42.0600  67.3417   152     9.005000
# 11  44.0  41.8967  67.2800   152     8.990000
# 12  44.0  41.8933  67.2783   152     9.030000
# 13   6.0  41.9867  67.7467   152    10.858333
# 14  30.0  41.6767  68.0483   153     9.563333
# 15   6.0  42.0600  68.7467   153    11.983333
# 16   7.0  42.3567  68.8467   153    12.235000
# 17   6.0  42.3550  68.4450   153    12.355000
# 18   7.0  42.2300  67.8800   153    10.288333
# 19   6.0  42.2300  67.8783   153    10.645000
# 20   6.0  42.7283  67.2817   153     6.788333
# 21   6.0  42.7283  67.2783   153     7.783333
# 22   6.0  43.0417  67.0850   153     9.486667
# 23   6.0  43.3567  66.8850   153     8.936667
# 24   6.0  43.3550  66.8850   153     8.800000
# 25   7.0  43.6867  66.6800   154     6.038333
# 26  10.0  44.1883  66.9817   154     9.090000
# 27  10.0  43.7267  67.1433   154     8.980000
# 28   6.0  43.6867  67.3783   154     9.446667
# 29  10.0  43.6483  67.6783   154     9.645000
# 30   7.0  43.6500  67.6833   154     9.591667
# 31  12.0  43.4800  67.9100   154    10.098333
# 32   6.0  43.4833  67.9117   154     9.455000
# 33  14.0  43.4000  67.7017   154     8.748333
# 34  12.0  43.4033  67.7067   154     8.636667
# 35  14.0  43.2700  67.9817   154     9.781667
# 36   9.0  43.2717  67.9867   154    10.238333
# 37   7.0  43.0217  68.3150   154    10.510000
# 38  10.0  42.9367  68.5150   154    10.995000
# 39   7.0  43.1500  68.6150   154    10.590000
# 40  11.0  43.3933  68.4800   155     9.503333
# 41  14.0  43.7600  68.9483   155     7.497500
# 42  19.0  43.5600  68.9433   155     8.230000
# 43  14.0  43.2267  69.2450   155     8.940000
# 44  11.0  43.1033  69.6933   155    10.290000
# 45   9.0  43.1017  69.6950   155    10.370000
# 46   6.0  42.9783  70.1400   155    10.691667
# 47  15.0  42.6800  70.1300   155    11.996667
# 48  12.0  42.5033  69.6683   155    12.188333
# 49  10.0  42.5050  69.6683   155    12.216667
# 50  11.0  42.4783  69.8750   155    11.335000
# 51   6.0  42.4350  70.2750   156    11.598333
# 52
# 2008
#      mld      lat      lon  date  surfacetemp
# 0    8.0  38.1517  74.3117   174    22.072000
# 1    7.0  38.0017  74.3650   174    22.090000
# 2    7.0  37.9433  74.4533   174    22.150000
# 3    6.0  37.8467  74.4417   174    21.592000
# 4    7.0  37.9017  74.5650   174    23.780000
# ..   ...      ...      ...   ...          ...
# 193  9.0  38.1800  74.7583   181    23.361667
# 194  7.0  38.2250  74.8217   181    22.287500
# 195  8.0  38.2817  74.8200   181    22.126667
# 196  7.0  38.2883  74.7900   181    22.536667
# 197  7.0  38.2400  74.8550   181    21.400000
#
# [198 rows x 5 columns]
# 198
# 2009
#       mld      lat      lon  date  surfacetemp
# 0     6.0  38.3100  74.0883   159    15.694000
# 1     6.0  38.3450  74.0133   159    15.642000
# 2     6.0  38.3433  73.8550   160    14.268000
# 3     7.0  38.4700  73.7183   160    14.840000
# 4     6.0  38.5583  73.7267   160    15.057500
# ..    ...      ...      ...   ...          ...
# 155   9.0  42.4817  69.3200   161    11.798333
# 156   8.0  42.5000  69.6667   161    12.013333
# 157  12.0  42.5017  69.6683   161    11.730000
# 158   6.0  42.2300  70.2767   161    11.831667
# 159   8.0  41.5233  69.3150   162    11.903333
#
# [160 rows x 5 columns]
# 160
# 2010
#       mld      lat      lon  date  surfacetemp
# 0     6.0  40.0983  72.6517   160    17.436000
# 1     6.0  40.1567  72.4567   160    16.946000
# 2     7.0  40.2267  72.1967   160    16.764000
# 3     8.0  40.3833  72.5333   160    16.922000
# 4     9.0  40.5600  72.5533   160    15.864000
# ..    ...      ...      ...   ...          ...
# 176   8.0  43.2717  70.0817   160    13.616000
# 177   8.0  42.9383  70.0850   160    14.802000
# 178  12.0  42.9417  70.2517   160    14.486000
# 179  10.0  42.8117  70.1783   160    14.718000
# 180   6.0  42.6783  70.4500   160    14.748333
#
# [181 rows x 5 columns]
# 181
# 2011
#      mld      lat      lon  date  surfacetemp
# 0    6.0  40.5600  69.7833   160    10.406000
# 1    9.0  40.6467  69.4783   160     9.880000
# 2    8.0  40.5183  69.0683   160    12.850000
# 3    6.0  40.6467  69.2467   160    10.298333
# 4    6.0  40.7867  69.2550   160    10.653333
# ..   ...      ...      ...   ...          ...
# 283  8.0  40.7500  69.0267   172    10.760000
# 284  8.0  40.8550  69.0233   172    11.023333
# 285  9.0  40.9833  69.0150   172     9.595000
# 286  6.0  41.0967  69.0033   172     9.633333
# 287  6.0  41.0783  69.0050   172     9.260000
#
# [288 rows x 5 columns]
# 288
# 2012
#       mld      lat      lon  date  surfacetemp
# 0    13.0  39.8600  73.5317   168    19.048333
# 1     6.0  40.0633  73.6750   168    18.371667
# 2     7.0  39.8717  72.6850   169    17.500000
# 3    12.0  40.0850  72.5733   170    17.758333
# 4    10.0  40.3933  73.0767   170    18.333333
# ..    ...      ...      ...   ...          ...
# 130   6.0  41.1667  68.7817   165    11.008333
# 131  16.0  41.1667  68.7850   165    10.861667
# 132   9.0  41.1667  68.7850   165    10.610000
# 133   6.0  40.8583  68.7867   165    12.175000
# 134   6.0  40.5633  68.8750   165    12.948333
#
# [135 rows x 5 columns]
# 135
# 2013
#       mld      lat      lon  date  surfacetemp
# 0    17.0  38.7400  73.9850   166    17.404000
# 1    12.0  37.0383  74.8883   168    20.565000
# 2     6.0  37.2950  74.7450   168    19.871667
# 3     7.0  38.0117  74.3033   169    19.013333
# 4     8.0  38.2167  74.2567   169    18.900000
# ..    ...      ...      ...   ...          ...
# 155   6.0  36.3200  74.8833   173    20.753333
# 156   6.0  36.3167  74.7400   173    20.711667
# 157   6.0  36.0017  75.1700   174    22.345000
# 158   8.0  36.0000  75.1783   174    22.550000
# 159   6.0  35.8700  75.3167   174    22.628000
#
# [160 rows x 5 columns]
# 160
# 2015
#      mld        lat        lon  date  surfacetemp
# 0   26.0  42.746667  69.521667   152    10.550128
# 1   18.0  43.238333  69.511667   152     9.967494
# 2   16.0  42.995000  70.171667   152     9.559465
# 3   14.0  42.993333  70.175000   152     9.546592
# 4   11.0  43.001667  70.418333   152     8.698560
# ..   ...        ...        ...   ...          ...
# 58  20.0  40.006667  70.008333   175    24.842434
# 59   8.0  41.110000  66.463333   176    12.989321
# 60   6.0  41.110000  66.465000   176    13.067547
# 61   9.0  40.338333  68.065000   181    20.723681
# 62  12.0  40.338333  68.198333   181    19.849357
#
# [63 rows x 5 columns]
# 63
# 2016
#       mld        lat        lon  date  surfacetemp
# 0    62.0  41.748333  66.656667   152     8.969661
# 1     9.0  43.448333  69.048333   152    11.615561
# 2     9.0  43.500000  69.020000   152    11.592753
# 3     9.0  42.165000  66.665000   152     9.968617
# 4     9.0  43.385000  68.803333   152    11.013886
# ..    ...        ...        ...   ...          ...
# 127   6.0  41.230000  68.593333   174    13.498073
# 128   6.0  40.193333  71.280000   179    17.048791
# 129   6.0  40.183333  71.283333   179    17.872024
# 130   6.0  39.726667  72.315000   179    17.760337
# 131   6.0  39.710000  72.245000   180    17.903081
#
# [132 rows x 5 columns]
# 132
# 2017
#      mld        lat        lon  date  surfacetemp
# 0   21.0  41.411667  66.170000   152     7.938288
# 1   26.0  41.580000  66.423333   152     8.507912
# 2   67.0  41.748333  66.585000   152     7.967398
# 3    8.0  41.831667  66.506667   152     7.922917
# 4    6.0  42.248333  66.495000   152     9.041016
# ..   ...        ...        ...   ...          ...
# 59  11.0  40.636667  68.095000   166    12.731466
# 60  14.0  40.581667  67.673333   166    11.540344
# 61   6.0  40.866667  67.428333   166    11.451451
# 62   6.0  41.106667  67.551667   166    10.985049
# 63   9.0  40.895000  67.713333   166    12.911047
#
# [64 rows x 5 columns]
# 64
# 2018
#      mld        lat        lon  date  surfacetemp
# 0   29.0  41.721667  67.961667   152     8.846488
# 1    6.0  41.913333  68.005000   152    11.088966
# 2    8.0  41.870000  67.955000   152    10.327626
# 3    8.0  42.008333  67.688333   152    10.627479
# 4   10.0  41.860000  67.961667   152     9.583624
# ..   ...        ...        ...   ...          ...
# 56   6.0  40.458333  69.068333   176    13.721355
# 57  12.0  42.855000  69.841667   177    16.146354
# 58  16.0  44.170000  66.618333   179     9.886649
# 59  65.0  43.335000  66.235000   180     8.892704
# 60  25.0  43.335000  66.238333   180     8.701880
#
# [61 rows x 5 columns]
# 61

# %%
print(len(pointstouse))
# Out:
# 3130

# %%
new_mld_nefsc = sum(finallatestsurfval, [])
print(len(new_mld_nefsc))
# Out:
# 3130

# %%
diff = [a_i - b_i for a_i, b_i in zip(new_mld_nefsc,pointstouse)]

# %%
print('MAX diff:          ',max(diff))
print('MIN diff:          ',min(diff))
print('MEAN diff:         ',statistics.mean(diff))
print('MAX mld_nefsc:     ',max(new_mld_nefsc))
print('MIN mld_nefsc:     ',min(new_mld_nefsc))
print('MAX pointstouse:   ',max(pointstouse))
print('MIN pointstouse:   ',min(pointstouse))
# Out:
# MAX diff:           7.803338661193848
# MIN diff:           -7.701949295043946
# MEAN diff:          -1.0652110349990496
# MAX mld_nefsc:      24.842433787372972
# MIN mld_nefsc:      4.734999999999999
# MAX pointstouse:    26.209143
# MIN pointstouse:    6.0867033

# %%
ind = np.where(np.isnan(pointstouse))[0]
print(ind)
for x in ind:
    new_mld_nefsc.pop(x)
    pointstouse.pop(x)
print(len(new_mld_nefsc))
print(len(pointstouse))
# Out:
# []
# 3130
# 3130

# %%
from scipy.stats import gaussian_kde

plt.figure(figsize=(8, 8))
plt.xlim(0,25)
plt.ylim(0,25)
# plt.plot(tempMLD, densMLD, color='blue')
# plt.plot(mld_nefsc, pointstouse, color='blue')
# plt.scatter(mld_nefsc, new_mld_nefsc, s = 15, c = 'blue')
# plt.title('Entire Region',fontsize = 15,fontweight="bold")
plt.xlabel('Obs SST (°C)',size = 15)
plt.ylabel('GLORYS SST (°C)',fontsize = 15)
xy = np.vstack([new_mld_nefsc,pointstouse])
dens = gaussian_kde(xy)(xy)
new_dens = dens * 100
plt.scatter(new_mld_nefsc, pointstouse, c=new_dens, s=20, vmin = 0, vmax = 2, cmap = plt.cm.jet, edgecolor='')
ident = [0.0, 220]
plt.plot(ident,ident,color='grey',alpha = 0.7,linewidth=0.7)
# plt.colorbar(label='Gaussian KDE Point Density', size = 15
# plt.colorbar().set_label(label='Gaussian KDE Point Density',size=15, rotation = 90)
# plt.colorbar().ax.tick_params(labelsize=12)
plt.grid(True)
plt.yticks([0,5,10,15,20,25], fontsize = 15)
plt.xticks([0,5,10,15,20,25], fontsize = 15)
plt.savefig('glorys.png')   
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(8, 8))
plt.xlim(-12,12)
plt.ylim(0,50)

# plt.ylim(0,1000)
plt.grid(True)
plt.hist(diff, bins = 30,zorder = 50)
plt.title('DEC Diff between Obs. SST and GLORYS SST',fontsize = 15,fontweight="bold")
plt.xlabel('Obs. SST - GLORYS SST (degrees C)', fontsize = 15)
plt.ylabel('Count', fontsize = 15)
plt.xticks([-12,-10,-8,-6,-4,-2,0,2,4,6,8,10,12], rotation = 90, fontsize = 12)
plt.yticks([0,10,20,30,40,50], fontsize = 12)
plt.savefig('glorys.png')
plt.show()

# %%
print(pointstouse)
# Out:
# [6.534959, 7.894376, 6.485153, 5.8552504, 3.9757996, 3.995575, 4.128147, 6.1116066, 4.1677, 4.1127663, 4.08127, 4.063692]

# %%
lat_input = [40.25, 40.0817, 40.26, 40.3733, 40.585, 40.7067, 40.6283, 40.4533, 40.5467, 40.665, 40.6183, 40.8817]

# %%
lonneg = [-69.275, -69.2117, -68.9383, -68.2783, -68.275, -67.8783, -67.7783, -67.7533, -67.655, -67.585, -67.4567, -67.51]

# %%
jan_1993=DS.sel(time=slice('1993-01-01','1993-01-31'))

# %%
touse = jan_1993.sel(time=jan_1993.time.dt.day==7)
print(type(touse.thetao))
print(touse.thetao.shape)
usenow = touse.thetao
tousedflat = usenow['latitude']
print(tousedflat.shape)
tousedflon = usenow['longitude']
print(tousedflon.shape)
# Out:
# <class 'xarray.core.dataarray.DataArray'>
# (1, 1, 133, 181)
# (133,)
# (181,)

# %%
import numpy as np

lat = np.array(usenow['latitude'][:])
long = np.array(usenow['longitude'][:])

def get_data(lat_input, long_input):
    lat_index  = np.nanargmin((lat-lat_input)**2)
    long_index = np.nanargmin((long-long_input)**2)
    return usenow[long_index][lat_index]

# %%
print(mld_locate_date[0][0])
# Out:
# [      nan       nan       nan       nan       nan       nan       nan
#        nan       nan       nan       nan       nan       nan       nan
#        nan       nan       nan 16.159275 16.600208 17.270393 17.655659
#  17.977936 18.284096 18.595387 19.056826 19.737267 20.193579 20.40379
#  21.016113 21.309092 21.615253 22.641407 23.86166  24.511337 24.663687
#  24.845333 25.089237 25.265022 25.3932   25.391003 25.330942 25.301645
#  25.419569 24.544298 23.756187 23.983246 24.296    24.330423 24.341412
#  24.274757 24.051363 23.668295 23.082338 22.264198 21.4944   20.990479
#  20.765617 20.699697 20.65282  20.60741  20.540026 20.451399 20.426497
#  20.477768 20.534166 20.564928 20.617664 20.70629  20.783197 20.824213
#  20.84985  20.863033 20.868893 20.82934  20.76049  20.663809 20.600819
#  20.654285 20.731194 20.543688 20.429426 20.41551  20.215551 19.998016
#  20.12473  20.384747 20.58983  20.941404 21.314219 21.508316 21.66506
#  21.66506  21.37135  20.999268 20.710684 20.345196 20.176    20.225807
#  20.251442 20.318094 20.532701 20.857906 21.178717 21.403576 21.535418
#  21.601337 21.604267 21.510513 21.379406 21.223396 21.09009  20.982422
#  20.925291 20.897457 20.914305 20.931883 20.93408  20.917967 20.913572
#  21.007324 21.180182 21.372814 21.573503 21.769066 21.882595 21.860622
#  21.637959 21.397717 21.24244  21.109135 21.023438 21.001465 21.01831
#  21.040285 21.03003  20.960447 20.81396  20.48729  20.146702 20.022919
#  19.969452 19.896938 19.869839 19.940886 20.065401 20.173803 20.230934
#  20.218483 20.16648  20.151829 20.20603  20.28953  20.347393 20.359112
#  20.3408   20.301249 20.236794 20.145237 20.05588  19.995087 19.970184
#  19.984833 20.032442 20.09763  20.170874 20.228737 20.255104 20.227272
#  20.091036 19.904263 19.84054  19.9299   19.99289  19.96872  19.92697
#  19.890347 19.851528 19.815638 19.787073 19.758507 19.72335 ]

# %%
pointstouse = []
for x in range(len(date)):
    locate_date = jan_1993.sel(time=jan_1993.time.dt.day==7)
    mld_locate_date = locate_date.thetao.values[0][0]
    
    lat = np.array(usenow['latitude'][:])
    long = np.array(usenow['longitude'][:])

    distanceslat = []; distanceslon = []
    for i in range(133):
        distanceslat.append((lat_input[x] - lat[i])**2)
        index_min_lat = min(range(len(distanceslat)), key=distanceslat.__getitem__)
    for ii in range(181):
        distanceslon.append((lonneg[x] - long[ii])**2)
        index_min_lon = min(range(len(distanceslon)), key=distanceslon.__getitem__)
    lat_index_use, lon_index_use = index_min_lat, index_min_lon
    pointstouse.append(mld_locate_date[lat_index_use, lon_index_use])

# %%
lat = np.array(usenow['latitude'][:])
long = np.array(usenow['longitude'][:])

distanceslat = []; distanceslon = []
for i in range(133):
    distanceslat.append((36 - lat[i])**2)
    index_min_lat = min(range(len(distanceslat)), key=distanceslat.__getitem__)
print(index_min_lat)
for ii in range(181):
    distanceslon.append((-68.3067 - long[i]**2))
    index_min_lon = min(range(len(distanceslon)), key=distanceslon.__getitem__)
print(index_min_lon)

x, y = index_min_lat, index_min_lon
# Out:
# 12
# 0
