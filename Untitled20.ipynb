# %%
# Import libraries
import matplotlib.pyplot as plt; import numpy as np; import netCDF4; from netCDF4 import Dataset
import pandas as pd; import numpy.ma as ma; import time as timeit; import os; import math
import itertools; import scipy.io; import mat73; import collections
import cartopy; import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from matplotlib.ticker import FuncFormatter
from matplotlib.ticker import AutoMinorLocator; from matplotlib.ticker import FixedLocator
from shapely.geometry import Point
from shapely.geometry.polygon import Polygon
# %matplotlib inline
import statistics; import xarray as xr; import matplotlib as mpl; import gsw

# %%
newv = [['', '', '37.00', '', '', '76.00'], ['', '', '36.00', '', '', '75.50'], ['', '', '35.50', '', '', '75.00'], ['', '', '36.00', '', '', '74.75'], ['', '', '37.40', '', '', '74.50'], ['', '', '39.50', '', '', '72.00'], ['', '', '40.50', '', '', '74.00'], ['', '', '39.40', '', '', '74.25'], ['', '', '37.00', '', '', '76.00']]
lon_v = []; lat_v = []
for i in range(9): 
    v1 = newv[i][2]
    lat_v.append(v1)
    v3 = newv[i][5]
    lon_v.append(v3)
lonlist_v = [float(i) for i in lon_v]; latlist_v = [float(i) for i in lat_v]
df_v = pd.DataFrame({'lon': lonlist_v, 'lat': latlist_v,})
lonlist_v_plot = [float(i)*-1 for i in lon_v]; latlist_v = [float(i) for i in lat_v]
df_v_plot = pd.DataFrame({'lon': lonlist_v_plot, 'lat': latlist_v,})
x_v = df_v_plot['lon']; y_v = df_v_plot['lat']

lonlist_vneg = [float(i)*-1 for i in lon_v]
df_v_plottable = pd.DataFrame({'lon': lonlist_vneg, 'lat': latlist_v,})
polygon_v = Polygon(df_v.values.tolist())

# %%
neww = [['', '', '40.00', '', '', '69.50'], ['', '', '40.30', '', '', '68.00'], ['', '', '40.40', '', '', '67.50'], ['', '', '40.60', '', '', '67.00'], ['', '', '40.80', '', '', '66.50'], ['', '', '41.45', '', '', '66.00'], ['', '', '41.80', '', '', '65.70'], ['', '', '42.10', '', '', '66.00'], ['', '', '42.10', '', '', '67.00'], ['', '', '42.10', '', '', '67.50'], ['', '', '41.80', '', '', '68.00'], ['', '', '41.10', '', '', '69.00'], ['', '', '41.00', '', '', '69.50'], ['', '', '40.00', '', '', '69.50']]
lon_w = []; lat_w = []
for i in range(14): 
    w1 = neww[i][2]
    lat_w.append(w1)
    w3 = neww[i][5]
    lon_w.append(w3)
lonlist_w = [float(i) for i in lon_w]; latlist_w = [float(i) for i in lat_w]
lonlist_wneg = [float(i)*-1 for i in lon_w]
df_w = pd.DataFrame({'lon': lonlist_w, 'lat': latlist_w,})
df_w_plottable = pd.DataFrame({'lon': lonlist_wneg, 'lat': latlist_w,})

lonlist_w_plot = [float(i)*-1 for i in lon_w]; latlist_w = [float(i) for i in lat_w]
df_w_plot = pd.DataFrame({'lon': lonlist_w_plot, 'lat': latlist_w,})
x_w = df_w_plot['lon']; y_w = df_w_plot['lat']
polygon_w = Polygon(df_w.values)

# %%
newy = [['', '', '41.80', '', '', '68.00'], ['', '', '42.10', '', '', '67.50'], ['', '', '42.10', '', '', '67.00'], ['', '', '42.10', '', '', '66.00'], ['', '', '43.00', '', '', '66.00'], ['', '', '44.20', '', '', '66.50'], ['', '', '44.20', '', '', '67.00'], ['', '', '44.20', '', '', '68.00'], ['', '', '41.80', '', '', '68.00']]
lon_y = []; lat_y = []
for i in range(9): 
    y1 = newy[i][2]
    lat_y.append(y1)
    y3 = newy[i][5]
    lon_y.append(y3)
lonlist_y = [float(i) for i in lon_y]; latlist_y = [float(i) for i in lat_y]
df_y = pd.DataFrame({'lon': lonlist_y, 'lat': latlist_y,})
lonlist_y_plot = [float(i)*-1 for i in lon_y]; latlist_y = [float(i) for i in lat_y]
df_y_plot = pd.DataFrame({'lon': lonlist_y_plot, 'lat': latlist_y,})
x_y = df_y_plot['lon']; y_y = df_y_plot['lat']

lonlist_yneg = [float(i)*-1 for i in lon_y]
df_y_plottable = pd.DataFrame({'lon': lonlist_yneg, 'lat': latlist_y,})
polygon_y = Polygon(df_y.values)

# %%
newt = [['', '', '42.20', '', '', '70.50'], ['', '', '42.00', '', '', '70.00'], ['', '', '41.10', '', '', '69.00'], ['', '', '41.80', '', '', '68.00'], ['', '', '44.20', '', '', '68.00'], ['', '', '43.90', '', '', '69.00'], ['', '', '43.70', '', '', '70.00'], ['', '', '43.00', '', '', '70.50'], ['', '', '42.20', '', '', '70.50']]
lon_t = []; lat_t = []
for i in range(9): 
    t1 = newt[i][2]
    lat_t.append(t1)
    t3 = newt[i][5]
    lon_t.append(t3)
lonlist_t = [float(i) for i in lon_t]; latlist_t = [float(i) for i in lat_t]
df_t = pd.DataFrame({'lon': lonlist_t, 'lat': latlist_t,})
lonlist_t_plot = [float(i)*-1 for i in lon_t]; latlist_t = [float(i) for i in lat_t]
df_t_plot = pd.DataFrame({'lon': lonlist_t_plot, 'lat': latlist_t,})
x_t = df_t_plot['lon']; y_t = df_t_plot['lat']

lonlist_tneg = [float(i)*-1 for i in lon_t]
df_t_plottable = pd.DataFrame({'lon': lonlist_tneg, 'lat': latlist_t,})
polygon_t = Polygon(df_t.values)

# %%
newx = [['', '', '40.50', '', '', '74.00'], ['', '', '39.50', '', '', '72.00'], ['', '', '40.00', '', '', '71.40'], ['', '', '40.00', '', '', '69.50'], ['', '', '41.00', '', '', '69.50'], ['', '', '41.10', '', '', '70.00'], ['', '', '41.00', '', '', '72.00'], ['', '', '40.50', '', '', '74.00']]
lon_x = []; lat_x = []
for i in range(8): 
    x1 = newx[i][2]
    lat_x.append(x1)
    x3 = newx[i][5]
    lon_x.append(x3)
lonlist_x = [float(i) for i in lon_x]; latlist_x = [float(i) for i in lat_x]
df_x = pd.DataFrame({'lon': lonlist_x, 'lat': latlist_x,})
lonlist_x_plot = [float(i)*-1 for i in lon_x]; latlist_x = [float(i) for i in lat_x]
df_x_plot = pd.DataFrame({'lon': lonlist_x_plot, 'lat': latlist_x,})
x_x = df_x_plot['lon']; y_x = df_x_plot['lat']

lonlist_xneg = [float(i)*-1 for i in lon_x]
df_x_plottable = pd.DataFrame({'lon': lonlist_xneg, 'lat': latlist_x,})
polygon_x = Polygon(df_x.values.tolist())

# %%
dens_threshold = 0.03

# %%
glorys12v1 ='global-reanalysis-phy-001-030-daily_1596465428590.nc'
DS=xr.open_dataset(glorys12v1)

# %%
countwithinpolygon = []; densmld = []; obs_lat = []; obs_lon = []; date_no = []; bottomdepth = []; years = []
yearwithdata = []; datefull = []; finallatestdepth = []; glorysmld = []
glorys_lat = []; glorys_lon = []; glorys_lat_index = []; glorys_lon_index = []

for year in range(1993,2019):
    filename = 'casts_{}.mat'.format(year)
    file = scipy.io.loadmat(filename,squeeze_me=True)
    npfile = file['casts_{}'.format(year)]
    
    lat_intermediate = []; lon_intermediate = []; p_intermediate = []; counterii = []
    t_intermediate = []; yd_intermediate = []; sal_intermediate = []; floor_intermediate = []
    
    for i in range(len(npfile)):
        yd = npfile[i]['yd']
        p = npfile[i]['p']
        s = npfile[i]['s']
        t = npfile[i]['t']
        gear = npfile[i]['gear']
        floordepth = npfile[i]['depth']
#         if (yd >= 0 and yd <= 365) or (yd >= 0 and yd <= 59):
        if yd > 334 and yd <= 365:  # and floordepth <= 200
            lat_intermediate.append(npfile[i]['lat'])
            lon_intermediate.append(npfile[i]['lon'])
            p_intermediate.append(npfile[i]['p'])
            t_intermediate.append(npfile[i]['t'])
            yd_intermediate.append(npfile[i]['yd'])
            sal_intermediate.append(npfile[i]['s'])
            floor_intermediate.append(npfile[i]['depth'])
    month_df = pd.DataFrame({'day': yd_intermediate,'lon': lon_intermediate,'lat': lat_intermediate, 'p': p_intermediate, 't': t_intermediate,'depth': floor_intermediate, 's': sal_intermediate})
    newdf = pd.DataFrame({'lon': lon_intermediate,'lat': lat_intermediate,'date': yd_intermediate})
    for ii in range(len(month_df)):
        new = newdf.iloc[ii].values
        point = Point(new)
        if isinstance(month_df['p'].iloc[ii], int) or isinstance(month_df['p'].iloc[ii], float) or isinstance(month_df['t'].iloc[ii], int) or isinstance(month_df['t'].iloc[ii], float):
            pass
        elif polygon_x.contains(point) == True or polygon_y.contains(point) == True or polygon_w.contains(point) == True or polygon_t.contains(point) == True or polygon_v.contains(point) == True:
            SA = gsw.SA_from_SP(month_df['s'].iloc[ii],month_df['p'].iloc[ii],month_df['lon'].iloc[ii],month_df['lat'].iloc[ii])
            CT = gsw.CT_from_pt(SA,month_df['t'].iloc[ii])
            DENS = gsw.sigma0(SA,CT)
            pt_df = pd.DataFrame({'p': month_df['p'].iloc[ii],'t': month_df['t'].iloc[ii], 's': month_df['s'].iloc[ii], 'CT': CT, 'DENSMLD': DENS}) 
            df_ptsnew = pt_df.dropna()
            df_final = pd.DataFrame(df_ptsnew.values)
            countwithinpolygon.append(1)
            l=[i for i in df_final[0] if i<=5] 
            if len(l) > 0:
                surfaceval = []
                numrange = []
                for iii in range(len(l)):
                    val = df_final[4][iii]
                    numrange.append(iii)
                    surfaceval.append(val)            
            surfacevalmean = statistics.mean(surfaceval)
            densfin = []; tempfin = []; pressurefin = []; salfin = []
            for iii in range(numrange[-1],len(df_final)): #for iii in range(numrange[-1]+1,len(df_final)):
                tempfin.append(df_final[1][iii])
                pressurefin.append(df_final[0][iii])
                salfin.append(df_final[2][iii])
                densfin.append(df_final[4][iii])
            d = {'temp': list(reversed(tempfin)), 'sal': list(reversed(salfin)), 'pressure': list(reversed(pressurefin)),'density': list(reversed(densfin))}
            dunreversed = {'temp': list(tempfin), 'sal': list(salfin), 'pressure': list(pressurefin), 'density': list(densfin)}
            dffinunreversed = pd.DataFrame(dunreversed)
            dffin = pd.DataFrame(d)
            
            for ix in range(len(dffinunreversed)):
                if dffinunreversed.at[ix,'density'] >= (surfacevalmean - dens_threshold) and dffinunreversed.at[ix,'density'] <= (surfacevalmean + dens_threshold):
                    if dffinunreversed.at[len(dffinunreversed)-1,'density'] <= (surfacevalmean + dens_threshold) and dffinunreversed.at[len(dffinunreversed)-1,'density'] >= (surfacevalmean - dens_threshold):
                        looknow = list(dffinunreversed['density'].values)
                        looknow2 = [i for i in looknow if i >= (surfacevalmean + dens_threshold)]
                        looknow3 = [i for i in looknow if i <= (surfacevalmean - dens_threshold)]
                        if len(looknow2) == 0 and len(looknow3) == 0:
                            if (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] <= 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 5)) or (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] > 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 10)):
                                densmld.append(month_df['depth'].iloc[ii])
                                obs_lat.append(month_df['lat'].iloc[ii])
                                obs_lon.append(month_df['lon'].iloc[ii])
                                date_no.append(month_df['day'].iloc[ii])
                                bottomdepth.append(month_df['depth'].iloc[ii])
                                years.append(year)
                                counterii.append(ii)
                                break
                            else:#here
                                break 
                        else:
                            if (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] <= 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 5)) or (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] > 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 10)):
                                for ix in range(len(dffinunreversed['density'])):
                                    if dffinunreversed.at[ix,'density'] >= (surfacevalmean - dens_threshold) and dffinunreversed.at[ix,'density'] <= (surfacevalmean + dens_threshold):
                                        pass
                                    else:
                                        densmld.append(month_df['depth'].iloc[ii])
                                        obs_lat.append(month_df['lat'].iloc[ii])
                                        obs_lon.append(month_df['lon'].iloc[ii])
                                        date_no.append(month_df['day'].iloc[ii])
                                        bottomdepth.append(month_df['depth'].iloc[ii])
                                        years.append(year)
                                        counterii.append(ii)
                                        plt.show()
                                        break
                                break
                            else:
                                break
                    else: 
                        if dffinunreversed.at[ix,'density'] <= (surfacevalmean - dens_threshold) or dffinunreversed.at[ix,'density'] >= (surfacevalmean + dens_threshold):
                            if (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] <= 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 5) and dffinunreversed.at[ix,'pressure'] <= (month_df['depth'].iloc[ii] - 5)) or (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] > 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 10) and dffinunreversed.at[ix,'pressure'] <= (month_df['depth'].iloc[ii] - 10)):
                                pass
                            else:
                                densmld.append(dffinunreversed.at[ix,'pressure'])
                                obs_lat.append(month_df['lat'].iloc[ii])
                                obs_lon.append(month_df['lon'].iloc[ii])
                                date_no.append(month_df['day'].iloc[ii])
                                bottomdepth.append(month_df['depth'].iloc[ii])
                                years.append(year)
                                counterii.append(ii)
                                break           
                        else: 
                            if dffinunreversed.at[ix,'density'] >= (surfacevalmean + dens_threshold) or dffinunreversed.at[ix,'density'] <= (surfacevalmean - dens_threshold):
                                break 
                elif dffinunreversed.at[ix,'density'] <= (surfacevalmean - dens_threshold) or dffinunreversed.at[ix,'density'] >= (surfacevalmean + dens_threshold):
                    if (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] <= 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 5) and dffinunreversed.at[ix,'pressure'] <= (month_df['depth'].iloc[ii] - 5)) or (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] > 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 10) and dffinunreversed.at[ix,'pressure'] <= (month_df['depth'].iloc[ii] - 10)):
                        pass
                    else:
                        for ix in range(len(dffinunreversed['density'])):
                            if dffinunreversed.at[ix,'density'] >= (surfacevalmean - dens_threshold) and dffinunreversed.at[ix,'density'] <= (surfacevalmean + dens_threshold):
                                pass
                            else:
                                densmld.append(dffinunreversed.at[ix,'pressure'])
                                obs_lat.append(month_df['lat'].iloc[ii])
                                obs_lon.append(month_df['lon'].iloc[ii])
                                date_no.append(month_df['day'].iloc[ii])
                                bottomdepth.append(month_df['depth'].iloc[ii])
                                years.append(year)
                                counterii.append(ii)
                                break
                        break
                else: 
                    break
                                
    inlat = []; inlon = []; date = []
    g_lat = []; g_lon = []; g_indexlon = []; g_indexlat = []
    for timer in counterii:
        inlat.append(newdf['lat'][timer])
        inlon.append(newdf['lon'][timer])
        date.append(newdf['date'][timer])
    datefull.append(date)
    for x in range(len(date)):
        use=DS.sel(time=slice('{}-12-01'.format(year),'{}-12-31'.format(year))) 
        locate_date = use.sel(time=use.time.dt.day==(date[x])-334)
        mld_locate_date = locate_date.mlotst.values[0]
    
        lat = np.array(locate_date.mlotst['latitude'][:])
        long = np.array(locate_date.mlotst['longitude'][:])
    
        lonneg = [float(i)*-1 for i in inlon]
        distanceslat = []; distanceslon = []
        for i in range(133):
            distanceslat.append((inlat[x] - lat[i])**2)
            index_min_lat = min(range(len(distanceslat)), key=distanceslat.__getitem__)
        for ii in range(181):
            distanceslon.append((lonneg[x] - long[ii])**2)
            index_min_lon = min(range(len(distanceslon)), key=distanceslon.__getitem__)
        lat_index_use, lon_index_use = index_min_lat, index_min_lon
        gloryslonval = float(DS['longitude'][index_min_lon])
        gloryslatval = float(DS['latitude'][index_min_lat])
        g_lat.append(gloryslatval)
        glorys_lat.append(gloryslatval)
        g_lon.append(gloryslonval)
        glorys_lon.append(gloryslonval)
        g_indexlat.append(index_min_lat)
        glorys_lat_index.append(index_min_lat)
        g_indexlon.append(index_min_lon)
        glorys_lon_index.append(index_min_lon)
        glorysmld.append(mld_locate_date[lat_index_use, lon_index_use]) 
    print('**********')
    print(year)
    print(len(countwithinpolygon))
    print(len(densmld))
    print(len(obs_lat))
    print(len(obs_lon))
    print(len(date_no))
    print(len(bottomdepth))
    print(len(years))
    print(len(glorysmld))
    print(len(glorys_lat))
    print(len(glorys_lon))
    print(len(glorys_lat_index))
    print(len(glorys_lon_index))
    print('')
# Out:
# **********
# 1993
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
#
# **********
# 1994
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
#
# **********
# 1995
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
#
# **********
# 1996
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
#
# **********
# 1997
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
#
# **********
# 1998
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
#
# **********
# 1999
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
#
# **********
# 2000
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
#
# **********
# 2001
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
#
# **********
# 2002
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
#
# **********
# 2003
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
#
# **********
# 2004
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
#
# **********
# 2005
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
#
# **********
# 2006
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
#
# **********
# 2007
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
#
# **********
# 2008
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
#
# **********
# 2009
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
# 117
#
# **********
# 2010
# 186
# 181
# 181
# 181
# 181
# 181
# 181
# 181
# 181
# 181
# 181
# 181
#
# **********
# 2011
# 258
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
#
# **********
# 2012
# 258
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
#
# **********
# 2013
# 258
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
#
# **********
# 2014
# 258
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
#
# **********
# 2015
# 258
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
#
# **********
# 2016
# 258
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
#
# **********
# 2017
# 258
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
#
# **********
# 2018
# 258
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244
# 244

# %%
pandas = pd.DataFrame({'obs_lat': obs_lat,'obs_lon': obs_lon, 'glorys_lat': glorys_lat, 'glorys_lon': glorys_lon,
                      'glorys_lat_index': glorys_lat_index, 'glorys_lon_index': glorys_lon_index, 
                      'bottomdepth':bottomdepth,'year':years, 'date_no':date_no, '003densmld':densmld, 'glorys_mld': glorysmld})

# %%
pandas_003new = pandas.assign(location=[*zip(pandas.glorys_lat_index, pandas.glorys_lon_index, pandas.year, pandas.obs_lon, pandas.obs_lat, pandas.date_no)])

# %%
print(len(pandas_003new))
# Out:
# 244

# %%
pandas_003newdd = pandas_003new.drop_duplicates(subset=['location'])

# %%
print(len(pandas_003newdd))
# Out:
# 244

# %%
filenow = 'glorys12v1_depth.nc'
BC=Dataset(filenow); BS=xr.open_dataset(filenow)
glorysdepth = np.asarray(BS['depth'].values)

# %%
# print(pandas_00100302new.shape)
ZC = pd.read_csv('12.csv') # change according to month
print(ZC.shape)
file_in ='12.nc' # change according to month
NC=Dataset(file_in); DS=xr.open_dataset(file_in)
# Out:
# (258, 9)

# %%
ZC = ZC.assign(location=[*zip(ZC.glorys_index_lat, ZC.glorys_index_lon, ZC.year, ZC.obs_lon, ZC.obs_lat, ZC.date)])
ZCdd = ZC.drop_duplicates(subset=['location'])

# %%
ZC['copy_index'] = ZC.index

# %%
print(ZC)
# Out:
#      Unnamed: 0  obs_lat  obs_lon  date  year  glorys_index_lat  \
# 0             0  40.9000  70.6833   335  1993                71
# 1             1  41.0350  70.3667   335  1993                72
# 2             2  41.0650  70.0300   335  1993                73
# 3             3  40.9317  70.1333   335  1993                71
# 4             4  40.9300  69.9850   335  1993                71
# ..          ...      ...      ...   ...   ...               ...
# 253         253  41.0383  70.2283   342  2011                72
# 254         254  41.0367  70.2817   342  2011                72
# 255         255  41.0367  70.3333   342  2011                72
# 256         256  41.0367  70.3983   342  2011                72
# 257         257  41.0600  70.5133   342  2011                73
#
#      glorys_index_lon  glorys_lat  glorys_lon  \
# 0                  88   40.916668  -70.666664
# 1                  92   41.000000  -70.333336
# 2                  96   41.083332  -70.000000
# 3                  94   40.916668  -70.166664
# 4                  96   40.916668  -70.000000
# ..                ...         ...         ...
# 253                93   41.000000  -70.250000
# 254                93   41.000000  -70.250000
# 255                92   41.000000  -70.333336
# 256                91   41.000000  -70.416664
# 257                90   41.083332  -70.500000
#
#                                   location  copy_index
# 0       (71, 88, 1993, 70.6833, 40.9, 335)           0
# 1     (72, 92, 1993, 70.3667, 41.035, 335)           1
# 2       (73, 96, 1993, 70.03, 41.065, 335)           2
# 3    (71, 94, 1993, 70.1333, 40.9317, 335)           3
# 4       (71, 96, 1993, 69.985, 40.93, 335)           4
# ..                                     ...         ...
# 253  (72, 93, 2011, 70.2283, 41.0383, 342)         253
# 254  (72, 93, 2011, 70.2817, 41.0367, 342)         254
# 255  (72, 92, 2011, 70.3333, 41.0367, 342)         255
# 256  (72, 91, 2011, 70.3983, 41.0367, 342)         256
# 257    (73, 90, 2011, 70.5133, 41.06, 342)         257
#
# [258 rows x 11 columns]

# %%
merged_large = pd.merge(ZC, pandas_003new, left_on=['location'], 
                        right_on = ['location'], left_index=True, how='outer', sort=False)

# %%
merged_large.isnull().sum()
# Out:
# Unnamed: 0           0
# obs_lat_x            0
# obs_lon_x            0
# date                 0
# year_x               0
# glorys_index_lat     0
# glorys_index_lon     0
# glorys_lat_x         0
# glorys_lon_x         0
# location             0
# copy_index           0
# obs_lat_y           14
# obs_lon_y           14
# glorys_lat_y        14
# glorys_lon_y        14
# glorys_lat_index    14
# glorys_lon_index    14
# bottomdepth         14
# year_y              14
# date_no             14
# 003densmld          14
# glorys_mld          14
# dtype: int64

# %%
marged = merged_large.dropna(subset=['copy_index'])
margeddd = merged_large.drop_duplicates(subset=['copy_index'])

# %%
print(len(margeddd))
# Out:
# 258

# %%
print(margeddd)
# Out:
#        Unnamed: 0  obs_lat_x  obs_lon_x  date  year_x  glorys_index_lat  \
# 0.0             0    40.9000    70.6833   335    1993                71
# 1.0             1    41.0350    70.3667   335    1993                72
# 2.0             2    41.0650    70.0300   335    1993                73
# 3.0             3    40.9317    70.1333   335    1993                71
# 4.0             4    40.9300    69.9850   335    1993                71
# ...           ...        ...        ...   ...     ...               ...
# 240.0         253    41.0383    70.2283   342    2011                72
# 241.0         254    41.0367    70.2817   342    2011                72
# NaN           255    41.0367    70.3333   342    2011                72
# 242.0         256    41.0367    70.3983   342    2011                72
# 243.0         257    41.0600    70.5133   342    2011                73
#
#        glorys_index_lon  glorys_lat_x  glorys_lon_x  \
# 0.0                  88     40.916668    -70.666664
# 1.0                  92     41.000000    -70.333336
# 2.0                  96     41.083332    -70.000000
# 3.0                  94     40.916668    -70.166664
# 4.0                  96     40.916668    -70.000000
# ...                 ...           ...           ...
# 240.0                93     41.000000    -70.250000
# 241.0                93     41.000000    -70.250000
# NaN                  92     41.000000    -70.333336
# 242.0                91     41.000000    -70.416664
# 243.0                90     41.083332    -70.500000
#
#                                     location  ...  obs_lon_y  glorys_lat_y  \
# 0.0       (71, 88, 1993, 70.6833, 40.9, 335)  ...    70.6833     40.916668
# 1.0     (72, 92, 1993, 70.3667, 41.035, 335)  ...    70.3667     41.000000
# 2.0       (73, 96, 1993, 70.03, 41.065, 335)  ...    70.0300     41.083332
# 3.0    (71, 94, 1993, 70.1333, 40.9317, 335)  ...    70.1333     40.916668
# 4.0       (71, 96, 1993, 69.985, 40.93, 335)  ...    69.9850     40.916668
# ...                                      ...  ...        ...           ...
# 240.0  (72, 93, 2011, 70.2283, 41.0383, 342)  ...    70.2283     41.000000
# 241.0  (72, 93, 2011, 70.2817, 41.0367, 342)  ...    70.2817     41.000000
# NaN    (72, 92, 2011, 70.3333, 41.0367, 342)  ...        NaN           NaN
# 242.0  (72, 91, 2011, 70.3983, 41.0367, 342)  ...    70.3983     41.000000
# 243.0    (73, 90, 2011, 70.5133, 41.06, 342)  ...    70.5133     41.083332
#
#        glorys_lon_y  glorys_lat_index  glorys_lon_index  bottomdepth  year_y  \
# 0.0      -70.666664              71.0              88.0         53.0  1993.0
# 1.0      -70.333336              72.0              92.0         40.0  1993.0
# 2.0      -70.000000              73.0              96.0         25.0  1993.0
# 3.0      -70.166664              71.0              94.0         24.0  1993.0
# 4.0      -70.000000              71.0              96.0         22.0  1993.0
# ...             ...               ...               ...          ...     ...
# 240.0    -70.250000              72.0              93.0         30.0  2011.0
# 241.0    -70.250000              72.0              93.0         35.0  2011.0
# NaN             NaN               NaN               NaN          NaN     NaN
# 242.0    -70.416664              72.0              91.0         41.0  2011.0
# 243.0    -70.500000              73.0              90.0         42.0  2011.0
#
#        date_no  003densmld  glorys_mld
# 0.0      335.0        53.0   50.965916
# 1.0      335.0        40.0   37.079990
# 2.0      335.0        25.0   19.837032
# 3.0      335.0        24.0   25.940735
# 4.0      335.0        22.0   21.668144
# ...        ...         ...         ...
# 240.0    342.0        20.0   20.142218
# 241.0    342.0        13.0   20.142218
# NaN        NaN         NaN         NaN
# 242.0    342.0        30.0   17.853331
# 243.0    342.0        23.0   18.158514
#
# [258 rows x 22 columns]

# %%
print(glorysdepth[22])
print(len(glorysdepth))
# Out:
# 109.7293
# 32

# %%
target = 11
res = min(enumerate(glorysdepth), key=lambda x: abs(target - x[1]))
print(res)
# Out:
# (8, 11.405)

# %%
def closest(list, Number):
    aux = []
    for valor in list:
        aux.append(abs(Number-valor))

    return aux.index(min(aux))

# %%
print(closest(glorysdepth,20))
# Out:
# 11

# %%
print(len(margeddd))
# Out:
# 258

# %%
print(len(ZC))
# Out:
# 258

# %%
# margeddd['glorys_mld'][333]

# %%
newmarged = margeddd.set_index('copy_index')

# %%
print(newmarged)
# Out:
#             Unnamed: 0  obs_lat_x  obs_lon_x  date  year_x  glorys_index_lat  \
# copy_index
# 0                    0    40.9000    70.6833   335    1993                71
# 1                    1    41.0350    70.3667   335    1993                72
# 2                    2    41.0650    70.0300   335    1993                73
# 3                    3    40.9317    70.1333   335    1993                71
# 4                    4    40.9300    69.9850   335    1993                71
# ...                ...        ...        ...   ...     ...               ...
# 253                253    41.0383    70.2283   342    2011                72
# 254                254    41.0367    70.2817   342    2011                72
# 255                255    41.0367    70.3333   342    2011                72
# 256                256    41.0367    70.3983   342    2011                72
# 257                257    41.0600    70.5133   342    2011                73
#
#             glorys_index_lon  glorys_lat_x  glorys_lon_x  \
# copy_index
# 0                         88     40.916668    -70.666664
# 1                         92     41.000000    -70.333336
# 2                         96     41.083332    -70.000000
# 3                         94     40.916668    -70.166664
# 4                         96     40.916668    -70.000000
# ...                      ...           ...           ...
# 253                       93     41.000000    -70.250000
# 254                       93     41.000000    -70.250000
# 255                       92     41.000000    -70.333336
# 256                       91     41.000000    -70.416664
# 257                       90     41.083332    -70.500000
#
#                                          location  ...  obs_lon_y  \
# copy_index                                         ...
# 0              (71, 88, 1993, 70.6833, 40.9, 335)  ...    70.6833
# 1            (72, 92, 1993, 70.3667, 41.035, 335)  ...    70.3667
# 2              (73, 96, 1993, 70.03, 41.065, 335)  ...    70.0300
# 3           (71, 94, 1993, 70.1333, 40.9317, 335)  ...    70.1333
# 4              (71, 96, 1993, 69.985, 40.93, 335)  ...    69.9850
# ...                                           ...  ...        ...
# 253         (72, 93, 2011, 70.2283, 41.0383, 342)  ...    70.2283
# 254         (72, 93, 2011, 70.2817, 41.0367, 342)  ...    70.2817
# 255         (72, 92, 2011, 70.3333, 41.0367, 342)  ...        NaN
# 256         (72, 91, 2011, 70.3983, 41.0367, 342)  ...    70.3983
# 257           (73, 90, 2011, 70.5133, 41.06, 342)  ...    70.5133
#
#             glorys_lat_y  glorys_lon_y  glorys_lat_index  glorys_lon_index  \
# copy_index
# 0              40.916668    -70.666664              71.0              88.0
# 1              41.000000    -70.333336              72.0              92.0
# 2              41.083332    -70.000000              73.0              96.0
# 3              40.916668    -70.166664              71.0              94.0
# 4              40.916668    -70.000000              71.0              96.0
# ...                  ...           ...               ...               ...
# 253            41.000000    -70.250000              72.0              93.0
# 254            41.000000    -70.250000              72.0              93.0
# 255                  NaN           NaN               NaN               NaN
# 256            41.000000    -70.416664              72.0              91.0
# 257            41.083332    -70.500000              73.0              90.0
#
#             bottomdepth  year_y  date_no  003densmld  glorys_mld
# copy_index
# 0                  53.0  1993.0    335.0        53.0   50.965916
# 1                  40.0  1993.0    335.0        40.0   37.079990
# 2                  25.0  1993.0    335.0        25.0   19.837032
# 3                  24.0  1993.0    335.0        24.0   25.940735
# 4                  22.0  1993.0    335.0        22.0   21.668144
# ...                 ...     ...      ...         ...         ...
# 253                30.0  2011.0    342.0        20.0   20.142218
# 254                35.0  2011.0    342.0        13.0   20.142218
# 255                 NaN     NaN      NaN         NaN         NaN
# 256                41.0  2011.0    342.0        30.0   17.853331
# 257                42.0  2011.0    342.0        23.0   18.158514
#
# [258 rows x 21 columns]

# %%
print(glorysdepth)
# Out:
# [4.940250e-01 1.541375e+00 2.645669e+00 3.819495e+00 5.078224e+00
#  6.440614e+00 7.929560e+00 9.572997e+00 1.140500e+01 1.346714e+01
#  1.581007e+01 1.849556e+01 2.159882e+01 2.521141e+01 2.944473e+01
#  3.443415e+01 4.034405e+01 4.737369e+01 5.576429e+01 6.580727e+01
#  7.785385e+01 9.232607e+01 1.097293e+02 1.306660e+02 1.558507e+02
#  1.861256e+02 2.224752e+02 2.660403e+02 3.181274e+02 3.802130e+02
#  4.539377e+02 5.410889e+02]

# %%
##### Method 3
dens_thresh = []; indexer = []; bottommix = []; target_list = []
for i in range(len(DS['T'])):
    a = np.asarray(DS['T'][i])
    b = np.asarray(DS['S'][i])
    ctemp = []; density = []; salinity = []; temperature = []
    for ii in range(len(a)):
        CT = gsw.CT_from_pt(b[ii],a[ii])
        temperature.append(a[ii])
        salinity.append(b[ii])
        ctemp.append(CT)
        DENS = gsw.sigma0(b[ii],CT)
        density.append(DENS)
    dffinunreversed = pd.DataFrame({'temp': a,'sal': b,'CT': ctemp, 'density': density, 'depth':glorysdepth})
        
    CT7 = gsw.CT_from_pt(b[7],a[7])
    DENS7 = gsw.sigma0(b[7],CT7)
    
    CTdepth = gsw.CT_from_pt(b[7],a[7]-0.2)
    DENSdepth = gsw.sigma0(b[7],CTdepth)
    
    diff = DENSdepth - DENS7
    print(diff)
    dens_thresh.append(diff)
    indexer.append(i)
# Out:
# /anaconda3/lib/python3.7/site-packages/gsw/_wrapped_ufuncs.py:3394: RuntimeWarning: overflow encountered in sigma0
#   return _gsw_ufuncs.sigma0(SA, CT)
# 0.03518279164177329
# 0.03363977326216627
# 0.03142054488694157
# 0.032812669519671545
# 0.032348152178656164
# 0.03372135381118824
# 0.034578018206957495
# 0.034410483307738104
# 0.03507653737801775
# 0.03569984074374588
# 0.03664090250708796
# 0.04154868930845623
# 0.035582661906573776
# 0.03711402871158498
# 0.0360545442563307
# 0.03568526832373209
# 0.035068210178224035
# 0.03380371628441026
# 0.03292054223493324
# 0.03292978645868061
# 0.033521165455567825
# 0.03347840788819667
# 0.0338870012087682
# 0.035219745162976324
# 0.035300009428965495
# 0.03726509294006064
# 0.037816904518422234
# 0.03766992112332446
# 0.03649242213236903
# 0.036214859533174604
# 0.03517873076725664
# 0.034218824730714914
# 0.030780855998500556
# 0.029810260946533162
# 0.02977141332780775
# 0.02972184176041992
# 0.030102115206318558
# 0.029892338184254186
# 0.029859490259468657
# 0.029825287225776265
# 0.029622125553032674
# 0.030851093654064243
# 0.03130095751703266
# 0.03490080565688913
# 0.03587346615813658
# 0.035870914140105015
# 0.03587542807053978
# 0.03464847813643246
# 0.03360570424661091
# 0.03351118329032943
# 0.034690026687712816
# 0.03507794307415679
# 0.03560698387991579
# 0.03536584347943972
# 0.03463648122806262
# 0.033956804463514345
# 0.033949299094956586
# 0.03371804751623131
# 0.031097068175768072
# 0.03317226939725515
# 0.03286071482762054
# 0.030541445467861195
# 0.03276108126306099
# 0.032815681011925335
# 0.03317022842247752
# 0.03401889433985161
# 0.034290479416767994
# 0.03420595702527862
# 0.033619949015928796
# 0.033230960897299155
# 0.03262727915080177
# 0.03224609000358214
# 0.032075954521587846
# 0.03153388285136316
# 0.03148423303241543
# 0.03238802466830748
# 0.03294333396206639
# 0.033929083488601464
# 0.034041817565139354
# 0.03321481078751276
# 0.03270352170216029
# 0.03265238739004417
# 0.03299260014250649
# 0.03364678187176651
# 0.033318931276426156
# 0.032058609935347704
# 0.030888760870993792
# 0.03160868497889169
# 0.033238943822880174
# 0.03289890532778372
# 0.0328436830359351
# 0.032626653309989706
# 0.031883856794365784
# 0.030379843160062592
# 0.030935697656332195
# 0.030979421129359253
# 0.03238117921000594
# 0.03244866498516785
# 0.03649378303498452
# 0.033524171204362574
# 0.03713426150034138
# 0.038947050471733746
# 0.04115799287228583
# 0.033931546864778284
# 0.03324332419924758
# 0.03348814201058303
# 0.03402079403008429
# 0.03413622015250439
# 0.03439323873999456
# 0.03478254581909823
# 0.0337459669715372
# 0.03458472891247766
# 0.03558225781898727
# 0.03481802209671514
# 0.03480090694984028
# 0.03148174079774435
# 0.03185809995534328
# 0.031548641996096194
# 0.03196790426454754
# 0.03211859139946682
# 0.03224992769264645
# 0.031138769780682196
# 0.031265778141005285
# 0.03160058018465861
# 0.030498674095952083
# 0.031213989833304367
# 0.03126486038377152
# 0.03393476636233572
# 0.03393476636233572
# 0.03393476636233572
# 0.03108030740668255
# 0.03108030740668255
# 0.031193256851793194
# 0.031193256851793194
# 0.031193256851793194
# 0.03148782747666701
# 0.03148782747666701
# 0.03148782747666701
# 0.03142206097413691
# 0.03142206097413691
# 0.03149505591181878
# 0.03149505591181878
# 0.03164988615981201
# 0.03164988615981201
# 0.03168627263539747
# 0.03168627263539747
# 0.031612118064913375
# 0.031612118064913375
# 0.03160058018465861
# 0.03160058018465861
# 0.030804009841176594
# 0.031047529460693113
# 0.03166470178416603
# 0.03166470178416603
# 0.03166470178416603
# 0.032135352618979596
# 0.032135352618979596
# 0.031965562572395356
# 0.031965562572395356
# 0.03453776239780382
# 0.03453776239780382
# 0.035402034392518544
# 0.035402034392518544
# 0.035881793357475544
# 0.035881793357475544
# 0.03568026434595595
# 0.03568026434595595
# 0.03879386876769786
# 0.03879386876769786
# 0.033666703203380166
# 0.033666703203380166
# 0.033666703203380166
# 0.033666703203380166
# 0.034140657822945286
# 0.034140657822945286
# 0.03559035390890131
# 0.03559035390890131
# 0.03409466523021365
# 0.03409466523021365
# 0.03409466523021365
# 0.03308518564267615
# 0.03308518564267615
# 0.031004245875692504
# 0.030869172784150578
# 0.0324320849756532
# 0.0324320849756532
# 0.035772919402688785
# 0.03669633715321652
# 0.03692721487846029
# 0.03696407537699997
# 0.03696407537699997
# 0.03724161408672444
# 0.036107511320551566
# 0.03633326752810717
# 0.03743681806008681
# 0.03742812584846433
# 0.037164977112524866
# 0.037164977112524866
# 0.03749574652579213
# 0.038106356003936526
# 0.042895079875734154
# 0.042895079875734154
# 0.0453994367269388
# 0.04337363695890417
# 0.04337363695890417
# 0.04094637987691385
# 0.03836071430009724
# 0.03836071430009724
# 0.03845342979252564
# 0.03866004599126427
# 0.036953300524032784
# 0.035417992911334295
# 0.035417992911334295
# 0.036108244590423055
# 0.036108244590423055
# 0.03663774502547312
# 0.03663329256369252
# 0.03663329256369252
# 0.03778185465148454
# 0.0379330980802024
# 0.0379330980802024
# 0.037391538172414585
# 0.03751043702777679
# 0.03756687730947306
# 0.03684678821059606
# 0.03684678821059606
# 0.03297613923996323
# 0.03297613923996323
# 0.03287755707378892
# 0.03279410311074571
# 0.03279410311074571
# 0.032521994381795594
# 0.033302508204769765
# 0.03364624642654235
# 0.03364624642654235
# 0.03368239237806847
# 0.03344825180374755
# 0.03346425589256796
# 0.03344657386082872
# 0.03647955627616284
# 0.03647955627616284
# 0.03673548086919709
# 0.03673548086919709
# 0.037025975418259804
# 0.03725997032643136
# 0.03743332481235484
# 0.037100037600112046
# 0.03700207142060208
# 0.0368405164701926
# 0.036715302463107946
# 0.036609771256053136
# 0.03659967199462244
# 0.03669151300073281
# 0.036806875737397604
# 0.036806875737397604
# 0.03693582577102461
# 0.037082272428961005
# 0.03716438791627752

# %%
# ##### Method 2
# dens_thresh = []; indexer = []; bottommix = []; target_list = []
# for i in range(len(DS['T'])):
#     a = np.asarray(DS['T'][i])
#     b = np.asarray(DS['S'][i])
#     ctemp = []; density = []; salinity = []; temperature = []
#     for ii in range(len(a)):
#         CT = gsw.CT_from_pt(b[ii],a[ii])
#         temperature.append(a[ii])
#         salinity.append(b[ii])
#         ctemp.append(CT)
#         DENS = gsw.sigma0(b[ii],CT)
#         density.append(DENS)
#     dffinunreversed = pd.DataFrame({'temp': a,'sal': b,'CT': ctemp, 'density': density, 'depth':glorysdepth})
        
#     CT7 = gsw.CT_from_pt(b[7],a[7])
#     DENS7 = gsw.sigma0(b[7],CT7)
    
#     for ix in range(len(dffinunreversed)):
#         if dffinunreversed.at[ix,'temp'] > (dffinunreversed.at[7,'temp'] - 0.2):
#             pass
#         else:
#             diff = dffinunreversed.at[ix,'density'] - dffinunreversed.at[7,'density']
#             if diff < 1000:
#                 dens_thresh.append(diff)
#                 bottommix.append(0)
#                 indexer.append(i)
#                 print(diff)
#                 print('')
#                 break
#             else:
#                 dens_thresh.append(diff)
#                 bottommix.append(1)
#                 indexer.append(i)
#                 print(diff)
#                 print('')
#                 break
#             break

# %%
print(len(indexer))
print(len(dens_thresh))
print(np.nanmean(dens_thresh))
print(np.nanmin(dens_thresh))
print(np.nanmax(dens_thresh))
# Out:
# 258
# 258
# 0.034315113289354424
# 0.029622125553032674
# 0.0453994367269388

# %%
# ##### Method 2
# dens_thresh = []; indexer = []; bottommix = []; target_list = []
# for i in range(len(DS['T'])):
#     a = np.asarray(DS['T'][i])
#     b = np.asarray(DS['S'][i])
#     ctemp = []; density = []; salinity = []; temperature = []
#     for ii in range(len(a)):
#         CT = gsw.CT_from_pt(b[ii],a[ii])
#         temperature.append(a[ii])
#         salinity.append(b[ii])
#         ctemp.append(CT)
#         DENS = gsw.sigma0(b[ii],CT)
#         density.append(DENS)
#     dffinunreversed = pd.DataFrame({'temp': a,'sal': b,'CT': ctemp, 'density': density, 'depth':glorysdepth})
        
#     CT7 = gsw.CT_from_pt(b[7],a[7])
#     DENS7 = gsw.sigma0(b[7],CT7)
    
#     for ix in range(len(dffinunreversed)):
# #             pass
#         if dffinunreversed.at[ix,'temp'] <= (dffinunreversed.at[7,'temp'] - 0.2):
#             print(dffinunreversed)
#             print('temp7',dffinunreversed.at[7,'temp'])
#             print('tempix',dffinunreversed.at[ix,'temp'])
#             diff = dffinunreversed.at[ix,'density'] - dffinunreversed.at[7,'density']
#             if diff < 1000:
#                 dens_thresh.append(diff)
#                 bottommix.append(0)
#                 indexer.append(i)
#                 print(diff)
#                 print('')
#                 break
#             else:
#                 dens_thresh.append(diff)
#                 bottommix.append(1)
#                 indexer.append(i)
#                 print(diff)
#                 print('')
#                 break
#         elif dffinunreversed.at[ix,'temp'] > (dffinunreversed.at[7,'temp'] - 0.2):
#             target_list.append(dffinunreversed.at[ix,'depth'])
#             print(dffinunreversed)
#             print(dffinunreversed.at[ix,'temp'])
#             print('NO')
#             bottommix.append(1)
#             dens_thresh.append(np.nan)
#             indexer.append(i)
#             break

# %%
# print(indexer)

# %%
b = [x for x in range(indexer[0], indexer[-1] + 1)]
a = set(indexer)
print (list(a ^ set(b)))
# Out:
# []

# %%
##### Method 1
# dens_thresh = []; indexer = []; bottommix = []; target_list = []
# for i in range(len(DS['T'])):
#     a = np.asarray(DS['T'][i])
#     b = np.asarray(DS['S'][i])
#     ctemp = []; density = []; salinity = []; temperature = []
#     for ii in range(len(a)):
#         CT = gsw.CT_from_pt(b[ii],a[ii])
#         temperature.append(a[ii])
#         salinity.append(b[ii])
#         ctemp.append(CT)
#         DENS = gsw.sigma0(b[ii],CT)
#         density.append(DENS)
#     dffinunreversed = pd.DataFrame({'temp': a,'sal': b,'CT': ctemp, 'density': density, 'depth':glorysdepth})
            
#     GMLD = newmarged['glorys_mld'][i]
#     target = GMLD
#     target_list.append(target)
#     res = min(enumerate(glorysdepth), key=lambda x: abs(target - x[1]))

#     CT = gsw.CT_from_pt(b[res[0]],a[res[0]])
#     DENS = gsw.sigma0(b[res[0]],CT)
    
#     CT7 = gsw.CT_from_pt(b[7],a[7])
#     DENS7 = gsw.sigma0(b[7],CT7)
    
#     temponedeep = a[res[0]+1]
#     if temponedeep > 100 or temponedeep < -100:
#         bottommix.append(1)
#         c = 1
#     else:
#         bottommix.append(0)
#         c = 0
    
#     dens_thresh.append(DENS-DENS7)
#     diff = DENS-DENS7

#     indexer.append(i)
#     if diff < 0 and c < 1 and res[1] > 0.494025:


# #     if diff < 0 and diff >-1000 and c < 1:
# #         pass
#         print('****')
#         print('GMLD:',target)
#         print('Closest:',res[1])
#         print(res)
#         print('****')
#         print(dffinunreversed['temp'][7])
#         print('temp at surface:', a[7])
#         print('temp at depth:', a[res[0]])
#         print('temp at one deeper:', a[res[0]+1])
#         print('temp at two deeper:', a[res[0]+2])
#         print('****')
#         print('sal at surface:', b[7])
#         print('sal at depth:', b[res[0]])
#         print('sal at one deeper:', b[res[0]+1])
#         print('****')
#         print('density at surface:', DENS7)
#         print('density at depth:', DENS)
#         print(DENS - DENS7)
#         print('****')
# #         plt.plot(dffinunreversed['density'][0:19],-1*dffinunreversed['depth'][0:19],linewidth=2)
#         plt.plot(dffinunreversed['temp'][0:19],-1*dffinunreversed['depth'][0:19],linewidth=2)
#         plt.axvline(dffinunreversed['temp'][7] ,color='red',alpha=0.8)
#         plt.axvline(dffinunreversed['temp'][res[0]] ,color='green',alpha=0.8)
# #         plt.axhline(y = GMLD*-1 ,color='red',alpha=0.2)
# #         plt.axvline(x = DENS,color='black' ,alpha=0.2)
# #         plt.axvline(x = DENS7,color='green' ,alpha=0.2)
#         print(i)
#         plt.show()
# #     elif diff < 0 and c < 1:
# #         print('****')
# #         print('GMLD:',target)
# #         print('Closest:',res[1])
# #         print(res)
# #         print('****')
# #         print('temp at surface:', a[7])
# #         print('temp at depth:', a[res[0]])
# #         print('temp at one deeper:', a[res[0]+1])
# #         print('****')
# #         print('density at surface:', DENS7)
# #         print('density at depth:', DENS)
# #         print('****')
# #         plt.plot(dffinunreversed['density'][0:19],-1*dffinunreversed['depth'][0:19],linewidth=2)
# #         plt.axhline(y = GMLD*-1 ,color='red',alpha=0.2)
# #         plt.axvline(x = DENS,color='black' ,alpha=0.2)
# #         plt.axvline(x = DENS7,color='green' ,alpha=0.2)
# #         plt.show()

# %%
# fulldataframe = pd.DataFrame({'dens_thresh': dens_thresh,'indexer': indexer,'bottommix': bottommix, 'GMLD': target_list})
fulldataframe = pd.DataFrame({'dens_thresh': dens_thresh,'indexer': indexer})
# fulldataframe_dropnag = fulldataframe.dropna(subset=['GMLD'])

# fulldataframe_dropnag_reindex = fulldataframe_dropnag.reset_index()
fulldataframe_dropnag_reindex = fulldataframe.reset_index()

# %%
data4 = fulldataframe_dropnag_reindex
print(np.nanmean(data4['dens_thresh']))
# print('***')
print(np.nanmin(data4['dens_thresh']))
print(np.nanmax(data4['dens_thresh']))
print(len(data4))
# print(data4)
# data10 = data4[data4['dens_thresh'] < 0]
# print(data10)

# data5 = fulldataframe_dropnag_reindex[fulldataframe_dropnag_reindex['dens_thresh'] < 0 ]
# data6 = data5[data5['dens_thresh'] > -1000 ]
# print(data6)

# data2 = fulldataframe_dropnag_reindex[fulldataframe_dropnag_reindex['bottommix'] > 0 ]
# print(data2)

# data3 = fulldataframe_dropnag_reindex[fulldataframe_dropnag_reindex['dens_thresh'] < -1000 ]
# print(data3)
# Out:
# 0.034315113289354424
# 0.029622125553032674
# 0.0453994367269388
# 258

# %%
# dens_tresh_list = [] 
# for i in range(len(dens_thresh)):
#     dens_thresh = fulldataframe_dropnag['dens_thresh'][i]
#     bottommix_ = fulldataframe_dropnag['bottommix'][i]
#     if bottommix_ < 1 and dens_thresh > -10 and dens_tresh < 10:
#         dens_tresh_list.append(dens_thresh)
# print(np.nanmin(dens_thresh))
# print(np.nanmax(dens_thresh))
# print(len(dens_thresh))
# print(len(indexer))

# %%
plt.hist(data4['dens_thresh'],bins=[-0.4,-0.35,-0.3,-0.25,-0.2,-0.15,-0.1,-0.05,0,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4])
plt.show()

# %%
dffinunreversed = pd.DataFrame({'indexer': indexer,'dens_thresh': dens_thresh})
print(dffinunreversed)
# Out:
#      indexer  dens_thresh
# 0          0     0.035183
# 1          1     0.033640
# 2          2     0.031421
# 3          3     0.032813
# 4          4     0.032348
# ..       ...          ...
# 253      253     0.036807
# 254      254     0.036807
# 255      255     0.036936
# 256      256     0.037082
# 257      257     0.037164
#
# [258 rows x 2 columns]

# %%
merged_largedd = pd.merge(newmarged, fulldataframe_dropnag_reindex, left_on=['copy_index'], 
                        right_on = ['indexer'], left_index=True, how='outer', sort=False)

# %%
print(merged_largedd.shape)
# Out:
# (258, 24)

# %%
print(merged_largedd)
# Out:
#      Unnamed: 0  obs_lat_x  obs_lon_x  date  year_x  glorys_index_lat  \
# 0             0    40.9000    70.6833   335    1993                71
# 1             1    41.0350    70.3667   335    1993                72
# 2             2    41.0650    70.0300   335    1993                73
# 3             3    40.9317    70.1333   335    1993                71
# 4             4    40.9300    69.9850   335    1993                71
# ..          ...        ...        ...   ...     ...               ...
# 253         253    41.0383    70.2283   342    2011                72
# 254         254    41.0367    70.2817   342    2011                72
# 255         255    41.0367    70.3333   342    2011                72
# 256         256    41.0367    70.3983   342    2011                72
# 257         257    41.0600    70.5133   342    2011                73
#
#      glorys_index_lon  glorys_lat_x  glorys_lon_x  \
# 0                  88     40.916668    -70.666664
# 1                  92     41.000000    -70.333336
# 2                  96     41.083332    -70.000000
# 3                  94     40.916668    -70.166664
# 4                  96     40.916668    -70.000000
# ..                ...           ...           ...
# 253                93     41.000000    -70.250000
# 254                93     41.000000    -70.250000
# 255                92     41.000000    -70.333336
# 256                91     41.000000    -70.416664
# 257                90     41.083332    -70.500000
#
#                                   location  ...  glorys_lat_index  \
# 0       (71, 88, 1993, 70.6833, 40.9, 335)  ...              71.0
# 1     (72, 92, 1993, 70.3667, 41.035, 335)  ...              72.0
# 2       (73, 96, 1993, 70.03, 41.065, 335)  ...              73.0
# 3    (71, 94, 1993, 70.1333, 40.9317, 335)  ...              71.0
# 4       (71, 96, 1993, 69.985, 40.93, 335)  ...              71.0
# ..                                     ...  ...               ...
# 253  (72, 93, 2011, 70.2283, 41.0383, 342)  ...              72.0
# 254  (72, 93, 2011, 70.2817, 41.0367, 342)  ...              72.0
# 255  (72, 92, 2011, 70.3333, 41.0367, 342)  ...               NaN
# 256  (72, 91, 2011, 70.3983, 41.0367, 342)  ...              72.0
# 257    (73, 90, 2011, 70.5133, 41.06, 342)  ...              73.0
#
#      glorys_lon_index  bottomdepth  year_y  date_no  003densmld  glorys_mld  \
# 0                88.0         53.0  1993.0    335.0        53.0   50.965916
# 1                92.0         40.0  1993.0    335.0        40.0   37.079990
# 2                96.0         25.0  1993.0    335.0        25.0   19.837032
# 3                94.0         24.0  1993.0    335.0        24.0   25.940735
# 4                96.0         22.0  1993.0    335.0        22.0   21.668144
# ..                ...          ...     ...      ...         ...         ...
# 253              93.0         30.0  2011.0    342.0        20.0   20.142218
# 254              93.0         35.0  2011.0    342.0        13.0   20.142218
# 255               NaN          NaN     NaN      NaN         NaN         NaN
# 256              91.0         41.0  2011.0    342.0        30.0   17.853331
# 257              90.0         42.0  2011.0    342.0        23.0   18.158514
#
#      index  dens_thresh  indexer
# 0        0     0.035183        0
# 1        1     0.033640        1
# 2        2     0.031421        2
# 3        3     0.032813        3
# 4        4     0.032348        4
# ..     ...          ...      ...
# 253    253     0.036807      253
# 254    254     0.036807      254
# 255    255     0.036936      255
# 256    256     0.037082      256
# 257    257     0.037164      257
#
# [258 rows x 24 columns]

# %%
merged_largeddropped = merged_largedd.drop(columns=['obs_lat_x', 'obs_lon_x', 'date', 'year_x', 'glorys_index_lat', 'glorys_index_lon', 
                               'glorys_lat_x', 'glorys_lon_x','location','indexer','Unnamed: 0' ])
print(merged_largeddropped.shape)
# Out:
# (258, 13)

# %%
print(merged_largeddropped)
# Out:
#      obs_lat_y  obs_lon_y  glorys_lat_y  glorys_lon_y  glorys_lat_index  \
# 0      40.9000    70.6833     40.916668    -70.666664              71.0
# 1      41.0350    70.3667     41.000000    -70.333336              72.0
# 2      41.0650    70.0300     41.083332    -70.000000              73.0
# 3      40.9317    70.1333     40.916668    -70.166664              71.0
# 4      40.9300    69.9850     40.916668    -70.000000              71.0
# ..         ...        ...           ...           ...               ...
# 253    41.0383    70.2283     41.000000    -70.250000              72.0
# 254    41.0367    70.2817     41.000000    -70.250000              72.0
# 255        NaN        NaN           NaN           NaN               NaN
# 256    41.0367    70.3983     41.000000    -70.416664              72.0
# 257    41.0600    70.5133     41.083332    -70.500000              73.0
#
#      glorys_lon_index  bottomdepth  year_y  date_no  003densmld  glorys_mld  \
# 0                88.0         53.0  1993.0    335.0        53.0   50.965916
# 1                92.0         40.0  1993.0    335.0        40.0   37.079990
# 2                96.0         25.0  1993.0    335.0        25.0   19.837032
# 3                94.0         24.0  1993.0    335.0        24.0   25.940735
# 4                96.0         22.0  1993.0    335.0        22.0   21.668144
# ..                ...          ...     ...      ...         ...         ...
# 253              93.0         30.0  2011.0    342.0        20.0   20.142218
# 254              93.0         35.0  2011.0    342.0        13.0   20.142218
# 255               NaN          NaN     NaN      NaN         NaN         NaN
# 256              91.0         41.0  2011.0    342.0        30.0   17.853331
# 257              90.0         42.0  2011.0    342.0        23.0   18.158514
#
#      index  dens_thresh
# 0        0     0.035183
# 1        1     0.033640
# 2        2     0.031421
# 3        3     0.032813
# 4        4     0.032348
# ..     ...          ...
# 253    253     0.036807
# 254    254     0.036807
# 255    255     0.036936
# 256    256     0.037082
# 257    257     0.037164
#
# [258 rows x 13 columns]

# %%
merged_largeddroppeddropped = merged_largeddropped.dropna(how='all')
print(merged_largeddroppeddropped.shape)
# Out:
# (258, 13)

# %%
print(merged_largeddroppeddropped)
# Out:
#      obs_lat_y  obs_lon_y  glorys_lat_y  glorys_lon_y  glorys_lat_index  \
# 0      40.9000    70.6833     40.916668    -70.666664              71.0
# 1      41.0350    70.3667     41.000000    -70.333336              72.0
# 2      41.0650    70.0300     41.083332    -70.000000              73.0
# 3      40.9317    70.1333     40.916668    -70.166664              71.0
# 4      40.9300    69.9850     40.916668    -70.000000              71.0
# ..         ...        ...           ...           ...               ...
# 253    41.0383    70.2283     41.000000    -70.250000              72.0
# 254    41.0367    70.2817     41.000000    -70.250000              72.0
# 255        NaN        NaN           NaN           NaN               NaN
# 256    41.0367    70.3983     41.000000    -70.416664              72.0
# 257    41.0600    70.5133     41.083332    -70.500000              73.0
#
#      glorys_lon_index  bottomdepth  year_y  date_no  003densmld  glorys_mld  \
# 0                88.0         53.0  1993.0    335.0        53.0   50.965916
# 1                92.0         40.0  1993.0    335.0        40.0   37.079990
# 2                96.0         25.0  1993.0    335.0        25.0   19.837032
# 3                94.0         24.0  1993.0    335.0        24.0   25.940735
# 4                96.0         22.0  1993.0    335.0        22.0   21.668144
# ..                ...          ...     ...      ...         ...         ...
# 253              93.0         30.0  2011.0    342.0        20.0   20.142218
# 254              93.0         35.0  2011.0    342.0        13.0   20.142218
# 255               NaN          NaN     NaN      NaN         NaN         NaN
# 256              91.0         41.0  2011.0    342.0        30.0   17.853331
# 257              90.0         42.0  2011.0    342.0        23.0   18.158514
#
#      index  dens_thresh
# 0        0     0.035183
# 1        1     0.033640
# 2        2     0.031421
# 3        3     0.032813
# 4        4     0.032348
# ..     ...          ...
# 253    253     0.036807
# 254    254     0.036807
# 255    255     0.036936
# 256    256     0.037082
# 257    257     0.037164
#
# [258 rows x 13 columns]

# %%
merged_largeddroppeddropped.to_csv('12_gmldinfermethod3.csv')

# %%
# 1_gmldinfer7 # remove index 983 # COMPLETE
# 2_gmldinfer7 # COMPLETE
# 3_gmldinfer7 # COMPLETE (some GMLD are less than 10)
# 4_gmldinfer7 # COMPLETE
# 5_gmldinfer7 # COMPLETE
# 6_gmldinfer7 # COMPLETE
# 7_gmldinfer7 # COMPLETE
# 8_gmldinfer7 # COMPLETE
# 9_gmldinfer7 # COMPLETE
# 10_gmldinfer7 # COMPLETE
# 11_gmldinfer7 # COMPLETE
# 12_gmldinfer7 # COMPLETE
