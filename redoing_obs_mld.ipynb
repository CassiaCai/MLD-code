# %%
# Import libraries
import matplotlib.pyplot as plt; import numpy as np; import netCDF4; from netCDF4 import Dataset
import pandas as pd; import numpy.ma as ma; import time as timeit; import os; import math
import itertools; import scipy.io; import mat73; import collections
import cartopy; import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from matplotlib.ticker import FuncFormatter
from matplotlib.ticker import AutoMinorLocator; from matplotlib.ticker import FixedLocator
from shapely.geometry import Point
from shapely.geometry.polygon import Polygon
# %matplotlib inline
import statistics; import xarray as xr; import matplotlib as mpl; import gsw

# %%
newv = [['', '', '37.00', '', '', '76.00'], ['', '', '36.00', '', '', '75.50'], ['', '', '35.50', '', '', '75.00'], ['', '', '36.00', '', '', '74.75'], ['', '', '37.40', '', '', '74.50'], ['', '', '39.50', '', '', '72.00'], ['', '', '40.50', '', '', '74.00'], ['', '', '39.40', '', '', '74.25'], ['', '', '37.00', '', '', '76.00']]
lon_v = []; lat_v = []
for i in range(9): 
    v1 = newv[i][2]
    lat_v.append(v1)
    v3 = newv[i][5]
    lon_v.append(v3)
lonlist_v = [float(i) for i in lon_v]; latlist_v = [float(i) for i in lat_v]
df_v = pd.DataFrame({'lon': lonlist_v, 'lat': latlist_v,})
lonlist_v_plot = [float(i)*-1 for i in lon_v]; latlist_v = [float(i) for i in lat_v]
df_v_plot = pd.DataFrame({'lon': lonlist_v_plot, 'lat': latlist_v,})
x_v = df_v_plot['lon']; y_v = df_v_plot['lat']

lonlist_vneg = [float(i)*-1 for i in lon_v]
df_v_plottable = pd.DataFrame({'lon': lonlist_vneg, 'lat': latlist_v,})
polygon_v = Polygon(df_v.values.tolist())

# %%
neww = [['', '', '40.00', '', '', '69.50'], ['', '', '40.30', '', '', '68.00'], ['', '', '40.40', '', '', '67.50'], ['', '', '40.60', '', '', '67.00'], ['', '', '40.80', '', '', '66.50'], ['', '', '41.45', '', '', '66.00'], ['', '', '41.80', '', '', '65.70'], ['', '', '42.10', '', '', '66.00'], ['', '', '42.10', '', '', '67.00'], ['', '', '42.10', '', '', '67.50'], ['', '', '41.80', '', '', '68.00'], ['', '', '41.10', '', '', '69.00'], ['', '', '41.00', '', '', '69.50'], ['', '', '40.00', '', '', '69.50']]
lon_w = []; lat_w = []
for i in range(14): 
    w1 = neww[i][2]
    lat_w.append(w1)
    w3 = neww[i][5]
    lon_w.append(w3)
lonlist_w = [float(i) for i in lon_w]; latlist_w = [float(i) for i in lat_w]
lonlist_wneg = [float(i)*-1 for i in lon_w]
df_w = pd.DataFrame({'lon': lonlist_w, 'lat': latlist_w,})
df_w_plottable = pd.DataFrame({'lon': lonlist_wneg, 'lat': latlist_w,})

lonlist_w_plot = [float(i)*-1 for i in lon_w]; latlist_w = [float(i) for i in lat_w]
df_w_plot = pd.DataFrame({'lon': lonlist_w_plot, 'lat': latlist_w,})
x_w = df_w_plot['lon']; y_w = df_w_plot['lat']
polygon_w = Polygon(df_w.values)

# %%
newy = [['', '', '41.80', '', '', '68.00'], ['', '', '42.10', '', '', '67.50'], ['', '', '42.10', '', '', '67.00'], ['', '', '42.10', '', '', '66.00'], ['', '', '43.00', '', '', '66.00'], ['', '', '44.20', '', '', '66.50'], ['', '', '44.20', '', '', '67.00'], ['', '', '44.20', '', '', '68.00'], ['', '', '41.80', '', '', '68.00']]
lon_y = []; lat_y = []
for i in range(9): 
    y1 = newy[i][2]
    lat_y.append(y1)
    y3 = newy[i][5]
    lon_y.append(y3)
lonlist_y = [float(i) for i in lon_y]; latlist_y = [float(i) for i in lat_y]
df_y = pd.DataFrame({'lon': lonlist_y, 'lat': latlist_y,})
lonlist_y_plot = [float(i)*-1 for i in lon_y]; latlist_y = [float(i) for i in lat_y]
df_y_plot = pd.DataFrame({'lon': lonlist_y_plot, 'lat': latlist_y,})
x_y = df_y_plot['lon']; y_y = df_y_plot['lat']

lonlist_yneg = [float(i)*-1 for i in lon_y]
df_y_plottable = pd.DataFrame({'lon': lonlist_yneg, 'lat': latlist_y,})
polygon_y = Polygon(df_y.values)

# %%
newt = [['', '', '42.20', '', '', '70.50'], ['', '', '42.00', '', '', '70.00'], ['', '', '41.10', '', '', '69.00'], ['', '', '41.80', '', '', '68.00'], ['', '', '44.20', '', '', '68.00'], ['', '', '43.90', '', '', '69.00'], ['', '', '43.70', '', '', '70.00'], ['', '', '43.00', '', '', '70.50'], ['', '', '42.20', '', '', '70.50']]
lon_t = []; lat_t = []
for i in range(9): 
    t1 = newt[i][2]
    lat_t.append(t1)
    t3 = newt[i][5]
    lon_t.append(t3)
lonlist_t = [float(i) for i in lon_t]; latlist_t = [float(i) for i in lat_t]
df_t = pd.DataFrame({'lon': lonlist_t, 'lat': latlist_t,})
lonlist_t_plot = [float(i)*-1 for i in lon_t]; latlist_t = [float(i) for i in lat_t]
df_t_plot = pd.DataFrame({'lon': lonlist_t_plot, 'lat': latlist_t,})
x_t = df_t_plot['lon']; y_t = df_t_plot['lat']

lonlist_tneg = [float(i)*-1 for i in lon_t]
df_t_plottable = pd.DataFrame({'lon': lonlist_tneg, 'lat': latlist_t,})
polygon_t = Polygon(df_t.values)

# %%
newx = [['', '', '40.50', '', '', '74.00'], ['', '', '39.50', '', '', '72.00'], ['', '', '40.00', '', '', '71.40'], ['', '', '40.00', '', '', '69.50'], ['', '', '41.00', '', '', '69.50'], ['', '', '41.10', '', '', '70.00'], ['', '', '41.00', '', '', '72.00'], ['', '', '40.50', '', '', '74.00']]
lon_x = []; lat_x = []
for i in range(8): 
    x1 = newx[i][2]
    lat_x.append(x1)
    x3 = newx[i][5]
    lon_x.append(x3)
lonlist_x = [float(i) for i in lon_x]; latlist_x = [float(i) for i in lat_x]
df_x = pd.DataFrame({'lon': lonlist_x, 'lat': latlist_x,})
lonlist_x_plot = [float(i)*-1 for i in lon_x]; latlist_x = [float(i) for i in lat_x]
df_x_plot = pd.DataFrame({'lon': lonlist_x_plot, 'lat': latlist_x,})
x_x = df_x_plot['lon']; y_x = df_x_plot['lat']

lonlist_xneg = [float(i)*-1 for i in lon_x]
df_x_plottable = pd.DataFrame({'lon': lonlist_xneg, 'lat': latlist_x,})
polygon_x = Polygon(df_x.values.tolist())

# %%
temp_threshold = 0.2

# %%
countwithinpolygon = []; tempmld = []; obs_lat = []; obs_lon = []; date_no = []; bottomdepth = []; years = []
yearwithdata = []; datefull = []; finallatestdepth = []; glorysmld = []
glorys_lat = []; glorys_lon = []; glorys_lat_index = []; glorys_lon_index = []

for year in range(1993,2019):
    filename = 'casts_{}.mat'.format(year)
    file = scipy.io.loadmat(filename,squeeze_me=True)
    npfile = file['casts_{}'.format(year)]
    
    lat_intermediate = []; lon_intermediate = []; p_intermediate = []; counterii = []
    t_intermediate = []; yd_intermediate = []; sal_intermediate = []; floor_intermediate = []
    
    for i in range(len(npfile)):
        yd = npfile[i]['yd']
        p = npfile[i]['p']
        s = npfile[i]['s']
        t = npfile[i]['t']
        gear = npfile[i]['gear']
        floordepth = npfile[i]['depth']
#         if yd == 0:
        if yd > 334 and yd <= 365:  # and floordepth <= 200
            lat_intermediate.append(npfile[i]['lat'])
            lon_intermediate.append(npfile[i]['lon'])
            p_intermediate.append(npfile[i]['p'])
            t_intermediate.append(npfile[i]['t'])
            yd_intermediate.append(npfile[i]['yd'])
            sal_intermediate.append(npfile[i]['s'])
            floor_intermediate.append(npfile[i]['depth'])
    month_df = pd.DataFrame({'day': yd_intermediate,'lon': lon_intermediate,'lat': lat_intermediate, 'p': p_intermediate, 't': t_intermediate,'depth': floor_intermediate, 's': sal_intermediate})
    newdf = pd.DataFrame({'lon': lon_intermediate,'lat': lat_intermediate,'date': yd_intermediate})
    for ii in range(len(month_df)):
        new = newdf.iloc[ii].values
        point = Point(new)
        if isinstance(month_df['p'].iloc[ii], int) or isinstance(month_df['p'].iloc[ii], float) or isinstance(month_df['t'].iloc[ii], int) or isinstance(month_df['t'].iloc[ii], float):
            pass
        elif polygon_x.contains(point) == True or polygon_y.contains(point) == True or polygon_w.contains(point) == True or polygon_t.contains(point) == True or polygon_v.contains(point) == True:
            SA = gsw.SA_from_SP(month_df['s'].iloc[ii],month_df['p'].iloc[ii],month_df['lon'].iloc[ii],month_df['lat'].iloc[ii])
            CT = gsw.CT_from_pt(SA,month_df['t'].iloc[ii])
            DENS = gsw.sigma0(SA,CT)
            pt_df = pd.DataFrame({'p': month_df['p'].iloc[ii],'t': month_df['t'].iloc[ii], 's': month_df['s'].iloc[ii], 'CT': CT, 'DENSMLD': DENS}) 
            df_ptsnew = pt_df.dropna()
            df_final = pd.DataFrame(df_ptsnew.values)
            countwithinpolygon.append(1)
            l=[i for i in df_final[0] if i<=5] 
            if len(l) > 0:
                surfaceval = []
                numrange = []
                for iii in range(len(l)):
                    val = df_final[1][iii]
                    numrange.append(iii)
                    surfaceval.append(val)            
            surfacevalmean = statistics.mean(surfaceval)
            densfin = []; tempfin = []; pressurefin = []; salfin = []
            for iii in range(numrange[-1],len(df_final)):
                tempfin.append(df_final[1][iii])
                pressurefin.append(df_final[0][iii])
                salfin.append(df_final[2][iii])
                densfin.append(df_final[4][iii])
            d = {'temp': list(reversed(tempfin)), 'sal': list(reversed(salfin)), 'pressure': list(reversed(pressurefin)),'density': list(reversed(densfin))}
            dunreversed = {'temp': list(tempfin), 'sal': list(salfin), 'pressure': list(pressurefin), 'density': list(densfin)}
            dffinunreversed = pd.DataFrame(dunreversed)
            dffin = pd.DataFrame(d)

            for ix in range(len(dffinunreversed)):
                if dffinunreversed.at[ix,'temp'] >= (surfacevalmean - temp_threshold) and dffinunreversed.at[ix,'temp'] <= (surfacevalmean + temp_threshold):
                    if dffinunreversed.at[len(dffinunreversed)-1,'temp'] <= (surfacevalmean + temp_threshold) and dffinunreversed.at[len(dffinunreversed)-1,'temp'] >= (surfacevalmean - temp_threshold):
                        looknow = list(dffinunreversed['temp'].values)
                        looknow2 = [i for i in looknow if i >= (surfacevalmean + temp_threshold)]
                        looknow3 = [i for i in looknow if i <= (surfacevalmean - temp_threshold)]
                        if len(looknow2) == 0 and len(looknow3) == 0:
                            if (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] <= 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 5)) or (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] > 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 10)):
                                tempmld.append(month_df['depth'].iloc[ii])
                                obs_lat.append(month_df['lat'].iloc[ii])
                                obs_lon.append(month_df['lon'].iloc[ii])
                                date_no.append(month_df['day'].iloc[ii])
                                bottomdepth.append(month_df['depth'].iloc[ii])
                                years.append(year)
                                counterii.append(ii)
                                # PLOTTING
#                                 plt.plot(df_final[1], df_final[0]*-1)
#                                 plt.axhline(y=month_df['depth'].iloc[ii]*-1,color='black', linestyle='-',alpha = 1)
#                                 plt.axhline(y=dffinunreversed.at[len(dffinunreversed)-1,'pressure']*-1,color='red', linestyle='-',alpha = 0.5)
#                                 plt.axhline(y=5*-1,color='green', linestyle='--',alpha = 1)
#                                 plt.axvline(x=surfacevalmean,color='green', linestyle='--',alpha = 1)
#                                 plt.axvline(x=surfacevalmean+0.2,color='green', linestyle='--',alpha = 0.5)
#                                 plt.axvline(x=surfacevalmean-0.2,color='green', linestyle='--',alpha = 0.5)
#                                 plt.show()
                                break
                            else:#here
                                break 
                        else:
                            if (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] <= 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 5)) or (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] > 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 10)):
                                for ix in range(len(dffinunreversed['temp'])):
                                    if dffinunreversed.at[ix,'temp'] >= (surfacevalmean - temp_threshold) and dffinunreversed.at[ix,'temp'] <= (surfacevalmean + temp_threshold):
                                        pass
                                    else:
                                        tempmld.append(dffinunreversed.at[ix,'pressure'])
                                        obs_lat.append(month_df['lat'].iloc[ii])
                                        obs_lon.append(month_df['lon'].iloc[ii])
                                        date_no.append(month_df['day'].iloc[ii])
                                        bottomdepth.append(month_df['depth'].iloc[ii])
                                        years.append(year)
                                        counterii.append(ii)
# #                                         PLOTTING problem here
#                                         plt.plot(df_final[1], df_final[0]*-1)
#                                         plt.axhline(y=dffinunreversed.at[ix,'pressure']*-1,color='blue', linestyle='-',alpha = 1)
#                                         plt.axhline(y=month_df['depth'].iloc[ii]*-1,color='black', linestyle='-',alpha = 1)
#                                         plt.axhline(y=dffinunreversed.at[len(dffinunreversed)-1,'pressure']*-1,color='red', linestyle='-',alpha = 0.5)
#                                         plt.axhline(y=5*-1,color='green', linestyle='--',alpha = 1)
#                                         plt.axvline(x=surfacevalmean,color='green', linestyle='--',alpha = 1)
#                                         plt.axvline(x=surfacevalmean+0.2,color='green', linestyle='--',alpha = 0.5)
#                                         plt.axvline(x=surfacevalmean-0.2,color='green', linestyle='--',alpha = 0.5)
#                                         plt.show()
                                        break
                                break
                            else:
                                break
                    else: 
                        if dffinunreversed.at[ix,'temp'] <= (surfacevalmean - temp_threshold) or dffinunreversed.at[ix,'temp'] >= (surfacevalmean + temp_threshold):
                            if (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] <= 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 5) and dffinunreversed.at[ix,'pressure'] <= (month_df['depth'].iloc[ii] - 5)) or (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] > 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 10) and dffinunreversed.at[ix,'pressure'] <= (month_df['depth'].iloc[ii] - 10)):
                                pass
                            else:
                                tempmld.append(dffinunreversed.at[ix,'pressure'])
                                obs_lat.append(month_df['lat'].iloc[ii])
                                obs_lon.append(month_df['lon'].iloc[ii])
                                date_no.append(month_df['day'].iloc[ii])
                                bottomdepth.append(month_df['depth'].iloc[ii])
                                years.append(year)
                                counterii.append(ii)
#                                 PLOTTING 
#                                 plt.plot(df_final[1], df_final[0]*-1)
#                                 plt.axhline(y=dffinunreversed.at[ix,'pressure']*-1,color='purple', linestyle='--',alpha = 0.5)
#                                 plt.axhline(y=month_df['depth'].iloc[ii]*-1,color='black', linestyle='-',alpha = 0.5)
#                                 plt.axhline(y=dffinunreversed.at[len(dffinunreversed)-1,'pressure']*-1,color='red', linestyle='-',alpha = 0.5)
#                                 plt.axhline(y=5*-1,color='green', linestyle='--',alpha = 1)
#                                 plt.axvline(x=surfacevalmean,color='green', linestyle='--',alpha = 1)
#                                 plt.axvline(x=surfacevalmean+0.2,color='green', linestyle='--',alpha = 0.5)
#                                 plt.axvline(x=surfacevalmean-0.2,color='green', linestyle='--',alpha = 0.5)
#                                 plt.show()
                                break           
                        else: 
                            if dffinunreversed.at[ix,'temp'] >= (surfacevalmean + temp_threshold) or dffinunreversed.at[ix,'temp'] <= (surfacevalmean - temp_threshold):
                                break 
                elif dffinunreversed.at[ix,'temp'] <= (surfacevalmean - temp_threshold) or dffinunreversed.at[ix,'temp'] >= (surfacevalmean + temp_threshold):
                    if (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] <= 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 5) and dffinunreversed.at[ix,'pressure'] <= (month_df['depth'].iloc[ii] - 5)) or (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] > 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 10) and dffinunreversed.at[ix,'pressure'] <= (month_df['depth'].iloc[ii] - 10)):
#                         pass
#                     else:
                        for ix in range(len(dffinunreversed['temp'])):
                            if dffinunreversed.at[ix,'temp'] >= (surfacevalmean - temp_threshold) and dffinunreversed.at[ix,'temp'] <= (surfacevalmean + temp_threshold):
                                pass
                            else:
                                tempmld.append(dffinunreversed.at[ix,'pressure'])
                                obs_lat.append(month_df['lat'].iloc[ii])
                                obs_lon.append(month_df['lon'].iloc[ii])
                                date_no.append(month_df['day'].iloc[ii])
                                bottomdepth.append(month_df['depth'].iloc[ii])
                                years.append(year)
                                counterii.append(ii)
                                
#                                 plt.plot(df_final[1], df_final[0]*-1)
#                                 plt.axhline(y=dffinunreversed.at[ix,'pressure']*-1,color='purple', linestyle='--',alpha = 0.5)
#                                 plt.axhline(y=month_df['depth'].iloc[ii]*-1,color='black', linestyle='-',alpha = 0.5)
#                                 plt.axhline(y=dffinunreversed.at[len(dffinunreversed)-1,'pressure']*-1,color='red', linestyle='-',alpha = 0.5)
#                                 plt.axhline(y=5*-1,color='green', linestyle='--',alpha = 1)
#                                 plt.axvline(x=surfacevalmean,color='green', linestyle='--',alpha = 1)
#                                 plt.axvline(x=surfacevalmean+0.2,color='green', linestyle='--',alpha = 0.5)
#                                 plt.axvline(x=surfacevalmean-0.2,color='green', linestyle='--',alpha = 0.5)
#                                 plt.show()
                                
                                break
                        break
                else: 
                    break
    print('**********')
    print(year)
    print(len(countwithinpolygon))
    print(len(tempmld))
    print(len(obs_lat))
    print(len(obs_lon))
    print(len(date_no))
    print(len(bottomdepth))
    print(len(years))
    print('')
# Out:
# **********
# 1993
# 115
# 112
# 112
# 112
# 112
# 112
# 112
#
# **********
# 1994
# 117
# 114
# 114
# 114
# 114
# 114
# 114
#
# **********
# 1995
# 117
# 114
# 114
# 114
# 114
# 114
# 114
#
# **********
# 1996
# 117
# 114
# 114
# 114
# 114
# 114
# 114
#
# **********
# 1997
# 117
# 114
# 114
# 114
# 114
# 114
# 114
#
# **********
# 1998
# 117
# 114
# 114
# 114
# 114
# 114
# 114
#
# **********
# 1999
# 117
# 114
# 114
# 114
# 114
# 114
# 114
#
# **********
# 2000
# 117
# 114
# 114
# 114
# 114
# 114
# 114
#
# **********
# 2001
# 117
# 114
# 114
# 114
# 114
# 114
# 114
#
# **********
# 2002
# 117
# 114
# 114
# 114
# 114
# 114
# 114
#
# **********
# 2003
# 117
# 114
# 114
# 114
# 114
# 114
# 114
#
# **********
# 2004
# 117
# 114
# 114
# 114
# 114
# 114
# 114
#
# **********
# 2005
# 117
# 114
# 114
# 114
# 114
# 114
# 114
#
# **********
# 2006
# 117
# 114
# 114
# 114
# 114
# 114
# 114
#
# **********
# 2007
# 117
# 114
# 114
# 114
# 114
# 114
# 114
#
# **********
# 2008
# 117
# 114
# 114
# 114
# 114
# 114
# 114
#
# **********
# 2009
# 117
# 114
# 114
# 114
# 114
# 114
# 114
#
# **********
# 2010
# 186
# 176
# 176
# 176
# 176
# 176
# 176
#
# **********
# 2011
# 258
# 238
# 238
# 238
# 238
# 238
# 238
#
# **********
# 2012
# 258
# 238
# 238
# 238
# 238
# 238
# 238
#
# **********
# 2013
# 258
# 238
# 238
# 238
# 238
# 238
# 238
#
# **********
# 2014
# 258
# 238
# 238
# 238
# 238
# 238
# 238
#
# **********
# 2015
# 258
# 238
# 238
# 238
# 238
# 238
# 238
#
# **********
# 2016
# 258
# 238
# 238
# 238
# 238
# 238
# 238
#
# **********
# 2017
# 258
# 238
# 238
# 238
# 238
# 238
# 238
#
# **********
# 2018
# 258
# 238
# 238
# 238
# 238
# 238
# 238

# %%
pandas_02 = pd.DataFrame({'obs_lat_t': obs_lat,'obs_lon_t': obs_lon,'bottomdepth_t':bottomdepth,'year_t':years, 'date_no_t':date_no, '02tempmld_t':tempmld})

# %%
print(pandas_02)
pandas_02new = pandas_02.assign(location=[*zip(pandas_02.year_t, pandas_02.obs_lon_t, pandas_02.obs_lat_t,pandas_02.date_no_t)])
print(len(pandas_02new))
print(len(pandas_02new['location'].unique()))
pandas_02new_dd = pandas_02new.drop_duplicates(subset=['location'])
print(len(pandas_02new_dd))
# Out:
#      obs_lat_t  obs_lon_t  bottomdepth_t  year_t  date_no_t  02tempmld_t
# 0      40.9000    70.6833             53    1993        335         53.0
# 1      41.0350    70.3667             40    1993        335         40.0
# 2      41.0650    70.0300             25    1993        335         25.0
# 3      40.9317    70.1333             24    1993        335         24.0
# 4      40.9300    69.9850             22    1993        335         22.0
# ..         ...        ...            ...     ...        ...          ...
# 233    40.9517    70.2467             35    2011        342         35.0
# 234    41.0367    70.2817             35    2011        342         13.0
# 235    41.0367    70.3333             38    2011        342         38.0
# 236    41.0367    70.3983             41    2011        342         41.0
# 237    41.0600    70.5133             42    2011        342         42.0
#
# [238 rows x 6 columns]
# 238
# 238
# 238

# %%
dens_threshold = 0.03

# %%
countwithinpolygon = []; densmld = []; obs_lat = []; obs_lon = []; date_no = []; bottomdepth = []; years = []
yearwithdata = []; datefull = []; finallatestdepth = []; glorysmld = []
glorys_lat = []; glorys_lon = []; glorys_lat_index = []; glorys_lon_index = []

for year in range(1993,2000):
    filename = 'casts_{}.mat'.format(year)
    file = scipy.io.loadmat(filename,squeeze_me=True)
    npfile = file['casts_{}'.format(year)]
    
    lat_intermediate = []; lon_intermediate = []; p_intermediate = []; counterii = []
    t_intermediate = []; yd_intermediate = []; sal_intermediate = []; floor_intermediate = []
    
    for i in range(len(npfile)):
        yd = npfile[i]['yd']
        p = npfile[i]['p']
        s = npfile[i]['s']
        t = npfile[i]['t']
        gear = npfile[i]['gear']
        floordepth = npfile[i]['depth']
#         if (yd > 334 and yd <= 365) or (yd >= 0 and yd <= 59):
        if yd >= 0 and yd <= 365:  # and floordepth <= 200
            lat_intermediate.append(npfile[i]['lat'])
            lon_intermediate.append(npfile[i]['lon'])
            p_intermediate.append(npfile[i]['p'])
            t_intermediate.append(npfile[i]['t'])
            yd_intermediate.append(npfile[i]['yd'])
            sal_intermediate.append(npfile[i]['s'])
            floor_intermediate.append(npfile[i]['depth'])
    month_df = pd.DataFrame({'day': yd_intermediate,'lon': lon_intermediate,'lat': lat_intermediate, 'p': p_intermediate, 't': t_intermediate,'depth': floor_intermediate, 's': sal_intermediate})
    newdf = pd.DataFrame({'lon': lon_intermediate,'lat': lat_intermediate,'date': yd_intermediate})
    for ii in range(len(month_df)):
        new = newdf.iloc[ii].values
        point = Point(new)
        if isinstance(month_df['p'].iloc[ii], int) or isinstance(month_df['p'].iloc[ii], float) or isinstance(month_df['t'].iloc[ii], int) or isinstance(month_df['t'].iloc[ii], float):
            pass
        elif polygon_x.contains(point) == True or polygon_y.contains(point) == True or polygon_w.contains(point) == True or polygon_t.contains(point) == True or polygon_v.contains(point) == True:
            SA = gsw.SA_from_SP(month_df['s'].iloc[ii],month_df['p'].iloc[ii],month_df['lon'].iloc[ii],month_df['lat'].iloc[ii])
            CT = gsw.CT_from_pt(SA,month_df['t'].iloc[ii])
            DENS = gsw.sigma0(SA,CT)
            pt_df = pd.DataFrame({'p': month_df['p'].iloc[ii],'t': month_df['t'].iloc[ii], 's': month_df['s'].iloc[ii], 'CT': CT, 'DENSMLD': DENS}) 
            df_ptsnew = pt_df.dropna()
            df_final = pd.DataFrame(df_ptsnew.values)
            countwithinpolygon.append(1)
            l=[i for i in df_final[0] if i<=5] 
            if len(l) > 0:
                surfaceval = []
                numrange = []
                for iii in range(len(l)):
                    val = df_final[4][iii]
                    numrange.append(iii)
                    surfaceval.append(val)            
            surfacevalmean = statistics.mean(surfaceval)
            densfin = []; tempfin = []; pressurefin = []; salfin = []
            for iii in range(numrange[-1],len(df_final)): #for iii in range(numrange[-1]+1,len(df_final)):
                tempfin.append(df_final[1][iii])
                pressurefin.append(df_final[0][iii])
                salfin.append(df_final[2][iii])
                densfin.append(df_final[4][iii])
            d = {'temp': list(reversed(tempfin)), 'sal': list(reversed(salfin)), 'pressure': list(reversed(pressurefin)),'density': list(reversed(densfin))}
            dunreversed = {'temp': list(tempfin), 'sal': list(salfin), 'pressure': list(pressurefin), 'density': list(densfin)}
            dffinunreversed = pd.DataFrame(dunreversed)
            dffin = pd.DataFrame(d)
            
#             print(dffin)
            for ix in range(len(dffinunreversed)):
                if dffinunreversed.at[ix,'density'] >= (surfacevalmean - dens_threshold) and dffinunreversed.at[ix,'density'] <= (surfacevalmean + dens_threshold):
                    if dffinunreversed.at[len(dffinunreversed)-1,'density'] <= (surfacevalmean + dens_threshold) and dffinunreversed.at[len(dffinunreversed)-1,'density'] >= (surfacevalmean - dens_threshold):
                        looknow = list(dffinunreversed['density'].values)
                        looknow2 = [i for i in looknow if i >= (surfacevalmean + dens_threshold)]
                        looknow3 = [i for i in looknow if i <= (surfacevalmean - dens_threshold)]
                        if len(looknow2) == 0 and len(looknow3) == 0:
                            if (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] <= 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 5)) or (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] > 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 10)):
                                densmld.append(month_df['depth'].iloc[ii])
                                obs_lat.append(month_df['lat'].iloc[ii])
                                obs_lon.append(month_df['lon'].iloc[ii])
                                date_no.append(month_df['day'].iloc[ii])
                                bottomdepth.append(month_df['depth'].iloc[ii])
                                years.append(year)
                                counterii.append(ii)
                                # PLOTTING  
#                                 plt.figure(figsize=(3,5))
#                                 plt.axhline(y=5*-1,color='green', linestyle='--',alpha = 1)
#                                 plt.plot(df_final[4], df_final[0]*-1)
# #                                 plt.axhline(y=74*-1,color='black', linestyle='--',linewidth = 3,alpha = 1)
# #                                 plt.axhline(y=200*-1,color='red', linestyle='-',alpha = 0.8)
# #                                 plt.axhline(y=226*-1,color='black', linestyle='-',alpha = 0.5)
# #                                 plt.axhline(y=20*-1,color='black', linestyle='-',alpha = 0.5)
#                                 plt.axvline(x=surfacevalmean,color='green', linestyle='--',alpha = 1)
#                                 plt.axvline(x=surfacevalmean+0.03,color='green', linestyle='--',alpha = 0.5)
#                                 plt.axvline(x=surfacevalmean-0.03,color='green', linestyle='--',alpha = 0.5)
#                                 plt.xticks([24.60,24.65,24.7,24.75,24.8], fontsize = 12) 
#                                 plt.yticks([-60,-50,-40,-30,-20,-10,0], fontsize = 12) 
#                                 plt.xlabel('Density (kg/m3)', fontsize = 12)
# #                                 plt.ylabel('Depth (m)', fontsize = 12)
#                                 plt.grid(b=True, which='both', color='black', linestyle='--',alpha = 0.2)
#                                 mpl.rcParams['axes.linewidth'] = 1.5
#                                 plt.text(24.75, -50, 'b.', dict(size=22))
#                                 plt.axhline(y=month_df['depth'].iloc[ii]*-1,color='black', linestyle='-',alpha = 0.5)
#                                 plt.axhline(y=dffinunreversed.at[len(dffinunreversed)-1,'pressure']*-1,color='red', linestyle='-',alpha = 0.8)
#                                 plt.axhline(y=month_df['depth'].iloc[ii]*-1,color='blue', linestyle='--',linewidth = 3,alpha = 1)
# #                                 plt.plot(df_final[1], df_final[0]*-1)
#                                 plt.show()
                                break
                            
                            else:#here
                                plt.figure(figsize=(3,5))
                                plt.plot(df_final[4], df_final[0]*-1)
                                plt.axhline(y=dffinunreversed.at[ix,'pressure']*-1,color='darkblue', linestyle='--',alpha = 1)
                                plt.axhline(y=month_df['depth'].iloc[ii]*-1,color='black', linestyle='-',alpha = 0.5)
                                plt.axhline(y=dffinunreversed.at[len(dffinunreversed)-1,'pressure']*-1,color='red', linestyle='-',alpha = 0.8)
                                plt.axhline(y=5*-1,color='green', linestyle='--',alpha = 1)
                                plt.axvline(x=surfacevalmean,color='green', linestyle='--',alpha = 1)
                                plt.axvline(x=surfacevalmean+0.03,color='green', linestyle='--',alpha = 0.5)
                                plt.axvline(x=surfacevalmean-0.03,color='green', linestyle='--',alpha = 0.5)
                                plt.yticks([-80,-70,-60,-50,-40,-30,-20,-10,0], fontsize = 12) 
                                plt.xticks([25.90,26.0,26.10,26.20], fontsize = 12)
                                plt.grid(b=True, which='both', color='black', linestyle='--',alpha = 0.2)
                                plt.text(26.10, -70, 'd.', dict(size=22))
                                plt.xlabel('Density (kg/m3)', fontsize = 12)
                                plt.show()
#                                 plt.plot(df_final[1], df_final[0]*-1)
#                                 plt.show()
                                break 
                        else:
                            if (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] <= 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 5)) or (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] > 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 10)):
                                for ix in range(len(dffinunreversed['density'])):
                                    if dffinunreversed.at[ix,'density'] >= (surfacevalmean - dens_threshold) and dffinunreversed.at[ix,'density'] <= (surfacevalmean + dens_threshold):
                                        pass
                                    else:
                                        densmld.append(dffinunreversed.at[ix,'pressure'])
                                        obs_lat.append(month_df['lat'].iloc[ii])
                                        obs_lon.append(month_df['lon'].iloc[ii])
                                        date_no.append(month_df['day'].iloc[ii])
                                        bottomdepth.append(month_df['depth'].iloc[ii])
                                        years.append(year)
                                        counterii.append(ii)
                                        #plotting
#                                         plt.plot(df_final[4], df_final[0]*-1)
#                                         plt.axhline(y=dffinunreversed.at[ix,'pressure']*-1,color='gray', linestyle='--',alpha = 1)
#                                         plt.axhline(y=month_df['depth'].iloc[ii]*-1,color='black', linestyle='-',alpha = 0.5)
#                                         plt.axhline(y=dffinunreversed.at[len(dffinunreversed)-1,'pressure']*-1,color='red', linestyle='-',alpha = 0.5)
#                                         plt.axhline(y=5*-1,color='green', linestyle='--',alpha = 1)
#                                         plt.axvline(x=surfacevalmean,color='green', linestyle='--',alpha = 1)
#                                         plt.axvline(x=surfacevalmean+0.03,color='green', linestyle='--',alpha = 0.5)
#                                         plt.axvline(x=surfacevalmean-0.03,color='green', linestyle='--',alpha = 0.5)
# #                                         plt.show()
# #                                         plt.plot(df_final[1], df_final[0]*-1)
# #                                         plt.axhline(y=5*-1,color='green', linestyle='--',alpha = 1)
# #                                         plt.axhline(y=24*-1,color='gray', linestyle='--',alpha = 1)
# #                                         plt.axvline(x=5.25,color='green', linestyle='--',alpha = 1)
# #                                         plt.axvline(x=5.25+0.2,color='green', linestyle='--',alpha = 0.5)
# #                                         plt.axvline(x=5.25-0.2,color='green', linestyle='--',alpha = 0.5)
# #                                         plt.axhline(y=dffinunreversed.at[len(dffinunreversed)-1,'pressure']*-1,color='red', linestyle='-',alpha = 0.5)
# #                                         plt.axhline(y=month_df['depth'].iloc[ii]*-1,color='black', linestyle='-',alpha = 0.5)
#                                         plt.show()
                                        break
                                break
                            else:
                                break
                    else: 
                        if dffinunreversed.at[ix,'density'] <= (surfacevalmean - dens_threshold) or dffinunreversed.at[ix,'density'] >= (surfacevalmean + dens_threshold):
                            if (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] <= 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 5) and dffinunreversed.at[ix,'pressure'] <= (month_df['depth'].iloc[ii] - 5)) or (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] > 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 10) and dffinunreversed.at[ix,'pressure'] <= (month_df['depth'].iloc[ii] - 10)):
                                pass
                            else:
                                densmld.append(dffinunreversed.at[ix,'pressure'])
                                obs_lat.append(month_df['lat'].iloc[ii])
                                obs_lon.append(month_df['lon'].iloc[ii])
                                date_no.append(month_df['day'].iloc[ii])
                                bottomdepth.append(month_df['depth'].iloc[ii])
                                years.append(year)
                                counterii.append(ii)
#                                 PLOTTING 
#                                 plt.plot(df_final[4], df_final[0]*-1)
#                                 plt.axhline(y=dffinunreversed.at[ix,'pressure']*-1,color='purple', linestyle='--',alpha = 0.5)
#                                 plt.axhline(y=month_df['depth'].iloc[ii]*-1,color='black', linestyle='-',alpha = 0.5)
#                                 plt.axhline(y=dffinunreversed.at[len(dffinunreversed)-1,'pressure']*-1,color='red', linestyle='-',alpha = 0.5)
#                                 plt.axhline(y=5*-1,color='green', linestyle='--',alpha = 1)
#                                 plt.axvline(x=surfacevalmean,color='green', linestyle='--',alpha = 1)
#                                 plt.axvline(x=surfacevalmean+0.03,color='green', linestyle='--',alpha = 0.5)
#                                 plt.axvline(x=surfacevalmean-0.03,color='green', linestyle='--',alpha = 0.5)
#                                 plt.show()
#                                 plt.plot(df_final[1], df_final[0]*-1)
#                                 plt.show()
                                break           
                        else: 
                            if dffinunreversed.at[ix,'density'] >= (surfacevalmean + dens_threshold) or dffinunreversed.at[ix,'density'] <= (surfacevalmean - dens_threshold):
                                break 
                elif dffinunreversed.at[ix,'density'] <= (surfacevalmean - dens_threshold) or dffinunreversed.at[ix,'density'] >= (surfacevalmean + dens_threshold):
                    if (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] <= 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 5) and dffinunreversed.at[ix,'pressure'] <= (month_df['depth'].iloc[ii] - 5)) or (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] > 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 10) and dffinunreversed.at[ix,'pressure'] <= (month_df['depth'].iloc[ii] - 10)):
#                         pass
#                     else:
                        for ix in range(len(dffinunreversed['density'])):
                            if dffinunreversed.at[ix,'density'] >= (surfacevalmean - dens_threshold) and dffinunreversed.at[ix,'density'] <= (surfacevalmean + dens_threshold):
                                pass
                            else:
                                densmld.append(dffinunreversed.at[ix,'pressure'])
                                obs_lat.append(month_df['lat'].iloc[ii])
                                obs_lon.append(month_df['lon'].iloc[ii])
                                date_no.append(month_df['day'].iloc[ii])
                                bottomdepth.append(month_df['depth'].iloc[ii])
                                years.append(year)
                                counterii.append(ii)
                                break
                        break
                else: 
                    break
    print('**********')
    print(year)
    print(len(countwithinpolygon))
    print(len(densmld))
#     print(densmld)
    print(len(obs_lat))
    print(len(obs_lon))
    print(len(date_no))
    print(len(bottomdepth))
    print(len(years))
    print('')
# Out:
# **********
# 1993
# 1500
# 1336
# 1336
# 1336
# 1336
# 1336
# 1336
# **********
# 1994
# 3304
# 3039
# 3039
# 3039
# 3039
# 3039
# 3039
# **********
# 1995
# 4920
# 4447
# 4447
# 4447
# 4447
# 4447
# 4447
# **********
# 1996
# 7064
# 6310
# 6310
# 6310
# 6310
# 6310
# 6310
# **********
# 1997
# 9134
# 7897
# 7897
# 7897
# 7897
# 7897
# 7897
# **********
# 1998
# 11051
# 9511
# 9511
# 9511
# 9511
# 9511
# 9511
# **********
# 1999
# 13058
# 11310
# 11310
# 11310
# 11310
# 11310
# 11310

# %%
pandas_03 = pd.DataFrame({'obs_lat_d3': obs_lat,'obs_lon_d3': obs_lon,'bottomdepth_d3':bottomdepth,'year_d3':years, 'date_no_d3':date_no, '003densmld_d3':densmld})

# %%
# print(pandas_03)
pandas_03new = pandas_03.assign(location=[*zip(pandas_03.year_d3, pandas_03.obs_lon_d3, pandas_03.obs_lat_d3,pandas_03.date_no_d3)])
print(len(pandas_03new))
print(len(pandas_03new['location'].unique()))
pandas_03new_dd = pandas_03new.drop_duplicates(subset=['location'])
print(len(pandas_03new_dd))
# Out:
# 239
# 239
# 239

# %%
dens_threshold = 0.01

# %%
countwithinpolygon = []; densmld = []; obs_lat = []; obs_lon = []; date_no = []; bottomdepth = []; years = []
yearwithdata = []; datefull = []; finallatestdepth = []; glorysmld = []
glorys_lat = []; glorys_lon = []; glorys_lat_index = []; glorys_lon_index = []

for year in range(1993,2019):
    filename = 'casts_{}.mat'.format(year)
    file = scipy.io.loadmat(filename,squeeze_me=True)
    npfile = file['casts_{}'.format(year)]
    
    lat_intermediate = []; lon_intermediate = []; p_intermediate = []; counterii = []
    t_intermediate = []; yd_intermediate = []; sal_intermediate = []; floor_intermediate = []
    
    for i in range(len(npfile)):
        yd = npfile[i]['yd']
        p = npfile[i]['p']
        s = npfile[i]['s']
        t = npfile[i]['t']
        gear = npfile[i]['gear']
        floordepth = npfile[i]['depth']
#         if (yd > 334 and yd <= 365) or (yd >= 0 and yd <= 59):
        if yd > 334 and yd <= 365:  # and floordepth <= 200
            lat_intermediate.append(npfile[i]['lat'])
            lon_intermediate.append(npfile[i]['lon'])
            p_intermediate.append(npfile[i]['p'])
            t_intermediate.append(npfile[i]['t'])
            yd_intermediate.append(npfile[i]['yd'])
            sal_intermediate.append(npfile[i]['s'])
            floor_intermediate.append(npfile[i]['depth'])
    month_df = pd.DataFrame({'day': yd_intermediate,'lon': lon_intermediate,'lat': lat_intermediate, 'p': p_intermediate, 't': t_intermediate,'depth': floor_intermediate, 's': sal_intermediate})
    newdf = pd.DataFrame({'lon': lon_intermediate,'lat': lat_intermediate,'date': yd_intermediate})
    for ii in range(len(month_df)):
        new = newdf.iloc[ii].values
        point = Point(new)
        if isinstance(month_df['p'].iloc[ii], int) or isinstance(month_df['p'].iloc[ii], float) or isinstance(month_df['t'].iloc[ii], int) or isinstance(month_df['t'].iloc[ii], float):
            pass
        elif polygon_x.contains(point) == True or polygon_y.contains(point) == True or polygon_w.contains(point) == True or polygon_t.contains(point) == True or polygon_v.contains(point) == True:
            SA = gsw.SA_from_SP(month_df['s'].iloc[ii],month_df['p'].iloc[ii],month_df['lon'].iloc[ii],month_df['lat'].iloc[ii])
            CT = gsw.CT_from_pt(SA,month_df['t'].iloc[ii])
            DENS = gsw.sigma0(SA,CT)
            pt_df = pd.DataFrame({'p': month_df['p'].iloc[ii],'t': month_df['t'].iloc[ii], 's': month_df['s'].iloc[ii], 'CT': CT, 'DENSMLD': DENS}) 
            df_ptsnew = pt_df.dropna()
            df_final = pd.DataFrame(df_ptsnew.values)
            countwithinpolygon.append(1)
            l=[i for i in df_final[0] if i<=5] 
            if len(l) > 0:
                surfaceval = []
                numrange = []
                for iii in range(len(l)):
                    val = df_final[4][iii]
                    numrange.append(iii)
                    surfaceval.append(val)            
            surfacevalmean = statistics.mean(surfaceval)
            densfin = []; tempfin = []; pressurefin = []; salfin = []
            for iii in range(numrange[-1],len(df_final)): #for iii in range(numrange[-1]+1,len(df_final)):
                tempfin.append(df_final[1][iii])
                pressurefin.append(df_final[0][iii])
                salfin.append(df_final[2][iii])
                densfin.append(df_final[4][iii])
            d = {'temp': list(reversed(tempfin)), 'sal': list(reversed(salfin)), 'pressure': list(reversed(pressurefin)),'density': list(reversed(densfin))}
            dunreversed = {'temp': list(tempfin), 'sal': list(salfin), 'pressure': list(pressurefin), 'density': list(densfin)}
            dffinunreversed = pd.DataFrame(dunreversed)
            dffin = pd.DataFrame(d)
            
#             print(dffin)
            for ix in range(len(dffinunreversed)):
                if dffinunreversed.at[ix,'density'] >= (surfacevalmean - dens_threshold) and dffinunreversed.at[ix,'density'] <= (surfacevalmean + dens_threshold):
                    if dffinunreversed.at[len(dffinunreversed)-1,'density'] <= (surfacevalmean + dens_threshold) and dffinunreversed.at[len(dffinunreversed)-1,'density'] >= (surfacevalmean - dens_threshold):
                        looknow = list(dffinunreversed['density'].values)
                        looknow2 = [i for i in looknow if i >= (surfacevalmean + dens_threshold)]
                        looknow3 = [i for i in looknow if i <= (surfacevalmean - dens_threshold)]
                        if len(looknow2) == 0 and len(looknow3) == 0:
                            if (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] <= 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 5)) or (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] > 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 10)):
                                densmld.append(month_df['depth'].iloc[ii])
                                obs_lat.append(month_df['lat'].iloc[ii])
                                obs_lon.append(month_df['lon'].iloc[ii])
                                date_no.append(month_df['day'].iloc[ii])
                                bottomdepth.append(month_df['depth'].iloc[ii])
                                years.append(year)
                                counterii.append(ii)
                                # PLOTTING
#                                 plt.plot(df_final[4], df_final[0]*-1)
#                                 plt.axhline(y=month_df['depth'].iloc[ii]*-1,color='black', linestyle='-',alpha = 0.5)
#                                 plt.axhline(y=dffinunreversed.at[len(dffinunreversed)-1,'pressure']*-1,color='red', linestyle='-',alpha = 0.5)
#                                 plt.axhline(y=5*-1,color='green', linestyle='--',alpha = 1)
#                                 plt.axvline(x=surfacevalmean,color='green', linestyle='--',alpha = 1)
#                                 plt.axvline(x=surfacevalmean+0.03,color='green', linestyle='--',alpha = 0.5)
#                                 plt.axvline(x=surfacevalmean-0.03,color='green', linestyle='--',alpha = 0.5)
#                                 plt.show()
#                                 plt.plot(df_final[1], df_final[0]*-1)
#                                 plt.show()
                                break
                            else:#here
#                                 plt.plot(df_final[4], df_final[0]*-1)
#                                 plt.axhline(y=dffinunreversed.at[ix,'pressure']*-1,color='darkblue', linestyle='--',alpha = 1)
#                                 plt.axhline(y=month_df['depth'].iloc[ii]*-1,color='black', linestyle='-',alpha = 0.5)
#                                 plt.axhline(y=dffinunreversed.at[len(dffinunreversed)-1,'pressure']*-1,color='red', linestyle='-',alpha = 0.5)
#                                 plt.axhline(y=5*-1,color='green', linestyle='--',alpha = 1)
#                                 plt.axvline(x=surfacevalmean,color='green', linestyle='--',alpha = 1)
#                                 plt.axvline(x=surfacevalmean+0.03,color='green', linestyle='--',alpha = 0.5)
#                                 plt.axvline(x=surfacevalmean-0.03,color='green', linestyle='--',alpha = 0.5)
#                                 plt.show()
#                                 plt.plot(df_final[1], df_final[0]*-1)
#                                 plt.show()
                                break 
                        else:
                            if (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] <= 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 5)) or (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] > 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 10)):
                                for ix in range(len(dffinunreversed['density'])):
                                    if dffinunreversed.at[ix,'density'] >= (surfacevalmean - dens_threshold) and dffinunreversed.at[ix,'density'] <= (surfacevalmean + dens_threshold):
                                        pass
                                    else:
                                        densmld.append(dffinunreversed.at[ix,'pressure'])
                                        obs_lat.append(month_df['lat'].iloc[ii])
                                        obs_lon.append(month_df['lon'].iloc[ii])
                                        date_no.append(month_df['day'].iloc[ii])
                                        bottomdepth.append(month_df['depth'].iloc[ii])
                                        years.append(year)
                                        counterii.append(ii)
                                        #plotting
#                                         plt.plot(df_final[4], df_final[0]*-1)
#                                         plt.axhline(y=dffinunreversed.at[ix,'pressure']*-1,color='gray', linestyle='--',alpha = 1)
#                                         plt.axhline(y=month_df['depth'].iloc[ii]*-1,color='black', linestyle='-',alpha = 0.5)
#                                         plt.axhline(y=dffinunreversed.at[len(dffinunreversed)-1,'pressure']*-1,color='red', linestyle='-',alpha = 0.5)
#                                         plt.axhline(y=5*-1,color='green', linestyle='--',alpha = 1)
#                                         plt.axvline(x=surfacevalmean,color='green', linestyle='--',alpha = 1)
#                                         plt.axvline(x=surfacevalmean+0.01,color='green', linestyle='--',alpha = 0.5)
#                                         plt.axvline(x=surfacevalmean-0.01,color='green', linestyle='--',alpha = 0.5)
# #                                         plt.show()
# #                                         plt.plot(df_final[1], df_final[0]*-1)
# #                                         plt.axhline(y=5*-1,color='green', linestyle='--',alpha = 1)
# #                                         plt.axhline(y=24*-1,color='gray', linestyle='--',alpha = 1)
# #                                         plt.axvline(x=5.25,color='green', linestyle='--',alpha = 1)
# #                                         plt.axvline(x=5.25+0.2,color='green', linestyle='--',alpha = 0.5)
# #                                         plt.axvline(x=5.25-0.2,color='green', linestyle='--',alpha = 0.5)
# #                                         plt.axhline(y=dffinunreversed.at[len(dffinunreversed)-1,'pressure']*-1,color='red', linestyle='-',alpha = 0.5)
# #                                         plt.axhline(y=month_df['depth'].iloc[ii]*-1,color='black', linestyle='-',alpha = 0.5)
#                                         plt.show()
                                        break
                                break
                            else:
                                break
                    else: 
                        if dffinunreversed.at[ix,'density'] <= (surfacevalmean - dens_threshold) or dffinunreversed.at[ix,'density'] >= (surfacevalmean + dens_threshold):
                            if (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] <= 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 5) and dffinunreversed.at[ix,'pressure'] <= (month_df['depth'].iloc[ii] - 5)) or (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] > 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 10) and dffinunreversed.at[ix,'pressure'] <= (month_df['depth'].iloc[ii] - 10)):
                                pass
                            else:
                                densmld.append(dffinunreversed.at[ix,'pressure'])
                                obs_lat.append(month_df['lat'].iloc[ii])
                                obs_lon.append(month_df['lon'].iloc[ii])
                                date_no.append(month_df['day'].iloc[ii])
                                bottomdepth.append(month_df['depth'].iloc[ii])
                                years.append(year)
                                counterii.append(ii)
#                                 PLOTTING 
#                                 plt.plot(df_final[4], df_final[0]*-1)
#                                 plt.axhline(y=dffinunreversed.at[ix,'pressure']*-1,color='purple', linestyle='--',alpha = 0.5)
#                                 plt.axhline(y=month_df['depth'].iloc[ii]*-1,color='black', linestyle='-',alpha = 0.5)
#                                 plt.axhline(y=dffinunreversed.at[len(dffinunreversed)-1,'pressure']*-1,color='red', linestyle='-',alpha = 0.5)
#                                 plt.axhline(y=5*-1,color='green', linestyle='--',alpha = 1)
#                                 plt.axvline(x=surfacevalmean,color='green', linestyle='--',alpha = 1)
#                                 plt.axvline(x=surfacevalmean+0.03,color='green', linestyle='--',alpha = 0.5)
#                                 plt.axvline(x=surfacevalmean-0.03,color='green', linestyle='--',alpha = 0.5)
#                                 plt.show()
#                                 plt.plot(df_final[1], df_final[0]*-1)
#                                 plt.show()
                                break           
                        else: 
                            if dffinunreversed.at[ix,'density'] >= (surfacevalmean + dens_threshold) or dffinunreversed.at[ix,'density'] <= (surfacevalmean - dens_threshold):
                                break 
                elif dffinunreversed.at[ix,'density'] <= (surfacevalmean - dens_threshold) or dffinunreversed.at[ix,'density'] >= (surfacevalmean + dens_threshold):
                    if (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] <= 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 5) and dffinunreversed.at[ix,'pressure'] <= (month_df['depth'].iloc[ii] - 5)) or (dffinunreversed.at[len(dffinunreversed)-1,'pressure'] > 25 and dffinunreversed.at[len(dffinunreversed)-1,'pressure'] >= (month_df['depth'].iloc[ii] - 10) and dffinunreversed.at[ix,'pressure'] <= (month_df['depth'].iloc[ii] - 10)):
#                         pass
#                     else:
                        for ix in range(len(dffinunreversed['density'])):
                            if dffinunreversed.at[ix,'density'] >= (surfacevalmean - dens_threshold) and dffinunreversed.at[ix,'density'] <= (surfacevalmean + dens_threshold):
                                pass
                            else:
                                densmld.append(dffinunreversed.at[ix,'pressure'])
                                obs_lat.append(month_df['lat'].iloc[ii])
                                obs_lon.append(month_df['lon'].iloc[ii])
                                date_no.append(month_df['day'].iloc[ii])
                                bottomdepth.append(month_df['depth'].iloc[ii])
                                years.append(year)
                                counterii.append(ii)
                                break
                        break
                else: 
                    break
    print('**********')
    print(year)
    print(len(countwithinpolygon))
    print(len(densmld))
    print(len(obs_lat))
    print(len(obs_lon))
    print(len(date_no))
    print(len(bottomdepth))
    print(len(years))
    print('')
# Out:
# **********
# 1993
# 115
# 113
# 113
# 113
# 113
# 113
# 113
#
# **********
# 1994
# 117
# 115
# 115
# 115
# 115
# 115
# 115
#
# **********
# 1995
# 117
# 115
# 115
# 115
# 115
# 115
# 115
#
# **********
# 1996
# 117
# 115
# 115
# 115
# 115
# 115
# 115
#
# **********
# 1997
# 117
# 115
# 115
# 115
# 115
# 115
# 115
#
# **********
# 1998
# 117
# 115
# 115
# 115
# 115
# 115
# 115
#
# **********
# 1999
# 117
# 115
# 115
# 115
# 115
# 115
# 115
#
# **********
# 2000
# 117
# 115
# 115
# 115
# 115
# 115
# 115
#
# **********
# 2001
# 117
# 115
# 115
# 115
# 115
# 115
# 115
#
# **********
# 2002
# 117
# 115
# 115
# 115
# 115
# 115
# 115
#
# **********
# 2003
# 117
# 115
# 115
# 115
# 115
# 115
# 115
#
# **********
# 2004
# 117
# 115
# 115
# 115
# 115
# 115
# 115
#
# **********
# 2005
# 117
# 115
# 115
# 115
# 115
# 115
# 115
#
# **********
# 2006
# 117
# 115
# 115
# 115
# 115
# 115
# 115
#
# **********
# 2007
# 117
# 115
# 115
# 115
# 115
# 115
# 115
#
# **********
# 2008
# 117
# 115
# 115
# 115
# 115
# 115
# 115
#
# **********
# 2009
# 117
# 115
# 115
# 115
# 115
# 115
# 115
#
# **********
# 2010
# 186
# 178
# 178
# 178
# 178
# 178
# 178
#
# **********
# 2011
# 258
# 242
# 242
# 242
# 242
# 242
# 242
#
# **********
# 2012
# 258
# 242
# 242
# 242
# 242
# 242
# 242
#
# **********
# 2013
# 258
# 242
# 242
# 242
# 242
# 242
# 242
#
# **********
# 2014
# 258
# 242
# 242
# 242
# 242
# 242
# 242
#
# **********
# 2015
# 258
# 242
# 242
# 242
# 242
# 242
# 242
#
# **********
# 2016
# 258
# 242
# 242
# 242
# 242
# 242
# 242
#
# **********
# 2017
# 258
# 242
# 242
# 242
# 242
# 242
# 242
#
# **********
# 2018
# 258
# 242
# 242
# 242
# 242
# 242
# 242

# %%
pandas_01 = pd.DataFrame({'obs_lat_d1': obs_lat,'obs_lon_d1': obs_lon,'bottomdepth_d1':bottomdepth,'year_d1':years, 'date_no_d1':date_no, '001densmld_d1':densmld}) 
print(len(pandas_01))
# Out:
# 242

# %%
pandas_01new = pandas_01.assign(location=[*zip(pandas_01.year_d1, pandas_01.obs_lon_d1, pandas_01.obs_lat_d1,pandas_01.date_no_d1)])
print(len(pandas_01new))
print(len(pandas_01new['location'].unique()))
pandas_01new_dd = pandas_01new.drop_duplicates(subset=['location'])
print(len(pandas_01new_dd))
# Out:
# 242
# 242
# 242

# %%
#pandas_02new_dd, pandas_01new_dd, pandas_03new_dd
pandas_001and003 = pd.merge(pandas_01new, pandas_03new, left_on=['location'], 
                        right_on = ['location'], left_index=True, how='outer', sort=False)
print(len(pandas_001and003))
pandas_001and003_dd = pandas_001and003.drop_duplicates(subset=['location'])
print(len(pandas_001and003_dd))

pandas_001and003and02 = pd.merge(pandas_001and003_dd, pandas_02new, left_on=['location'], 
                        right_on = ['location'], left_index=True, how='outer', sort=False)
print(len(pandas_001and003and02))
pandas_001and003and02_dd = pandas_001and003and02.drop_duplicates(subset=['location'])
print(len(pandas_001and003and02_dd))
# Out:
# 242
# 242
# 243
# 243

# %%
print(pandas_001and003and02_dd)
# Out:
#        obs_lat_d1  obs_lon_d1  bottomdepth_d1  year_d1  date_no_d1  \
# 0.0       40.9000     70.6833            53.0   1993.0       335.0
# 1.0       41.0350     70.3667            40.0   1993.0       335.0
# 2.0       41.0650     70.0300            25.0   1993.0       335.0
# 3.0       40.9317     70.1333            24.0   1993.0       335.0
# 4.0       40.9300     69.9850            22.0   1993.0       335.0
# ...           ...         ...             ...      ...         ...
# 234.0     41.0367     70.2817            35.0   2011.0       342.0
# 235.0     41.0367     70.3333            38.0   2011.0       342.0
# 236.0     41.0367     70.3983            41.0   2011.0       342.0
# 237.0     41.0600     70.5133            42.0   2011.0       342.0
# 128.0         NaN         NaN             NaN      NaN         NaN
#
#        001densmld_d1                       location  obs_lat_d3  obs_lon_d3  \
# 0.0             32.0     (1993, 70.6833, 40.9, 335)     40.9000     70.6833
# 1.0             40.0   (1993, 70.3667, 41.035, 335)     41.0350     70.3667
# 2.0             18.0     (1993, 70.03, 41.065, 335)     41.0650     70.0300
# 3.0             24.0  (1993, 70.1333, 40.9317, 335)     40.9317     70.1333
# 4.0             18.0     (1993, 69.985, 40.93, 335)     40.9300     69.9850
# ...              ...                            ...         ...         ...
# 234.0            8.0  (2011, 70.2817, 41.0367, 342)     41.0367     70.2817
# 235.0           12.0  (2011, 70.3333, 41.0367, 342)     41.0367     70.3333
# 236.0           17.0  (2011, 70.3983, 41.0367, 342)     41.0367     70.3983
# 237.0           16.0    (2011, 70.5133, 41.06, 342)     41.0600     70.5133
# 128.0            NaN   (2010, 69.525, 42.5117, 335)         NaN         NaN
#
#        bottomdepth_d3  year_d3  date_no_d3  003densmld_d3  obs_lat_t  \
# 0.0              53.0   1993.0       335.0           53.0    40.9000
# 1.0              40.0   1993.0       335.0           40.0    41.0350
# 2.0              25.0   1993.0       335.0           25.0    41.0650
# 3.0              24.0   1993.0       335.0           24.0    40.9317
# 4.0              22.0   1993.0       335.0           22.0    40.9300
# ...               ...      ...         ...            ...        ...
# 234.0            35.0   2011.0       342.0           13.0    41.0367
# 235.0            38.0   2011.0       342.0           16.0    41.0367
# 236.0            41.0   2011.0       342.0           30.0    41.0367
# 237.0            42.0   2011.0       342.0           23.0    41.0600
# 128.0             NaN      NaN         NaN            NaN    42.5117
#
#        obs_lon_t  bottomdepth_t  year_t  date_no_t  02tempmld_t
# 0.0      70.6833           53.0  1993.0      335.0         53.0
# 1.0      70.3667           40.0  1993.0      335.0         40.0
# 2.0      70.0300           25.0  1993.0      335.0         25.0
# 3.0      70.1333           24.0  1993.0      335.0         24.0
# 4.0      69.9850           22.0  1993.0      335.0         22.0
# ...          ...            ...     ...        ...          ...
# 234.0    70.2817           35.0  2011.0      342.0         13.0
# 235.0    70.3333           38.0  2011.0      342.0         38.0
# 236.0    70.3983           41.0  2011.0      342.0         41.0
# 237.0    70.5133           42.0  2011.0      342.0         42.0
# 128.0    69.5250          273.0  2010.0      335.0         98.0
#
# [243 rows x 19 columns]

# %%
pandas_001and003and02_dd.obs_lat_d3 = pandas_001and003and02_dd.obs_lat_d3.combine_first(pandas_001and003and02_dd.obs_lat_t) 
pandas_001and003and02_dd.obs_lon_d3 = pandas_001and003and02_dd.obs_lon_d3.combine_first(pandas_001and003and02_dd.obs_lon_t) 
pandas_001and003and02_dd.date_no_d3 = pandas_001and003and02_dd.date_no_d3.combine_first(pandas_001and003and02_dd.date_no_t) 
pandas_001and003and02_dd.year_d3 = pandas_001and003and02_dd.year_d3.combine_first(pandas_001and003and02_dd.year_t) 
pandas_001and003and02_dd.bottomdepth_d3 = pandas_001and003and02_dd.bottomdepth_d3.combine_first(pandas_001and003and02_dd.bottomdepth_t) 

pandas_001and003and02_dd.obs_lat_d3 = pandas_001and003and02_dd.obs_lat_d3.combine_first(pandas_001and003and02_dd.obs_lat_d1) 
pandas_001and003and02_dd.obs_lon_d3 = pandas_001and003and02_dd.obs_lon_d3.combine_first(pandas_001and003and02_dd.obs_lon_d1) 
pandas_001and003and02_dd.date_no_d3 = pandas_001and003and02_dd.date_no_d3.combine_first(pandas_001and003and02_dd.date_no_d1) 
pandas_001and003and02_dd.year_d3 = pandas_001and003and02_dd.year_d3.combine_first(pandas_001and003and02_dd.year_d1) 
pandas_001and003and02_dd.bottomdepth_d3 = pandas_001and003and02_dd.bottomdepth_d3.combine_first(pandas_001and003and02_dd.bottomdepth_d1)

# %%
sum(pd.isnull(pandas_001and003and02_dd['obs_lat_d3']))
# Out:
# 0

# %%
pandas_001and003and02_dd_new = pandas_001and003and02_dd.drop(columns=['obs_lat_d1', 'obs_lon_d1', 'bottomdepth_d1', 'year_d1','date_no_d1','obs_lat_t',
                                                   'obs_lon_t','bottomdepth_t','year_t','date_no_t'])
pandas_001and003and02_dd_new_reset = pandas_001and003and02_dd_new.reset_index()
pandas_001and003and02_dd_new_reset_dc = pandas_001and003and02_dd_new_reset.drop(columns = ['index'])

# %%
print(pandas_001and003and02_dd_new_reset_dc)
# Out:
#      001densmld_d1                       location  obs_lat_d3  obs_lon_d3  \
# 0             32.0     (1993, 70.6833, 40.9, 335)     40.9000     70.6833
# 1             40.0   (1993, 70.3667, 41.035, 335)     41.0350     70.3667
# 2             18.0     (1993, 70.03, 41.065, 335)     41.0650     70.0300
# 3             24.0  (1993, 70.1333, 40.9317, 335)     40.9317     70.1333
# 4             18.0     (1993, 69.985, 40.93, 335)     40.9300     69.9850
# ..             ...                            ...         ...         ...
# 238            8.0  (2011, 70.2817, 41.0367, 342)     41.0367     70.2817
# 239           12.0  (2011, 70.3333, 41.0367, 342)     41.0367     70.3333
# 240           17.0  (2011, 70.3983, 41.0367, 342)     41.0367     70.3983
# 241           16.0    (2011, 70.5133, 41.06, 342)     41.0600     70.5133
# 242            NaN   (2010, 69.525, 42.5117, 335)     42.5117     69.5250
#
#      bottomdepth_d3  year_d3  date_no_d3  003densmld_d3  02tempmld_t
# 0              53.0   1993.0       335.0           53.0         53.0
# 1              40.0   1993.0       335.0           40.0         40.0
# 2              25.0   1993.0       335.0           25.0         25.0
# 3              24.0   1993.0       335.0           24.0         24.0
# 4              22.0   1993.0       335.0           22.0         22.0
# ..              ...      ...         ...            ...          ...
# 238            35.0   2011.0       342.0           13.0         13.0
# 239            38.0   2011.0       342.0           16.0         38.0
# 240            41.0   2011.0       342.0           30.0         41.0
# 241            42.0   2011.0       342.0           23.0         42.0
# 242           273.0   2010.0       335.0            NaN         98.0
#
# [243 rows x 9 columns]

# %%
pandas_001and003and02_dd_new_reset_dc_renamed = pandas_001and003and02_dd_new_reset_dc.rename(columns={"001densmld_d1": "001densmld", "003densmld_d3": "003densmld", "02tempmld_t": "02tempmld", "obs_lat_d3": "obs_lat", "obs_lon_d3": "obs_lon", "bottomdepth_d3": "bottomdepth", "year_d3": "year", "date_no_d3": "date_no"})

# %%
print(pandas_001and003and02_dd_new_reset_dc_renamed)
# Out:
#      001densmld                       location  obs_lat  obs_lon  bottomdepth  \
# 0          32.0     (1993, 70.6833, 40.9, 335)  40.9000  70.6833         53.0
# 1          40.0   (1993, 70.3667, 41.035, 335)  41.0350  70.3667         40.0
# 2          18.0     (1993, 70.03, 41.065, 335)  41.0650  70.0300         25.0
# 3          24.0  (1993, 70.1333, 40.9317, 335)  40.9317  70.1333         24.0
# 4          18.0     (1993, 69.985, 40.93, 335)  40.9300  69.9850         22.0
# ..          ...                            ...      ...      ...          ...
# 238         8.0  (2011, 70.2817, 41.0367, 342)  41.0367  70.2817         35.0
# 239        12.0  (2011, 70.3333, 41.0367, 342)  41.0367  70.3333         38.0
# 240        17.0  (2011, 70.3983, 41.0367, 342)  41.0367  70.3983         41.0
# 241        16.0    (2011, 70.5133, 41.06, 342)  41.0600  70.5133         42.0
# 242         NaN   (2010, 69.525, 42.5117, 335)  42.5117  69.5250        273.0
#
#        year  date_no  003densmld  02tempmld
# 0    1993.0    335.0        53.0       53.0
# 1    1993.0    335.0        40.0       40.0
# 2    1993.0    335.0        25.0       25.0
# 3    1993.0    335.0        24.0       24.0
# 4    1993.0    335.0        22.0       22.0
# ..      ...      ...         ...        ...
# 238  2011.0    342.0        13.0       13.0
# 239  2011.0    342.0        16.0       38.0
# 240  2011.0    342.0        30.0       41.0
# 241  2011.0    342.0        23.0       42.0
# 242  2010.0    335.0         NaN       98.0
#
# [243 rows x 9 columns]

# %%
pandas_001and003and02_dd_new_reset_dc_renamed.to_csv('12_finaldataset.csv')

# %%
#2

# %%
month = pd.read_csv('01_final.csv')
monthnew = month.assign(location=[*zip(month.year, month.obs_lon, month.obs_lat,month.date_no)])
print(len(monthnew))
monthnew_dd = monthnew.drop_duplicates(subset=['location'])
print(len(monthnew_dd))
# Out:
# 1157
# 1149

# %%
monthnew_dd_dc = monthnew_dd.drop(columns=['Unnamed: 0', '001densmld', '003densmld', 'bottomdepth','date_no','02tempmld',
                                                   'obs_lat','obs_lon','year','date_no'])
print(monthnew_dd_dc)
# Out:
#       glorys_lat_index  glorys_lon_index  glorys_mld  glorysmld_new003  \
# 0                 71.0              82.0   36.469620         55.764290
# 1                 68.0              83.0   29.602957         40.344051
# 2                 68.0              89.0   47.151100         55.764290
# 3                 70.0              91.0   44.251842         55.764290
# 4                 71.0              88.0   15.106663         25.211411
# ...                ...               ...         ...               ...
# 1151              37.0              38.0         NaN          9.572997
# 1153              75.0             121.0         NaN         40.344051
# 1154              82.0             142.0         NaN         18.495560
# 1155              82.0             116.0         NaN         92.326073
# 1156              76.0             113.0         NaN         40.344051
#
#       glorys_lat  glorys_lon  glorysmld_new001  \
# 0      40.916668  -71.166664         25.211411
# 1      40.666668  -71.083336         34.434151
# 2      40.666668  -70.583336         47.373692
# 3      40.833332  -70.416664         47.373692
# 4      40.916668  -70.666664         15.810070
# ...          ...         ...               ...
# 1151   38.083332  -74.833336          6.440614
# 1153   41.250000  -67.916664         13.467140
# 1154   41.833332  -66.166664         15.810070
# 1155   41.833332  -68.333336         92.326073
# 1156   41.333332  -68.583336         34.434151
#
#                               location
# 0        (1993.0, 71.17, 40.9517, 6.0)
# 1        (1993.0, 71.05, 40.6983, 6.0)
# 2        (1993.0, 70.55, 40.6517, 6.0)
# 3      (1993.0, 70.3833, 40.8317, 6.0)
# 4      (1993.0, 70.6833, 40.9017, 6.0)
# ...                                ...
# 1151  (2012.0, 74.8533, 38.0433, 24.0)
# 1153    (1998.0, 67.958, 41.237, 10.0)
# 1154     (1998.0, 66.18, 41.803, 13.0)
# 1155    (1998.0, 68.303, 41.837, 16.0)
# 1156    (1998.0, 68.597, 41.307, 18.0)
#
# [1149 rows x 8 columns]

# %%
gwithobs = pd.merge(monthnew_dd_dc, pandas_001and003and02_dd_new_reset_dc_renamed, left_on=['location'], 
                        right_on = ['location'], left_index=True, how='outer', sort=False)

# %%
print(gwithobs)
# Out:
#        glorys_lat_index  glorys_lon_index  glorys_mld  glorysmld_new003  \
# 0.0                71.0              82.0   36.469620         55.764290
# 1.0                68.0              83.0   29.602957         40.344051
# 2.0                68.0              89.0   47.151100         55.764290
# 3.0                70.0              91.0   44.251842         55.764290
# 4.0                71.0              88.0   15.106663         25.211411
# ...                 ...               ...         ...               ...
# 383.0               NaN               NaN         NaN               NaN
# 384.0               NaN               NaN         NaN               NaN
# 410.0               NaN               NaN         NaN               NaN
# 515.0               NaN               NaN         NaN               NaN
# 519.0               NaN               NaN         NaN               NaN
#
#        glorys_lat  glorys_lon  glorysmld_new001  \
# 0.0     40.916668  -71.166664         25.211411
# 1.0     40.666668  -71.083336         34.434151
# 2.0     40.666668  -70.583336         47.373692
# 3.0     40.833332  -70.416664         47.373692
# 4.0     40.916668  -70.666664         15.810070
# ...           ...         ...               ...
# 383.0         NaN         NaN               NaN
# 384.0         NaN         NaN               NaN
# 410.0         NaN         NaN               NaN
# 515.0         NaN         NaN               NaN
# 519.0         NaN         NaN               NaN
#
#                               location  001densmld  obs_lat  obs_lon  \
# 0.0      (1993.0, 71.17, 40.9517, 6.0)        53.0  40.9517  71.1700
# 1.0      (1993.0, 71.05, 40.6983, 6.0)        46.0  40.6983  71.0500
# 2.0      (1993.0, 70.55, 40.6517, 6.0)        33.0  40.6517  70.5500
# 3.0    (1993.0, 70.3833, 40.8317, 6.0)        32.0  40.8317  70.3833
# 4.0    (1993.0, 70.6833, 40.9017, 6.0)        54.0  40.9017  70.6833
# ...                                ...         ...      ...      ...
# 383.0       (1997, 67.212, 41.943, 18)        55.0  41.9430  67.2120
# 384.0        (1997, 67.662, 42.17, 19)        39.5  42.1700  67.6620
# 410.0         (1998, 68.26, 41.013, 9)        50.0  41.0130  68.2600
# 515.0       (1999, 66.677, 41.933, 20)        65.0  41.9330  66.6770
# 519.0       (1999, 67.647, 41.708, 21)         6.0  41.7080  67.6470
#
#        bottomdepth    year  date_no  003densmld  02tempmld
# 0.0           53.0  1993.0      6.0        53.0       53.0
# 1.0           61.0  1993.0      6.0        49.0       50.0
# 2.0           62.0  1993.0      6.0        45.0       33.0
# 3.0           51.0  1993.0      6.0        36.0       37.0
# 4.0           54.0  1993.0      6.0        54.0       54.0
# ...            ...     ...      ...         ...        ...
# 383.0         55.0  1997.0     18.0        55.0       55.0
# 384.0        182.0  1997.0     19.0        48.3       64.5
# 410.0         50.0  1998.0      9.0        50.0       50.0
# 515.0         65.0  1999.0     20.0        65.0       65.0
# 519.0         57.0  1999.0     21.0        57.0       57.0
#
# [1156 rows x 16 columns]

# %%
sum(pd.isnull(gwithobs['glorys_lat_index']))
sum(pd.isnull(gwithobs['glorys_lon_index']))
# Out:
# 7

# %%
month = pd.read_csv('05_final.csv')
print(len(month))
# Out:
# 4368

# %%
monthnew = month.assign(location=[*zip(month.year, month.obs_lon, month.obs_lat,month.date_no)])
print(len(monthnew['location'].unique()))
# Out:
# 4092

# %%
monthnew_dd = monthnew.drop_duplicates(subset=['location'])
print(len(monthnew_dd))
# Out:
# 4092

# %%
pandas_001and003 = pd.merge(monthnew_dd, pandas_02new_dd, left_on=['location'], 
                        right_on = ['location'], left_index=True, how='outer', sort=False)

# %%
print(len(pandas_001and003))
# Out:
# 4394

# %%
pandas_00100302new = pandas_001and003.drop(columns=['date_no_t', 'year_t', 'bottomdepth_t', 'obs_lon_t','obs_lat_t','location' ])

# %%
print(len(pandas_00100302new))
# Out:
# 4394

# %%
plt.scatter(pandas_00100302new['02tempmld_t'],pandas_00100302new['003densmld'],alpha=0.03)
plt.show()

# %%
plt.scatter(pandas_001and003['02tempmld'],pandas_001and003['003densmld'],alpha=0.03)
plt.show()

# %%
plt.scatter(pandas_001and003['02tempmld'],pandas_001and003['02tempmld_t'],alpha=0.03)
plt.show()
plt.scatter(pandas_001and003['02tempmld'],pandas_001and003['02tempmld_t'],alpha=1)
plt.show()

# %%
plt.scatter(pandas_001and003['02tempmld'],pandas_001and003['001densmld'],alpha=0.03)
plt.show()

# %%
plt.scatter(pandas_001and003['02tempmld_t'],pandas_001and003['001densmld'],alpha=0.03)
plt.show()

# %%
print(np.nanmin(densmld))
# Out:
# 3.0

# %%
print(type(date_no_int[1]))
# Out:
# <class 'int'>

# %%
date_no_int = [int(i) for i in date_no]

# %%
pandas_03 = pd.DataFrame({'obs_lat_d3': obs_lat,'obs_lon_d3': obs_lon,'bottomdepth_d3':bottomdepth,'year_d3':years, 'date_no_d3':date_no_int, '003densmld_d3':densmld}) 
print(len(pandas_03))
# Out:
# 3914

# %%
pandas_03new = pandas_03.assign(location=[*zip(pandas_03.year_d3, pandas_03.obs_lon_d3, pandas_03.obs_lat_d3,pandas_03.date_no_d3)])
print(len(pandas_03new['location'].unique()))
# Out:
# 3784

# %%
pandas_03new_dd = pandas_03new.drop_duplicates(subset=['location'])
print(len(pandas_03new_dd))
# Out:
# 3784

# %%
pandas_00100302newnew = pandas_00100302new.assign(location=[*zip(pandas_00100302new.year, pandas_00100302new.obs_lon, pandas_00100302new.obs_lat,pandas_00100302new.date_no)])
print(len(pandas_00100302newnew))
print(len(pandas_00100302newnew['location'].unique()))
# Out:
# 4394
# 4394

# %%
pandas_full_undropped = pd.merge(pandas_00100302newnew, pandas_03new, left_on=['location'], 
                        right_on = ['location'], left_index=True, how='outer', sort=False)

# %%
pandas_full_undropped_dd = pandas_full_undropped.drop_duplicates(subset=['location'])
print(len(pandas_full_undropped_dd))
# Out:
# 4697

# %%
# print(pandas_full_undropped)

# %%
pandas_full_drop = pandas_full_undropped_dd.drop(columns=['date_no_d3', 'year_d3', 'bottomdepth_d3', 'obs_lon_d3','obs_lat_d3','location','Unnamed: 0' ])

# %%
print(pandas_full_drop.shape)
# Out:
# (4697, 17)

# %%
plt.scatter(pandas_full_undropped['003densmld_d3'],pandas_full_undropped['02tempmld_t'],alpha=0.03)
plt.show()
plt.scatter(pandas_full_undropped['003densmld'],pandas_full_undropped['02tempmld_t'],alpha=0.03)
plt.show()
plt.scatter(pandas_full_undropped['003densmld'],pandas_full_undropped['003densmld_d3'],alpha=1)
plt.show()

# %%
print(pandas_full_drop)
# Out:
#         001densmld  003densmld  glorys_lat_index  glorys_lon_index  \
# NaN            5.0         5.0              19.0              40.0
# NaN            5.0         5.0              38.0              50.0
# NaN            4.0         4.0              43.0              58.0
# NaN            6.0         9.0              46.0              61.0
# NaN            5.0         8.0              49.0              64.0
# ...            ...         ...               ...               ...
# 3901.0         NaN         NaN               NaN               NaN
# 3906.0         NaN         NaN               NaN               NaN
# 3908.0         NaN         NaN               NaN               NaN
# 3911.0         NaN         NaN               NaN               NaN
# 3913.0         NaN         NaN               NaN               NaN
#
#         bottomdepth  date_no  02tempmld  glorys_mld  glorysmld_new003  \
# NaN          2200.0    129.0        5.0   10.528886               NaN
# NaN           956.0    130.0        NaN   10.528886               NaN
# NaN           803.0    131.0        4.0   10.528886               NaN
# NaN           775.0    131.0       14.0   10.528886               NaN
# NaN           643.0    132.0       10.0   10.376293               NaN
# ...             ...      ...        ...         ...               ...
# 3901.0          NaN      NaN        NaN         NaN               NaN
# 3906.0          NaN      NaN        NaN         NaN               NaN
# 3908.0          NaN      NaN        NaN         NaN               NaN
# 3911.0          NaN      NaN        NaN         NaN               NaN
# 3913.0          NaN      NaN        NaN         NaN               NaN
#
#         obs_lat  obs_lon    year  glorys_lat  glorys_lon  glorysmld_new001  \
# NaN     36.5517  74.6667  1993.0   36.583332  -74.666664               NaN
# NaN     38.1667  73.8500  1993.0   38.166668  -73.833336               NaN
# NaN     38.5650  73.1633  1993.0   38.583332  -73.166664               NaN
# NaN     38.8150  72.9017  1993.0   38.833332  -72.916664               NaN
# NaN     39.1167  72.6700  1993.0   39.083332  -72.666664               NaN
# ...         ...      ...     ...         ...         ...               ...
# 3901.0      NaN      NaN     NaN         NaN         NaN               NaN
# 3906.0      NaN      NaN     NaN         NaN         NaN               NaN
# 3908.0      NaN      NaN     NaN         NaN         NaN               NaN
# 3911.0      NaN      NaN     NaN         NaN         NaN               NaN
# 3913.0      NaN      NaN     NaN         NaN         NaN               NaN
#
#         02tempmld_t  003densmld_d3
# NaN             NaN            NaN
# NaN             NaN            NaN
# NaN             NaN            NaN
# NaN             NaN            NaN
# NaN             NaN            NaN
# ...             ...            ...
# 3901.0          NaN           51.0
# 3906.0          NaN           42.0
# 3908.0          NaN           45.0
# 3911.0          NaN            9.0
# 3913.0          NaN            5.0
#
# [4697 rows x 17 columns]

# %%
pandas_full_drop_reset = pandas_full_drop.reset_index()

# %%
print(pandas_full_drop_reset)
# Out:
#        index  001densmld  003densmld  glorys_lat_index  glorys_lon_index  \
# 0        NaN         5.0         5.0              19.0              40.0
# 1        NaN         5.0         5.0              38.0              50.0
# 2        NaN         4.0         4.0              43.0              58.0
# 3        NaN         6.0         9.0              46.0              61.0
# 4        NaN         5.0         8.0              49.0              64.0
# ...      ...         ...         ...               ...               ...
# 4692  3901.0         NaN         NaN               NaN               NaN
# 4693  3906.0         NaN         NaN               NaN               NaN
# 4694  3908.0         NaN         NaN               NaN               NaN
# 4695  3911.0         NaN         NaN               NaN               NaN
# 4696  3913.0         NaN         NaN               NaN               NaN
#
#       bottomdepth  date_no  02tempmld  glorys_mld  glorysmld_new003  obs_lat  \
# 0          2200.0    129.0        5.0   10.528886               NaN  36.5517
# 1           956.0    130.0        NaN   10.528886               NaN  38.1667
# 2           803.0    131.0        4.0   10.528886               NaN  38.5650
# 3           775.0    131.0       14.0   10.528886               NaN  38.8150
# 4           643.0    132.0       10.0   10.376293               NaN  39.1167
# ...           ...      ...        ...         ...               ...      ...
# 4692          NaN      NaN        NaN         NaN               NaN      NaN
# 4693          NaN      NaN        NaN         NaN               NaN      NaN
# 4694          NaN      NaN        NaN         NaN               NaN      NaN
# 4695          NaN      NaN        NaN         NaN               NaN      NaN
# 4696          NaN      NaN        NaN         NaN               NaN      NaN
#
#       obs_lon    year  glorys_lat  glorys_lon  glorysmld_new001  02tempmld_t  \
# 0     74.6667  1993.0   36.583332  -74.666664               NaN          NaN
# 1     73.8500  1993.0   38.166668  -73.833336               NaN          NaN
# 2     73.1633  1993.0   38.583332  -73.166664               NaN          NaN
# 3     72.9017  1993.0   38.833332  -72.916664               NaN          NaN
# 4     72.6700  1993.0   39.083332  -72.666664               NaN          NaN
# ...       ...     ...         ...         ...               ...          ...
# 4692      NaN     NaN         NaN         NaN               NaN          NaN
# 4693      NaN     NaN         NaN         NaN               NaN          NaN
# 4694      NaN     NaN         NaN         NaN               NaN          NaN
# 4695      NaN     NaN         NaN         NaN               NaN          NaN
# 4696      NaN     NaN         NaN         NaN               NaN          NaN
#
#       003densmld_d3
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 4692           51.0
# 4693           42.0
# 4694           45.0
# 4695            9.0
# 4696            5.0
#
# [4697 rows x 18 columns]

# %%
pandas_01 = pd.DataFrame({'obs_lat_d1': obs_lat,'obs_lon_d1': obs_lon,'bottomdepth_d1':bottomdepth,'year_d1':years, 'date_no_d1':date_no, '001densmld_d1':densmld}) 
print(len(pandas_01))
# Out:
# 3914

# %%
pandas_01new = pandas_01.assign(location=[*zip(pandas_01.year_d1, pandas_01.obs_lon_d1, pandas_01.obs_lat_d1,pandas_01.date_no_d1)])
print(len(pandas_01new['location'].unique()))
# Out:
# 3784

# %%
pandas_01new_dd = pandas_01new.drop_duplicates(subset=['location'])
print(len(pandas_01new_dd))
# Out:
# 3784

# %%
true_one = pd.merge(pandas_01new_dd, pandas_03new, left_on=['location'], 
                        right_on = ['location'], left_index=True, how='outer', sort=False)

# %%
pandas_03new_reset = pandas_03new.reset_index()
true_two_reset = true_two.reset_index()
print(len(pandas_03new_reset))
print(len(true_two_reset))
# Out:
# 3914
# 5066

# %%
print(type(pandas_03new_reset['location']))
print(type(true_two_reset['location']))

pandas_03new_reset_dd = pandas_03new_reset.drop_duplicates(subset=['location'])
print(len(pandas_03new_reset_dd))

true_two_reset_dd = true_two_reset.drop_duplicates(subset=['location'])
print(len(true_two_reset_dd))

true_twonw = pd.merge(pandas_03new_reset_dd, true_two_reset_dd, left_on=['location'], 
                        right_on = ['location'], left_index=True, how='outer', sort=False)

print(len(true_twonw))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# 3784
# 3798
# 3798

# %%
print(true_twonw.iloc[42])
# Out:
# index_x                                     43
# obs_lat_d3                             40.8767
# obs_lon_d3                              67.935
# bottomdepth_d3                              61
# year_d3                                   1993
# date_no_d3                                 140
# 003densmld_d3                                6
# location          (1993, 67.935, 40.8767, 140)
# index_y                                     43
# obs_lat_t                              40.8767
# obs_lon_t                               67.935
# bottomdepth_t                               61
# year_t                                    1993
# date_no_t                                  140
# 02tempmld_t                                  8
# obs_lat_d1                             40.8767
# obs_lon_d1                              67.935
# bottomdepth_d1                              61
# year_d1                                   1993
# date_no_d1                                 140
# 001densmld_d1                                6
# Name: 45, dtype: object

# %%
pandas_02new
true_two = pd.merge(pandas_02new, pandas_01new, left_on=['location'], 
                        right_on = ['location'], left_index=True, how='outer', sort=False)

# %%
print(pandas_03new)
# Out:
#       obs_lat_d3  obs_lon_d3  bottomdepth_d3  year_d3  date_no_d3  \
# 0      40.618300   68.461700              73     1993         139
# 1      40.648000   67.550000              84     1993         141
# 2      40.693300   68.203300              77     1993         139
# 3      40.650000   67.620000              85     1993         142
# 4      40.800000   68.001700              69     1993         139
# ...          ...         ...             ...      ...         ...
# 3909   41.501667   68.908333             156     2018         151
# 3910   41.496667   68.906667             154     2018         151
# 3911   41.580000   68.668333             135     2018         151
# 3912   41.578333   68.663333             137     2018         151
# 3913   41.980000   67.715000              51     2018         151
#
#       003densmld_d3                                           location
# 0              14.0                      (1993, 68.4617, 40.6183, 139)
# 1               7.0                         (1993, 67.55, 40.648, 141)
# 2               9.0                      (1993, 68.2033, 40.6933, 139)
# 3               7.0                          (1993, 67.62, 40.65, 142)
# 4               7.0                         (1993, 68.0017, 40.8, 139)
# ...             ...                                                ...
# 3909            7.0  (2018, 68.90833333333333, 41.50166666666667, 151)
# 3910            8.0  (2018, 68.90666666666667, 41.49666666666667, 151)
# 3911            9.0  (2018, 68.66833333333334, 41.580000000000005, ...
# 3912           10.0  (2018, 68.66333333333334, 41.57833333333333, 151)
# 3913            5.0  (2018, 67.71499999999999, 41.980000000000004, ...
#
# [3914 rows x 7 columns]

# %%
print(true_two)
# Out:
#         obs_lat_t  obs_lon_t  bottomdepth_t  year_t  date_no_t  02tempmld_t  \
# 0.0       40.6183    68.4617           73.0  1993.0      139.0         16.0
# 1.0       40.6480    67.5500           84.0  1993.0      141.0          7.0
# 2.0       40.6933    68.2033           77.0  1993.0      139.0         14.0
# 3.0       40.6500    67.6200           85.0  1993.0      142.0          7.0
# 4.0       40.8000    68.0017           69.0  1993.0      139.0          7.0
# ...           ...        ...            ...     ...        ...          ...
# 835.0         NaN        NaN            NaN     NaN        NaN          NaN
# 1852.0        NaN        NaN            NaN     NaN        NaN          NaN
# 1870.0        NaN        NaN            NaN     NaN        NaN          NaN
# 2368.0        NaN        NaN            NaN     NaN        NaN          NaN
# 3380.0        NaN        NaN            NaN     NaN        NaN          NaN
#
#                                                  location  obs_lat_d1  \
# 0.0                         (1993, 68.4617, 40.6183, 139)   40.618300
# 1.0                            (1993, 67.55, 40.648, 141)   40.648000
# 2.0                         (1993, 68.2033, 40.6933, 139)   40.693300
# 3.0                             (1993, 67.62, 40.65, 142)   40.650000
# 4.0                            (1993, 68.0017, 40.8, 139)   40.800000
# ...                                                   ...         ...
# 835.0                         (1996, 66.668, 41.423, 133)   41.423000
# 1852.0                      (2003, 68.7583, 40.6433, 145)   40.643300
# 1870.0                      (2003, 67.7533, 41.8433, 147)   41.843300
# 2368.0                      (2006, 68.8467, 41.0917, 139)   41.091700
# 3380.0  (2016, 72.24499999999999, 40.86833333333333, 128)   40.868333
#
#         obs_lon_d1  bottomdepth_d1  year_d1  date_no_d1  001densmld_d1
# 0.0        68.4617            73.0   1993.0       139.0            9.0
# 1.0        67.5500            84.0   1993.0       141.0            6.0
# 2.0        68.2033            77.0   1993.0       139.0            6.0
# 3.0        67.6200            85.0   1993.0       142.0            6.0
# 4.0        68.0017            69.0   1993.0       139.0            6.0
# ...            ...             ...      ...         ...            ...
# 835.0      66.6680            85.0   1996.0       133.0           27.0
# 1852.0     68.7583            62.0   2003.0       145.0            7.0
# 1870.0     67.7533            36.0   2003.0       147.0            8.0
# 2368.0     68.8467            72.0   2006.0       139.0           15.0
# 3380.0     72.2450            28.0   2016.0       128.0            5.0
#
# [5066 rows x 13 columns]

# %%
print(len(true_one))
print(len(true_two))
# Out:
# 26404
# 5066

# %%
pandas_full_drop_resetnew = pandas_full_drop_reset.assign(location=[*zip(pandas_full_drop_reset.year, pandas_full_drop_reset.obs_lon, pandas_full_drop_reset.obs_lat,pandas_full_drop_reset.date_no)])
print(len(pandas_full_drop_resetnew['location'].unique()))
# Out:
# 4697

# %%
pandas_full_undropped_new = pd.merge(pandas_full_drop_resetnew, pandas_01new_dd, left_on=['location'], 
                        right_on = ['location'], left_index=True, how='outer', sort=False)

# %%
print(len(pandas_full_undropped_new))
# Out:
# 5000

# %%
pandas_full_undropped_new_dd = pandas_full_undropped_new.drop_duplicates(subset=['location'])
print(len(pandas_full_undropped_new_dd))
# Out:
# 5000

# %%
print(len(pandas_full_undropped_new_dd))
# Out:
# 5000

# %%
# sum(pd.isnull(pandas_full_undropped_new_dd['003densmld_d3']))
sum(pd.isnull(pandas_full_undropped_new_dd['02tempmld_t']))
# Out:
# 1209

# %%
print(pandas_full_undropped_new_dd['003densmld_d3'].unique())
# Out:
# [ nan 14.   7.   9.  15.  12.   5.  11.  10.  16.  18.   8.   6.  51.
#  55.  54.  50.  45.  46.  49.  48.  47.  19.  17.  21.  29.  60.  65.
#  22.  33.   4.  20.  13.  26.  53.  52.  27.  41.  32.  24.  40.  36.
#  35.  28.  70.  38.  58.  39.  66.  63.  23.  56.  68.  43.  62.  25.
#  31.  64.  61.  57.  74.   3.  73.  75.  44.  67.  42.  77.  86.  59.
#  30.  37.  79.  69.  81.  72.  76.  85.  90.  91.  92.  78.   7.4 11.9
#  11.4 13.4 18.5 14.9 16.6  6.5  7.1 17.4 22.4  8.1 51.5 71.  29.5  8.5
#   4.4 13.6 11.5  5.4 15.4  4.1 80.  84.  34.  93.  83.  41.9  6.4 13.9
#  10.6  8.6  7.9  7.5]

# %%
pandas_full_drop_new = pandas_full_undropped_new.drop(columns=['date_no_d1', 'year_d1', 'bottomdepth_d1', 'obs_lon_d1','obs_lat_d1','location','index' ])

# %%
pandas_full_drop_new_reset = pandas_full_drop_new.reset_index()

# %%
pandas_full_drop_new_reset = pandas_full_drop_new_reset.drop(columns=['index' ])

# %%
print(pandas_full_drop_new_reset)
# Out:
#        001densmld  003densmld  glorys_lat_index  glorys_lon_index  \
# 0             5.0         5.0              19.0              40.0
# 1             5.0         5.0              38.0              50.0
# 2             4.0         4.0              43.0              58.0
# 3             6.0         9.0              46.0              61.0
# 4             5.0         8.0              49.0              64.0
# ...           ...         ...               ...               ...
# 27877         NaN         NaN               NaN               NaN
# 27878         NaN         NaN               NaN               NaN
# 27879         NaN         NaN               NaN               NaN
# 27880         NaN         NaN               NaN               NaN
# 27881         NaN         NaN               NaN               NaN
#
#        bottomdepth  date_no  02tempmld  glorys_mld  glorysmld_new003  obs_lat  \
# 0           2200.0    129.0        5.0   10.528886               NaN  36.5517
# 1            956.0    130.0        NaN   10.528886               NaN  38.1667
# 2            803.0    131.0        4.0   10.528886               NaN  38.5650
# 3            775.0    131.0       14.0   10.528886               NaN  38.8150
# 4            643.0    132.0       10.0   10.376293               NaN  39.1167
# ...            ...      ...        ...         ...               ...      ...
# 27877          NaN      NaN        NaN         NaN               NaN      NaN
# 27878          NaN      NaN        NaN         NaN               NaN      NaN
# 27879          NaN      NaN        NaN         NaN               NaN      NaN
# 27880          NaN      NaN        NaN         NaN               NaN      NaN
# 27881          NaN      NaN        NaN         NaN               NaN      NaN
#
#        obs_lon    year  glorys_lat  glorys_lon  glorysmld_new001  02tempmld_t  \
# 0      74.6667  1993.0   36.583332  -74.666664               NaN          NaN
# 1      73.8500  1993.0   38.166668  -73.833336               NaN          NaN
# 2      73.1633  1993.0   38.583332  -73.166664               NaN          NaN
# 3      72.9017  1993.0   38.833332  -72.916664               NaN          NaN
# 4      72.6700  1993.0   39.083332  -72.666664               NaN          NaN
# ...        ...     ...         ...         ...               ...          ...
# 27877      NaN     NaN         NaN         NaN               NaN          NaN
# 27878      NaN     NaN         NaN         NaN               NaN          NaN
# 27879      NaN     NaN         NaN         NaN               NaN          NaN
# 27880      NaN     NaN         NaN         NaN               NaN          NaN
# 27881      NaN     NaN         NaN         NaN               NaN          NaN
#
#        003densmld_d3  001densmld_d1
# 0                NaN            NaN
# 1                NaN            NaN
# 2                NaN            NaN
# 3                NaN            NaN
# 4                NaN            NaN
# ...              ...            ...
# 27877            NaN           51.0
# 27878            NaN           42.0
# 27879            NaN            9.0
# 27880            NaN            6.0
# 27881            NaN            5.0
#
# [27882 rows x 18 columns]

# %%
plt.scatter(pandas_full_drop_new_reset['001densmld'],pandas_full_drop_new_reset['001densmld_d1'],alpha=0.2)
plt.show()

# %%
plt.scatter(pandas_full_drop_new_reset['003densmld_d3'],pandas_full_drop_new_reset['001densmld_d1'],alpha=0.03)
plt.show()

# %%
print(np.nanmean(pandas_full_drop_new_reset['003densmld_d3']-pandas_full_drop_new_reset['02tempmld_t']))
print(np.nanmean(pandas_full_drop_new_reset['003densmld']-pandas_full_drop_new_reset['02tempmld_t']))
print(np.nanmean(pandas_full_drop_new_reset['001densmld_d1']-pandas_full_drop_new_reset['02tempmld_t']))
print(np.nanmean(pandas_full_drop_new_reset['001densmld']-pandas_full_drop_new_reset['02tempmld_t']))
# Out:
# -4.949178532311063
# -4.448630887185104
# -14.64507658643326
# -14.154505494505495

# %%
print(np.nanmean(pandas_full_drop_new_reset['003densmld_d3']-pandas_001and003['02tempmld']))
print(np.nanmean(pandas_full_drop_new_reset['003densmld']-pandas_001and003['02tempmld']))
print(np.nanmean(pandas_full_drop_new_reset['001densmld_d1']-pandas_001and003['02tempmld']))
print(np.nanmean(pandas_full_drop_new_reset['001densmld']-pandas_001and003['02tempmld']))
# Out:
# -4.368883312421581
# -4.152106430155211
# -13.296019900497512
# -13.590308370044053

# %%
pandas_full_undropped_new_dd.iloc[13]
# Out:
# index                                              5
# 001densmld                                         7
# 003densmld                                        15
# glorys_lat_index                                  70
# glorys_lon_index                                 123
# bottomdepth                                       69
# date_no                                          139
# 02tempmld                                         15
# glorys_mld                                   10.5289
# glorysmld_new003                                 NaN
# obs_lat                                      40.8167
# obs_lon                                       67.785
# year                                            1993
# glorys_lat                                   40.8333
# glorys_lon                                    -67.75
# glorysmld_new001                                 NaN
# 02tempmld_t                                       15
# 003densmld_d3                                     15
# location            (1993.0, 67.785, 40.8167, 139.0)
# obs_lat_d1                                   40.8167
# obs_lon_d1                                    67.785
# bottomdepth_d1                                    69
# year_d1                                         1993
# date_no_d1                                       139
# 001densmld_d1                                      7
# Name: 5.0, dtype: object

# %%
pandas_full_undropped_new_dd.obs_lat = pandas_full_undropped_new_dd.obs_lat.combine_first(pandas_full_undropped_new_dd.obs_lat_d1)

# %%
pandas_full_undropped_new_dd_use = pandas_full_undropped_new_dd.drop(columns=['003densmld', '001densmld',
                                                                             'year_d1','date_no_d1','bottomdepth_d1',
                                                                             'obs_lon_d1','obs_lat_d1','location'])

# %%
print(len(pandas_full_undropped_new_dd_use))
# Out:
# 5000

# %%
pandas_use = pandas_full_drop_new_reset.drop(columns=['003densmld', '001densmld'])

# %%
pandas_full_undropped_new_dd_use_dna = pandas_full_undropped_new_dd_use.dropna(subset=['02tempmld_t','003densmld_d3','001densmld_d1'], how='all')

# %%
pandas_full_undropped_new_dd_use_dna_reset = pandas_full_undropped_new_dd_use_dna.reset_index()

# %%
pandas_full_undropped_new_dd_use_dna_reset_dd_li = pandas_full_undropped_new_dd_use_dna_reset.drop(columns=['index'])

# %%
print(4402)

# %%
print(pandas_full_undropped_new_dd_use_dna_reset_dd_li)
# Out:
#       level_0  glorys_lat_index  glorys_lon_index  bottomdepth  date_no  \
# 0         0.0              67.0             114.0         73.0    139.0
# 1         1.0              68.0             125.0         84.0    141.0
# 2         2.0              68.0             118.0         77.0    139.0
# 3         5.0              70.0             123.0         69.0    139.0
# 4         6.0              68.0             121.0         81.0    142.0
# ...       ...               ...               ...          ...      ...
# 4398   3901.0               NaN               NaN          NaN      NaN
# 4399   3906.0               NaN               NaN          NaN      NaN
# 4400   3908.0               NaN               NaN          NaN      NaN
# 4401   3911.0               NaN               NaN          NaN      NaN
# 4402   3913.0               NaN               NaN          NaN      NaN
#
#       02tempmld  glorys_mld  glorysmld_new003  obs_lat  obs_lon    year  \
# 0          16.0   10.528886               NaN  40.6183  68.4617  1993.0
# 1           7.0   10.528886               NaN  40.6480  67.5500  1993.0
# 2          14.0   10.528886               NaN  40.6933  68.2033  1993.0
# 3          15.0   10.528886               NaN  40.8167  67.7850  1993.0
# 4          81.0   10.528886               NaN  40.6770  67.8800  1993.0
# ...         ...         ...               ...      ...      ...     ...
# 4398        NaN         NaN               NaN      NaN      NaN     NaN
# 4399        NaN         NaN               NaN      NaN      NaN     NaN
# 4400        NaN         NaN               NaN      NaN      NaN     NaN
# 4401        NaN         NaN               NaN      NaN      NaN     NaN
# 4402        NaN         NaN               NaN      NaN      NaN     NaN
#
#       glorys_lat  glorys_lon  glorysmld_new001  02tempmld_t  003densmld_d3  \
# 0      40.583332  -68.500000               NaN         16.0           14.0
# 1      40.666668  -67.583336               NaN          7.0            7.0
# 2      40.666668  -68.166664               NaN         14.0            9.0
# 3      40.833332  -67.750000               NaN         15.0           15.0
# 4      40.666668  -67.916664               NaN         11.0           12.0
# ...          ...         ...               ...          ...            ...
# 4398         NaN         NaN               NaN          NaN            NaN
# 4399         NaN         NaN               NaN          NaN            NaN
# 4400         NaN         NaN               NaN          NaN            NaN
# 4401         NaN         NaN               NaN          NaN            NaN
# 4402         NaN         NaN               NaN          NaN            NaN
#
#       001densmld_d1
# 0               9.0
# 1               6.0
# 2               6.0
# 3               7.0
# 4              10.0
# ...             ...
# 4398           51.0
# 4399           42.0
# 4400            9.0
# 4401            6.0
# 4402            5.0
#
# [4403 rows x 17 columns]

# %%
sum(pd.isnull(pandas_full_undropped_new_dd_use_dna_reset_dd_li['bottomdepth']))
# Out:
# 988

# %%
plt.scatter(pandas_use['glorys_mld'],pandas_use['003densmld_d3'],alpha=0.03)
plt.show()
# plt.scatter(pandas_use['glorys_mld'],pandas_001and003['003densmld'],alpha=0.3)
# plt.show()

# %%
print(pandas_use)
# Out:
#       glorys_lat_index  glorys_lon_index  bottomdepth  date_no  02tempmld  \
# 0                 71.0              82.0         53.0      6.0       53.0
# 1                 68.0              83.0         61.0      6.0       50.0
# 2                 68.0              89.0         62.0      6.0       33.0
# 3                 70.0              91.0         51.0      6.0       37.0
# 4                 71.0              88.0         54.0      6.0       54.0
# ...                ...               ...          ...      ...        ...
# 1174               NaN               NaN          NaN      NaN        NaN
# 1175               NaN               NaN          NaN      NaN        NaN
# 1176               NaN               NaN          NaN      NaN        NaN
# 1177               NaN               NaN          NaN      NaN        NaN
# 1178               NaN               NaN          NaN      NaN        NaN
#
#       glorys_mld  glorysmld_new003  obs_lat  obs_lon    year  glorys_lat  \
# 0      36.469620         55.764290  40.9517  71.1700  1993.0   40.916668
# 1      29.602957         40.344051  40.6983  71.0500  1993.0   40.666668
# 2      47.151100         55.764290  40.6517  70.5500  1993.0   40.666668
# 3      44.251842         55.764290  40.8317  70.3833  1993.0   40.833332
# 4      15.106663         25.211411  40.9017  70.6833  1993.0   40.916668
# ...          ...               ...      ...      ...     ...         ...
# 1174         NaN               NaN      NaN      NaN     NaN         NaN
# 1175         NaN               NaN      NaN      NaN     NaN         NaN
# 1176         NaN               NaN      NaN      NaN     NaN         NaN
# 1177         NaN               NaN      NaN      NaN     NaN         NaN
# 1178         NaN               NaN      NaN      NaN     NaN         NaN
#
#       glorys_lon  glorysmld_new001  02tempmld_t  003densmld_d3  001densmld_d1
# 0     -71.166664         25.211411         53.0           53.0           53.0
# 1     -71.083336         34.434151         50.0           49.0           46.0
# 2     -70.583336         47.373692         33.0           45.0           33.0
# 3     -70.416664         47.373692         37.0           36.0           32.0
# 4     -70.666664         15.810070         54.0           54.0           54.0
# ...          ...               ...          ...            ...            ...
# 1174         NaN               NaN          NaN            NaN           55.0
# 1175         NaN               NaN          NaN            NaN           39.5
# 1176         NaN               NaN          NaN            NaN           50.0
# 1177         NaN               NaN          NaN            NaN           65.0
# 1178         NaN               NaN          NaN            NaN            6.0
#
# [1179 rows x 16 columns]

# %%
pandas_use.to_csv('01_usethisone.csv')

# %%
dec = pd.read_csv('12_usethisone.csv')

# %%
print(dec)
# Out:
#      Unnamed: 0  glorys_lat_index  glorys_lon_index  bottomdepth  date_no  \
# 0             0              71.0              88.0         53.0    335.0
# 1             1              72.0              92.0         40.0    335.0
# 2             2              73.0              96.0         25.0    335.0
# 3             3              71.0              94.0         24.0    335.0
# 4             4              71.0              96.0         22.0    335.0
# ..          ...               ...               ...          ...      ...
# 253         253              70.0              94.0          NaN    341.0
# 254         254              71.0              94.0          NaN    342.0
# 255         255              71.0              95.0          NaN    342.0
# 256         256              72.0              95.0          NaN    342.0
# 257         257              72.0              94.0          NaN    342.0
#
#      02tempmld  glorys_mld  glorysmld_new001  obs_lat  obs_lon  year  \
# 0         53.0   50.965916         55.764290  40.9000  70.6833  1993
# 1         40.0   37.079990         40.344051  41.0350  70.3667  1993
# 2         25.0   19.837032         21.598820  41.0650  70.0300  1993
# 3         24.0   25.940735         29.444731  40.9317  70.1333  1993
# 4         22.0   21.668144         21.598820  40.9300  69.9850  1993
# ..         ...         ...               ...      ...      ...   ...
# 253        NaN         NaN         34.434151  40.8733  70.1467  2011
# 254        NaN         NaN         29.444731  40.9533  70.1817  2011
# 255        NaN         NaN         25.211411  40.9550  70.1133  2011
# 256        NaN         NaN         25.211411  41.0350  70.0950  2011
# 257        NaN         NaN         25.211411  41.0383  70.1633  2011
#
#      glorys_lat  glorys_lon  glorysmld_new003  02tempmld_t  003densmld_d3  \
# 0     40.916668  -70.666664         55.764290         53.0           53.0
# 1     41.000000  -70.333336         40.344051         40.0           40.0
# 2     41.083332  -70.000000         21.598820         25.0           25.0
# 3     40.916668  -70.166664         29.444731         24.0           24.0
# 4     40.916668  -70.000000         21.598820         22.0           22.0
# ..          ...         ...               ...          ...            ...
# 253   40.833332  -70.166664         34.434151          NaN            NaN
# 254   40.916668  -70.166664         29.444731          NaN            NaN
# 255   40.916668  -70.083336         25.211411          NaN            NaN
# 256   41.000000  -70.083336         25.211411          NaN            NaN
# 257   41.000000  -70.166664         25.211411          NaN            NaN
#
#      001densmld_d1
# 0             32.0
# 1             40.0
# 2             18.0
# 3             24.0
# 4             18.0
# ..             ...
# 253            NaN
# 254            NaN
# 255            NaN
# 256            NaN
# 257            NaN
#
# [258 rows x 17 columns]

# %%
countwithinpolygon = []; tempmld = []; obs_lat = []; obs_lon = []; date_no = []; bottomdepth = []; years = []
yearwithdata = []; datefull = []; finallatestdepth = []; glorysmld = []
glorys_lat = []; glorys_lon = []; glorys_lat_index = []; glorys_lon_index = []

for year in range(1993,2019):
    filename = 'casts_{}.mat'.format(year)
    file = scipy.io.loadmat(filename,squeeze_me=True)
    npfile = file['casts_{}'.format(year)]
    
    lat_intermediate = []; lon_intermediate = []; p_intermediate = []; counterii = []
    t_intermediate = []; yd_intermediate = []; sal_intermediate = []; floor_intermediate = []
    
    for i in range(len(npfile)):
        yd = npfile[i]['yd']
        p = npfile[i]['p']
        s = npfile[i]['s']
        t = npfile[i]['t']
        gear = npfile[i]['gear']
        floordepth = npfile[i]['depth']
#         if yd == 0:
        if yd >= 0 and yd <= 365:  # and floordepth <= 200
            lat_intermediate.append(npfile[i]['lat'])
            lon_intermediate.append(npfile[i]['lon'])
            p_intermediate.append(npfile[i]['p'])
            t_intermediate.append(npfile[i]['t'])
            yd_intermediate.append(npfile[i]['yd'])
            sal_intermediate.append(npfile[i]['s'])
            floor_intermediate.append(npfile[i]['depth'])
    month_df = pd.DataFrame({'day': yd_intermediate,'lon': lon_intermediate,'lat': lat_intermediate, 'p': p_intermediate, 't': t_intermediate,'depth': floor_intermediate, 's': sal_intermediate})
    newdf = pd.DataFrame({'lon': lon_intermediate,'lat': lat_intermediate,'date': yd_intermediate})
    for ii in range(len(month_df)):
        new = newdf.iloc[ii].values
        point = Point(new)
        if isinstance(month_df['p'].iloc[ii], int) or isinstance(month_df['p'].iloc[ii], float) or isinstance(month_df['t'].iloc[ii], int) or isinstance(month_df['t'].iloc[ii], float):
            pass
        elif polygon_w.contains(point) == True:
            countwithinpolygon.append(1)
    print(len(countwithinpolygon))
# Out:
# 636
# 1523
# 2506
# 3568
# 4596
# 5445
# 6431
# 6719
# 7063
# 7382
# 7726
# 8060
# 8425
# 8745
# 9078
# 9411
# 9911
# 10339
# 10657
# 10985
# 11267
# 11514
# 11757
# 11957
# 12176
# 12363
